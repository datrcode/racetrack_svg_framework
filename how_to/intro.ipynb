# %% [markdown]
# # racetrack_svg_framework
#
# Package of visualizations modeled after the java racetrack visualization application.  Visualizations are produced directly from pandas dataframes into scalable vector graphics (SVG) markdown.
#
# Why would you use this visualization library when there are so many other (excellent) choices?  You wouldn't.
#
# That being said, here are the reasons I develop and use this -- many of these reasons are not unique to this package:
# * Native support for pandas and polars dataframes
# * Built-in colors that are universal across views
# * Counting implementations to include count-by-set operations
# * Annotation support for dataframe filtering and views
# * Small multiples for most view types
# * SVG output
# * Layout templating for creating coordinated views
# * Coordinated and filtering of views using Panels
# * Temporal aggregation implementations
#
# ## Implemented visualizations
# * Temporal Barchart
# * Periodic Barchart
# * XY Scatterplot
# * LinkNode Visualization
# * Histogram
# * Piechart
# * Boxplot
# * Calendar Heatmap
# * Choropleth Maps
#
# ## Commonalities Across Visualization Implementations
# Where possible, all methods are mostly composed of default values meaning that only the absolutely necessary parameters are required.
#
# ### Data Manipulation Parameters
# * df - pandas or polars dataframe to visualization
# * count_by - field to count by; row counting indicated by default value of None
# * color_by - field to color by; default color indicated by None
# * ts_field - timestamp field (for temporal views), will be automatically selected if set to None
#
# ### Geometry Parameters
# * w - width of the visualization in pixels
# * h - height of the visualization in pixels
# * txt_h - text height for labels

# %% [markdown]
# ## Importing racetrack_svg library

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(1, '../framework') # base location of the .py classes
from racetrack import *

rt = RACETrack()

# %% [markdown]
# ## Simple Temporal Barchart Example

# %%
# Simple temporal barchart example
from math import pi, cos, sin

_timestamps, _types, _counts = [], [], []
_phase_0, _phase_1 = 90, 180
for _date in pd.date_range(start='2021-01-01', end='2021-12-31', freq='D'):
    _timestamps.append(_date)
    _types.     append('blue')
    _counts.    append(15 + cos(_phase_0 * pi/180)*15)

    _timestamps.append(_date)
    _types.     append('red')
    _counts.    append(10 + sin(_phase_1 * pi/180)*5)

    _phase_0 = (_phase_0 + 5)  % 360
    _phase_1 = (_phase_1 + 10) % 360

df = pd.DataFrame({'timestamp':_timestamps, 'type':_types, 'count':_counts})

rt.temporalBarChart(df, count_by='count', color_by='type', w=1280, h=128)

# %% [markdown]
# <svg id="temporalbarchart_27295" x="0" y="0" width="1280" height="128" xmlns="http://www.w3.org/2000/svg"><rect width="1279" height="127" x="0" y="0" fill="#ffffff" fill-opacity="(1.0,)" stroke="#ffffff" stroke-opacity="(1.0,)" /><line x1="20" y1="3" x2="20" y2="110" stroke="#909090" stroke_width="0.5" /><text x="22" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">01/01</text><line x1="23.443835616438356" y1="3" x2="23.443835616438356" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="26.887671232876713" y1="3" x2="26.887671232876713" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="30.33150684931507" y1="3" x2="30.33150684931507" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="33.775342465753425" y1="3" x2="33.775342465753425" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="37.21917808219178" y1="3" x2="37.21917808219178" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="40.66301369863014" y1="3" x2="40.66301369863014" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="44.106849315068494" y1="3" x2="44.106849315068494" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="47.55068493150685" y1="3" x2="47.55068493150685" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="50.99452054794521" y1="3" x2="50.99452054794521" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="54.43835616438356" y1="3" x2="54.43835616438356" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="57.88219178082192" y1="3" x2="57.88219178082192" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="61.326027397260276" y1="3" x2="61.326027397260276" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="64.76986301369863" y1="3" x2="64.76986301369863" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="68.21369863013697" y1="3" x2="68.21369863013697" y2="110" stroke="#909090" stroke_width="0.5" /><text x="70.21369863013697" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">01/15</text><line x1="71.65753424657532" y1="3" x2="71.65753424657532" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="75.10136986301367" y1="3" x2="75.10136986301367" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="78.54520547945202" y1="3" x2="78.54520547945202" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="81.98904109589037" y1="3" x2="81.98904109589037" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="85.43287671232872" y1="3" x2="85.43287671232872" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="88.87671232876707" y1="3" x2="88.87671232876707" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="92.32054794520542" y1="3" x2="92.32054794520542" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="95.76438356164377" y1="3" x2="95.76438356164377" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="99.20821917808212" y1="3" x2="99.20821917808212" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="102.65205479452047" y1="3" x2="102.65205479452047" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="106.09589041095882" y1="3" x2="106.09589041095882" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="109.53972602739717" y1="3" x2="109.53972602739717" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="112.98356164383551" y1="3" x2="112.98356164383551" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="116.42739726027386" y1="3" x2="116.42739726027386" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="119.87123287671221" y1="3" x2="119.87123287671221" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="123.31506849315056" y1="3" x2="123.31506849315056" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="126.75890410958891" y1="3" x2="126.75890410958891" y2="110" stroke="#909090" stroke_width="0.5" /><text x="128.7589041095889" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">02/01</text><line x1="130.20273972602726" y1="3" x2="130.20273972602726" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="133.6465753424656" y1="3" x2="133.6465753424656" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="137.09041095890396" y1="3" x2="137.09041095890396" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="140.5342465753423" y1="3" x2="140.5342465753423" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="143.97808219178066" y1="3" x2="143.97808219178066" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="147.421917808219" y1="3" x2="147.421917808219" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="150.86575342465736" y1="3" x2="150.86575342465736" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="154.3095890410957" y1="3" x2="154.3095890410957" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="157.75342465753405" y1="3" x2="157.75342465753405" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="161.1972602739724" y1="3" x2="161.1972602739724" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="164.64109589041075" y1="3" x2="164.64109589041075" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="168.0849315068491" y1="3" x2="168.0849315068491" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="171.52876712328745" y1="3" x2="171.52876712328745" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="174.9726027397258" y1="3" x2="174.9726027397258" y2="110" stroke="#909090" stroke_width="0.5" /><text x="176.9726027397258" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">02/15</text><line x1="178.41643835616415" y1="3" x2="178.41643835616415" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="181.8602739726025" y1="3" x2="181.8602739726025" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="185.30410958904085" y1="3" x2="185.30410958904085" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="188.7479452054792" y1="3" x2="188.7479452054792" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="192.19178082191755" y1="3" x2="192.19178082191755" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="195.6356164383559" y1="3" x2="195.6356164383559" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="199.07945205479425" y1="3" x2="199.07945205479425" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="202.5232876712326" y1="3" x2="202.5232876712326" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="205.96712328767094" y1="3" x2="205.96712328767094" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="209.4109589041093" y1="3" x2="209.4109589041093" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="212.85479452054764" y1="3" x2="212.85479452054764" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="216.298630136986" y1="3" x2="216.298630136986" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="219.74246575342434" y1="3" x2="219.74246575342434" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="223.1863013698627" y1="3" x2="223.1863013698627" y2="110" stroke="#909090" stroke_width="0.5" /><text x="225.1863013698627" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">03/01</text><line x1="226.63013698630104" y1="3" x2="226.63013698630104" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="230.0739726027394" y1="3" x2="230.0739726027394" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="233.51780821917774" y1="3" x2="233.51780821917774" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="236.9616438356161" y1="3" x2="236.9616438356161" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="240.40547945205444" y1="3" x2="240.40547945205444" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="243.84931506849279" y1="3" x2="243.84931506849279" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="247.29315068493113" y1="3" x2="247.29315068493113" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="250.73698630136948" y1="3" x2="250.73698630136948" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="254.18082191780783" y1="3" x2="254.18082191780783" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="257.6246575342462" y1="3" x2="257.6246575342462" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="261.06849315068456" y1="3" x2="261.06849315068456" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="264.51232876712294" y1="3" x2="264.51232876712294" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="267.9561643835613" y1="3" x2="267.9561643835613" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="271.3999999999997" y1="3" x2="271.3999999999997" y2="110" stroke="#909090" stroke_width="0.5" /><text x="273.3999999999997" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">03/15</text><line x1="274.84383561643807" y1="3" x2="274.84383561643807" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="278.28767123287645" y1="3" x2="278.28767123287645" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="281.7315068493148" y1="3" x2="281.7315068493148" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="285.1753424657532" y1="3" x2="285.1753424657532" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="288.6191780821916" y1="3" x2="288.6191780821916" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="292.06301369862996" y1="3" x2="292.06301369862996" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="295.50684931506834" y1="3" x2="295.50684931506834" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="298.9506849315067" y1="3" x2="298.9506849315067" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="302.3945205479451" y1="3" x2="302.3945205479451" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="305.83835616438347" y1="3" x2="305.83835616438347" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="309.28219178082185" y1="3" x2="309.28219178082185" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="312.7260273972602" y1="3" x2="312.7260273972602" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="316.1698630136986" y1="3" x2="316.1698630136986" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="319.613698630137" y1="3" x2="319.613698630137" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="323.05753424657536" y1="3" x2="323.05753424657536" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="326.50136986301374" y1="3" x2="326.50136986301374" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="329.9452054794521" y1="3" x2="329.9452054794521" y2="110" stroke="#909090" stroke_width="0.5" /><text x="331.9452054794521" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">04/01</text><line x1="333.3890410958905" y1="3" x2="333.3890410958905" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="336.83287671232887" y1="3" x2="336.83287671232887" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="340.27671232876725" y1="3" x2="340.27671232876725" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="343.7205479452056" y1="3" x2="343.7205479452056" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="347.164383561644" y1="3" x2="347.164383561644" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="350.6082191780824" y1="3" x2="350.6082191780824" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="354.05205479452076" y1="3" x2="354.05205479452076" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="357.49589041095913" y1="3" x2="357.49589041095913" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="360.9397260273975" y1="3" x2="360.9397260273975" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="364.3835616438359" y1="3" x2="364.3835616438359" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="367.82739726027427" y1="3" x2="367.82739726027427" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="371.27123287671265" y1="3" x2="371.27123287671265" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="374.715068493151" y1="3" x2="374.715068493151" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="378.1589041095894" y1="3" x2="378.1589041095894" y2="110" stroke="#909090" stroke_width="0.5" /><text x="380.1589041095894" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">04/15</text><line x1="381.6027397260278" y1="3" x2="381.6027397260278" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="385.04657534246616" y1="3" x2="385.04657534246616" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="388.49041095890453" y1="3" x2="388.49041095890453" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="391.9342465753429" y1="3" x2="391.9342465753429" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="395.3780821917813" y1="3" x2="395.3780821917813" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="398.82191780821967" y1="3" x2="398.82191780821967" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="402.26575342465804" y1="3" x2="402.26575342465804" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="405.7095890410964" y1="3" x2="405.7095890410964" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="409.1534246575348" y1="3" x2="409.1534246575348" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="412.5972602739732" y1="3" x2="412.5972602739732" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="416.04109589041155" y1="3" x2="416.04109589041155" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="419.48493150684993" y1="3" x2="419.48493150684993" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="422.9287671232883" y1="3" x2="422.9287671232883" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="426.3726027397267" y1="3" x2="426.3726027397267" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="429.81643835616507" y1="3" x2="429.81643835616507" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="433.26027397260344" y1="3" x2="433.26027397260344" y2="110" stroke="#909090" stroke_width="0.5" /><text x="435.26027397260344" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">05/01</text><line x1="436.7041095890418" y1="3" x2="436.7041095890418" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="440.1479452054802" y1="3" x2="440.1479452054802" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="443.5917808219186" y1="3" x2="443.5917808219186" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="447.03561643835695" y1="3" x2="447.03561643835695" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="450.47945205479533" y1="3" x2="450.47945205479533" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="453.9232876712337" y1="3" x2="453.9232876712337" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="457.3671232876721" y1="3" x2="457.3671232876721" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="460.81095890411046" y1="3" x2="460.81095890411046" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="464.25479452054884" y1="3" x2="464.25479452054884" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="467.6986301369872" y1="3" x2="467.6986301369872" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="471.1424657534256" y1="3" x2="471.1424657534256" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="474.586301369864" y1="3" x2="474.586301369864" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="478.03013698630235" y1="3" x2="478.03013698630235" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="481.47397260274073" y1="3" x2="481.47397260274073" y2="110" stroke="#909090" stroke_width="0.5" /><text x="483.47397260274073" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">05/15</text><line x1="484.9178082191791" y1="3" x2="484.9178082191791" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="488.3616438356175" y1="3" x2="488.3616438356175" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="491.80547945205586" y1="3" x2="491.80547945205586" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="495.24931506849424" y1="3" x2="495.24931506849424" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="498.6931506849326" y1="3" x2="498.6931506849326" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="502.136986301371" y1="3" x2="502.136986301371" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="505.5808219178094" y1="3" x2="505.5808219178094" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="509.02465753424775" y1="3" x2="509.02465753424775" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="512.4684931506861" y1="3" x2="512.4684931506861" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="515.9123287671244" y1="3" x2="515.9123287671244" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="519.3561643835628" y1="3" x2="519.3561643835628" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="522.8000000000012" y1="3" x2="522.8000000000012" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="526.2438356164396" y1="3" x2="526.2438356164396" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="529.687671232878" y1="3" x2="529.687671232878" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="533.1315068493163" y1="3" x2="533.1315068493163" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="536.5753424657547" y1="3" x2="536.5753424657547" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="540.0191780821931" y1="3" x2="540.0191780821931" y2="110" stroke="#909090" stroke_width="0.5" /><text x="542.0191780821931" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">06/01</text><line x1="543.4630136986315" y1="3" x2="543.4630136986315" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="546.9068493150698" y1="3" x2="546.9068493150698" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="550.3506849315082" y1="3" x2="550.3506849315082" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="553.7945205479466" y1="3" x2="553.7945205479466" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="557.238356164385" y1="3" x2="557.238356164385" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="560.6821917808234" y1="3" x2="560.6821917808234" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="564.1260273972617" y1="3" x2="564.1260273972617" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="567.5698630137001" y1="3" x2="567.5698630137001" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="571.0136986301385" y1="3" x2="571.0136986301385" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="574.4575342465769" y1="3" x2="574.4575342465769" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="577.9013698630152" y1="3" x2="577.9013698630152" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="581.3452054794536" y1="3" x2="581.3452054794536" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="584.789041095892" y1="3" x2="584.789041095892" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="588.2328767123304" y1="3" x2="588.2328767123304" y2="110" stroke="#909090" stroke_width="0.5" /><text x="590.2328767123304" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">06/15</text><line x1="591.6767123287688" y1="3" x2="591.6767123287688" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="595.1205479452071" y1="3" x2="595.1205479452071" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="598.5643835616455" y1="3" x2="598.5643835616455" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="602.0082191780839" y1="3" x2="602.0082191780839" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="605.4520547945223" y1="3" x2="605.4520547945223" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="608.8958904109606" y1="3" x2="608.8958904109606" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="612.339726027399" y1="3" x2="612.339726027399" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="615.7835616438374" y1="3" x2="615.7835616438374" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="619.2273972602758" y1="3" x2="619.2273972602758" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="622.6712328767142" y1="3" x2="622.6712328767142" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="626.1150684931525" y1="3" x2="626.1150684931525" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="629.5589041095909" y1="3" x2="629.5589041095909" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="633.0027397260293" y1="3" x2="633.0027397260293" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="636.4465753424677" y1="3" x2="636.4465753424677" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="639.890410958906" y1="3" x2="639.890410958906" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="643.3342465753444" y1="3" x2="643.3342465753444" y2="110" stroke="#909090" stroke_width="0.5" /><text x="645.3342465753444" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">07/01</text><line x1="646.7780821917828" y1="3" x2="646.7780821917828" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="650.2219178082212" y1="3" x2="650.2219178082212" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="653.6657534246596" y1="3" x2="653.6657534246596" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="657.1095890410979" y1="3" x2="657.1095890410979" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="660.5534246575363" y1="3" x2="660.5534246575363" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="663.9972602739747" y1="3" x2="663.9972602739747" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="667.4410958904131" y1="3" x2="667.4410958904131" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="670.8849315068514" y1="3" x2="670.8849315068514" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="674.3287671232898" y1="3" x2="674.3287671232898" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="677.7726027397282" y1="3" x2="677.7726027397282" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="681.2164383561666" y1="3" x2="681.2164383561666" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="684.660273972605" y1="3" x2="684.660273972605" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="688.1041095890433" y1="3" x2="688.1041095890433" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="691.5479452054817" y1="3" x2="691.5479452054817" y2="110" stroke="#909090" stroke_width="0.5" /><text x="693.5479452054817" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">07/15</text><line x1="694.9917808219201" y1="3" x2="694.9917808219201" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="698.4356164383585" y1="3" x2="698.4356164383585" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="701.8794520547968" y1="3" x2="701.8794520547968" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="705.3232876712352" y1="3" x2="705.3232876712352" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="708.7671232876736" y1="3" x2="708.7671232876736" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="712.210958904112" y1="3" x2="712.210958904112" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="715.6547945205504" y1="3" x2="715.6547945205504" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="719.0986301369887" y1="3" x2="719.0986301369887" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="722.5424657534271" y1="3" x2="722.5424657534271" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="725.9863013698655" y1="3" x2="725.9863013698655" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="729.4301369863039" y1="3" x2="729.4301369863039" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="732.8739726027422" y1="3" x2="732.8739726027422" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="736.3178082191806" y1="3" x2="736.3178082191806" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="739.761643835619" y1="3" x2="739.761643835619" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="743.2054794520574" y1="3" x2="743.2054794520574" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="746.6493150684958" y1="3" x2="746.6493150684958" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="750.0931506849341" y1="3" x2="750.0931506849341" y2="110" stroke="#909090" stroke_width="0.5" /><text x="752.0931506849341" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">08/01</text><line x1="753.5369863013725" y1="3" x2="753.5369863013725" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="756.9808219178109" y1="3" x2="756.9808219178109" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="760.4246575342493" y1="3" x2="760.4246575342493" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="763.8684931506876" y1="3" x2="763.8684931506876" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="767.312328767126" y1="3" x2="767.312328767126" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="770.7561643835644" y1="3" x2="770.7561643835644" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="774.2000000000028" y1="3" x2="774.2000000000028" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="777.6438356164412" y1="3" x2="777.6438356164412" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="781.0876712328795" y1="3" x2="781.0876712328795" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="784.5315068493179" y1="3" x2="784.5315068493179" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="787.9753424657563" y1="3" x2="787.9753424657563" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="791.4191780821947" y1="3" x2="791.4191780821947" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="794.863013698633" y1="3" x2="794.863013698633" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="798.3068493150714" y1="3" x2="798.3068493150714" y2="110" stroke="#909090" stroke_width="0.5" /><text x="800.3068493150714" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">08/15</text><line x1="801.7506849315098" y1="3" x2="801.7506849315098" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="805.1945205479482" y1="3" x2="805.1945205479482" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="808.6383561643866" y1="3" x2="808.6383561643866" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="812.0821917808249" y1="3" x2="812.0821917808249" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="815.5260273972633" y1="3" x2="815.5260273972633" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="818.9698630137017" y1="3" x2="818.9698630137017" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="822.4136986301401" y1="3" x2="822.4136986301401" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="825.8575342465784" y1="3" x2="825.8575342465784" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="829.3013698630168" y1="3" x2="829.3013698630168" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="832.7452054794552" y1="3" x2="832.7452054794552" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="836.1890410958936" y1="3" x2="836.1890410958936" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="839.632876712332" y1="3" x2="839.632876712332" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="843.0767123287703" y1="3" x2="843.0767123287703" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="846.5205479452087" y1="3" x2="846.5205479452087" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="849.9643835616471" y1="3" x2="849.9643835616471" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="853.4082191780855" y1="3" x2="853.4082191780855" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="856.8520547945238" y1="3" x2="856.8520547945238" y2="110" stroke="#909090" stroke_width="0.5" /><text x="858.8520547945238" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">09/01</text><line x1="860.2958904109622" y1="3" x2="860.2958904109622" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="863.7397260274006" y1="3" x2="863.7397260274006" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="867.183561643839" y1="3" x2="867.183561643839" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="870.6273972602773" y1="3" x2="870.6273972602773" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="874.0712328767157" y1="3" x2="874.0712328767157" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="877.5150684931541" y1="3" x2="877.5150684931541" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="880.9589041095925" y1="3" x2="880.9589041095925" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="884.4027397260309" y1="3" x2="884.4027397260309" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="887.8465753424692" y1="3" x2="887.8465753424692" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="891.2904109589076" y1="3" x2="891.2904109589076" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="894.734246575346" y1="3" x2="894.734246575346" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="898.1780821917844" y1="3" x2="898.1780821917844" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="901.6219178082227" y1="3" x2="901.6219178082227" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="905.0657534246611" y1="3" x2="905.0657534246611" y2="110" stroke="#909090" stroke_width="0.5" /><text x="907.0657534246611" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">09/15</text><line x1="908.5095890410995" y1="3" x2="908.5095890410995" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="911.9534246575379" y1="3" x2="911.9534246575379" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="915.3972602739763" y1="3" x2="915.3972602739763" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="918.8410958904146" y1="3" x2="918.8410958904146" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="922.284931506853" y1="3" x2="922.284931506853" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="925.7287671232914" y1="3" x2="925.7287671232914" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="929.1726027397298" y1="3" x2="929.1726027397298" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="932.6164383561681" y1="3" x2="932.6164383561681" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="936.0602739726065" y1="3" x2="936.0602739726065" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="939.5041095890449" y1="3" x2="939.5041095890449" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="942.9479452054833" y1="3" x2="942.9479452054833" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="946.3917808219217" y1="3" x2="946.3917808219217" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="949.83561643836" y1="3" x2="949.83561643836" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="953.2794520547984" y1="3" x2="953.2794520547984" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="956.7232876712368" y1="3" x2="956.7232876712368" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="960.1671232876752" y1="3" x2="960.1671232876752" y2="110" stroke="#909090" stroke_width="0.5" /><text x="962.1671232876752" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">10/01</text><line x1="963.6109589041135" y1="3" x2="963.6109589041135" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="967.0547945205519" y1="3" x2="967.0547945205519" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="970.4986301369903" y1="3" x2="970.4986301369903" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="973.9424657534287" y1="3" x2="973.9424657534287" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="977.386301369867" y1="3" x2="977.386301369867" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="980.8301369863054" y1="3" x2="980.8301369863054" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="984.2739726027438" y1="3" x2="984.2739726027438" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="987.7178082191822" y1="3" x2="987.7178082191822" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="991.1616438356206" y1="3" x2="991.1616438356206" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="994.605479452059" y1="3" x2="994.605479452059" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="998.0493150684973" y1="3" x2="998.0493150684973" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1001.4931506849357" y1="3" x2="1001.4931506849357" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1004.9369863013741" y1="3" x2="1004.9369863013741" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1008.3808219178125" y1="3" x2="1008.3808219178125" y2="110" stroke="#909090" stroke_width="0.5" /><text x="1010.3808219178125" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">10/15</text><line x1="1011.8246575342508" y1="3" x2="1011.8246575342508" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1015.2684931506892" y1="3" x2="1015.2684931506892" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1018.7123287671276" y1="3" x2="1018.7123287671276" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1022.156164383566" y1="3" x2="1022.156164383566" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1025.6000000000042" y1="3" x2="1025.6000000000042" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1029.0438356164425" y1="3" x2="1029.0438356164425" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1032.4876712328808" y1="3" x2="1032.4876712328808" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1035.931506849319" y1="3" x2="1035.931506849319" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1039.3753424657573" y1="3" x2="1039.3753424657573" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1042.8191780821955" y1="3" x2="1042.8191780821955" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1046.2630136986338" y1="3" x2="1046.2630136986338" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1049.706849315072" y1="3" x2="1049.706849315072" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1053.1506849315103" y1="3" x2="1053.1506849315103" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1056.5945205479486" y1="3" x2="1056.5945205479486" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1060.0383561643869" y1="3" x2="1060.0383561643869" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1063.4821917808251" y1="3" x2="1063.4821917808251" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1066.9260273972634" y1="3" x2="1066.9260273972634" y2="110" stroke="#909090" stroke_width="0.5" /><text x="1068.9260273972634" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">11/01</text><line x1="1070.3698630137017" y1="3" x2="1070.3698630137017" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1073.81369863014" y1="3" x2="1073.81369863014" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1077.2575342465782" y1="3" x2="1077.2575342465782" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1080.7013698630165" y1="3" x2="1080.7013698630165" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1084.1452054794547" y1="3" x2="1084.1452054794547" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1087.589041095893" y1="3" x2="1087.589041095893" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1091.0328767123312" y1="3" x2="1091.0328767123312" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1094.4767123287695" y1="3" x2="1094.4767123287695" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1097.9205479452078" y1="3" x2="1097.9205479452078" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1101.364383561646" y1="3" x2="1101.364383561646" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1104.8082191780843" y1="3" x2="1104.8082191780843" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1108.2520547945226" y1="3" x2="1108.2520547945226" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1111.6958904109608" y1="3" x2="1111.6958904109608" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1115.139726027399" y1="3" x2="1115.139726027399" y2="110" stroke="#909090" stroke_width="0.5" /><text x="1117.139726027399" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">11/15</text><line x1="1118.5835616438374" y1="3" x2="1118.5835616438374" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1122.0273972602756" y1="3" x2="1122.0273972602756" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1125.4712328767139" y1="3" x2="1125.4712328767139" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1128.9150684931521" y1="3" x2="1128.9150684931521" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1132.3589041095904" y1="3" x2="1132.3589041095904" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1135.8027397260287" y1="3" x2="1135.8027397260287" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1139.246575342467" y1="3" x2="1139.246575342467" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1142.6904109589052" y1="3" x2="1142.6904109589052" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1146.1342465753435" y1="3" x2="1146.1342465753435" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1149.5780821917817" y1="3" x2="1149.5780821917817" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1153.02191780822" y1="3" x2="1153.02191780822" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1156.4657534246583" y1="3" x2="1156.4657534246583" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1159.9095890410965" y1="3" x2="1159.9095890410965" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1163.3534246575348" y1="3" x2="1163.3534246575348" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1166.797260273973" y1="3" x2="1166.797260273973" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1170.2410958904113" y1="3" x2="1170.2410958904113" y2="110" stroke="#909090" stroke_width="0.5" /><text x="1172.2410958904113" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">12/01</text><line x1="1173.6849315068496" y1="3" x2="1173.6849315068496" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1177.1287671232878" y1="3" x2="1177.1287671232878" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1180.572602739726" y1="3" x2="1180.572602739726" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1184.0164383561644" y1="3" x2="1184.0164383561644" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1187.4602739726026" y1="3" x2="1187.4602739726026" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1190.904109589041" y1="3" x2="1190.904109589041" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1194.3479452054792" y1="3" x2="1194.3479452054792" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1197.7917808219174" y1="3" x2="1197.7917808219174" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1201.2356164383557" y1="3" x2="1201.2356164383557" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1204.679452054794" y1="3" x2="1204.679452054794" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1208.1232876712322" y1="3" x2="1208.1232876712322" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1211.5671232876705" y1="3" x2="1211.5671232876705" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1215.0109589041087" y1="3" x2="1215.0109589041087" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1218.454794520547" y1="3" x2="1218.454794520547" y2="110" stroke="#909090" stroke_width="0.5" /><text x="1220.454794520547" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">12/15</text><line x1="1221.8986301369853" y1="3" x2="1221.8986301369853" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1225.3424657534235" y1="3" x2="1225.3424657534235" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1228.7863013698618" y1="3" x2="1228.7863013698618" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1232.2301369863" y1="3" x2="1232.2301369863" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1235.6739726027383" y1="3" x2="1235.6739726027383" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1239.1178082191766" y1="3" x2="1239.1178082191766" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1242.5616438356149" y1="3" x2="1242.5616438356149" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1246.0054794520531" y1="3" x2="1246.0054794520531" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1249.4493150684914" y1="3" x2="1249.4493150684914" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1252.8931506849297" y1="3" x2="1252.8931506849297" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1256.336986301368" y1="3" x2="1256.336986301368" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1259.7808219178062" y1="3" x2="1259.7808219178062" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1263.2246575342444" y1="3" x2="1263.2246575342444" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1266.6684931506827" y1="3" x2="1266.6684931506827" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1270.112328767121" y1="3" x2="1270.112328767121" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="1273.5561643835592" y1="3" x2="1273.5561643835592" y2="8" stroke="#c0c0c0" stroke_width="0.5" /><line x1="20" y1="111" x2="20"            y2="3" stroke="#101010" stroke-width="1" /><line x1="20" y1="111" x2="1277" y2="111"          stroke="#101010" stroke-width="1" /><rect x="21.0" y="47.53659268620362" width="3.4438356164383563" height="62.46340731379638" fill="#4988b6" /><rect x="21.0" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827783" fill="#0000ff" /><rect x="21.0" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="24.443835616438356" y="52.97235085177527" width="3.4438356164383563" height="57.02764914822473" fill="#4988b6" /><rect x="24.443835616438356" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="24.443835616438356" y="52.972350851775275" width="3.4438356164383563" height="22.81603155533696" fill="#ff0000" /><rect x="27.887671232876713" y="58.317335501163235" width="3.4438356164383563" height="51.682664498836765" fill="#4988b6" /><rect x="27.887671232876713" y="79.02994972226693" width="3.4438356164383563" height="30.970050277733062" fill="#0000ff" /><rect x="27.887671232876713" y="58.31733550116323" width="3.4438356164383563" height="20.712614221103703" fill="#ff0000" /><rect x="31.33150684931507" y="63.48296507846722" width="3.4438356164383563" height="46.51703492153278" fill="#4988b6" /><rect x="31.33150684931507" y="82.22198727260613" width="3.4438356164383563" height="27.778012727393868" fill="#0000ff" /><rect x="31.33150684931507" y="63.48296507846722" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="34.775342465753425" y="68.38497965547054" width="3.4438356164383563" height="41.615020344529455" fill="#4988b6" /><rect x="34.775342465753425" y="85.34020172496673" width="3.4438356164383563" height="24.659798275033275" fill="#0000ff" /><rect x="34.775342465753425" y="68.38497965547054" width="3.4438356164383563" height="16.95522206949618" fill="#ff0000" /><rect x="38.21917808219178" y="72.94544787322057" width="3.4438356164383563" height="37.05455212677943" fill="#4988b6" /><rect x="38.21917808219178" y="88.3608615845369" width="3.4438356164383563" height="21.639138415463087" fill="#0000ff" /><rect x="38.21917808219178" y="72.94544787322056" width="3.4438356164383563" height="15.415413711316347" fill="#ff0000" /><rect x="41.66301369863014" y="77.094594388479" width="3.4438356164383563" height="32.905405611521005" fill="#4988b6" /><rect x="41.66301369863014" y="91.26097780586107" width="3.4438356164383563" height="18.739022194138922" fill="#0000ff" /><rect x="41.66301369863014" y="77.094594388479" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="45.106849315068494" y="80.77239641222212" width="3.4438356164383563" height="29.227603587777875" fill="#4988b6" /><rect x="45.106849315068494" y="94.01847875335687" width="3.4438356164383563" height="15.98152124664312" fill="#0000ff" /><rect x="45.106849315068494" y="80.77239641222212" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="48.55068493150685" y="83.92990481470797" width="3.4438356164383563" height="26.07009518529203" fill="#4988b6" /><rect x="48.55068493150685" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210702" fill="#0000ff" /><rect x="48.55068493150685" y="83.92990481470798" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="51.99452054794521" y="86.53025348152458" width="3.4438356164383563" height="23.46974651847542" fill="#4988b6" /><rect x="51.99452054794521" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716144" fill="#0000ff" /><rect x="51.99452054794521" y="86.53025348152458" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="55.43835616438356" y="88.54932988924747" width="3.4438356164383563" height="21.45067011075253" fill="#4988b6" /><rect x="55.43835616438356" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671206" fill="#0000ff" /><rect x="55.43835616438356" y="88.54932988924747" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="58.88219178082192" y="89.97608994719877" width="3.4438356164383563" height="20.023910052801227" fill="#4988b6" /><rect x="58.88219178082192" y="103.22217228833352" width="3.4438356164383563" height="6.777827711666475" fill="#0000ff" /><rect x="58.88219178082192" y="89.97608994719877" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="62.326027397260276" y="90.81251071874951" width="3.4438356164383563" height="19.187489281250485" fill="#4988b6" /><rect x="62.326027397260276" y="104.9788941361316" width="3.4438356164383563" height="5.021105863868406" fill="#0000ff" /><rect x="62.326027397260276" y="90.81251071874952" width="3.4438356164383563" height="14.166383417382079" fill="#ff0000" /><rect x="65.76986301369863" y="91.07318537240724" width="3.4438356164383563" height="18.926814627592755" fill="#4988b6" /><rect x="65.76986301369863" y="106.48859908372359" width="3.4438356164383563" height="3.5114009162764113" fill="#0000ff" /><rect x="65.76986301369863" y="91.07318537240724" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="69.21369863013699" y="90.7845752953774" width="3.4438356164383563" height="19.21542470462261" fill="#4988b6" /><rect x="69.21369863013699" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264337" fill="#0000ff" /><rect x="69.21369863013699" y="90.7845752953774" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="72.65753424657535" y="89.9839444110289" width="3.4438356164383563" height="20.0160555889711" fill="#4988b6" /><rect x="72.65753424657535" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321904" fill="#0000ff" /><rect x="72.65753424657535" y="89.9839444110289" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="76.1013698630137" y="88.71801007193015" width="3.4438356164383563" height="21.281989928069848" fill="#4988b6" /><rect x="76.1013698630137" y="89.2873857788963" width="3.4438356164383563" height="20.7126142211037" fill="#ff0000" /><rect x="79.54520547945205" y="87.0413531708347" width="3.4438356164383563" height="22.95864682916531" fill="#4988b6" /><rect x="79.54520547945205" y="87.18396844466305" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="82.98904109589041" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#4988b6" /><rect x="82.98904109589041" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="86.43287671232878" y="82.7026904304715" width="3.4438356164383563" height="27.2973095695285" fill="#4988b6" /><rect x="86.43287671232878" y="82.84530570429986" width="3.4438356164383563" height="27.15469429570014" fill="#ff0000" /><rect x="89.87671232876713" y="80.17251266310045" width="3.4438356164383563" height="29.82748733689955" fill="#4988b6" /><rect x="89.87671232876713" y="80.74188837006659" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="93.32054794520548" y="77.49126294826962" width="3.4438356164383563" height="32.50873705173037" fill="#4988b6" /><rect x="93.32054794520548" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321815" fill="#0000ff" /><rect x="93.32054794520548" y="77.49126294826962" width="3.4438356164383563" height="31.23170365689819" fill="#ff0000" /><rect x="96.76438356164384" y="74.72429358333264" width="3.4438356164383563" height="35.27570641666736" fill="#4988b6" /><rect x="96.76438356164384" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264293" fill="#0000ff" /><rect x="96.76438356164384" y="74.72429358333264" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="100.2082191780822" y="71.93328694400283" width="3.4438356164383563" height="38.06671305599717" fill="#4988b6" /><rect x="100.2082191780822" y="106.4885990837236" width="3.4438356164383563" height="3.511400916276407" fill="#0000ff" /><rect x="100.2082191780822" y="71.93328694400284" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="103.65205479452055" y="69.17455170247656" width="3.4438356164383563" height="40.82544829752344" fill="#4988b6" /><rect x="103.65205479452055" y="104.97889413613159" width="3.4438356164383563" height="5.021105863868411" fill="#0000ff" /><rect x="103.65205479452055" y="69.17455170247656" width="3.4438356164383563" height="35.80434243365502" fill="#ff0000" /><rect x="107.0958904109589" y="66.49752877843119" width="3.4438356164383563" height="43.50247122156881" fill="#4988b6" /><rect x="107.0958904109589" y="103.22217228833354" width="3.4438356164383563" height="6.777827711666462" fill="#0000ff" /><rect x="107.0958904109589" y="66.49752877843119" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="110.53972602739726" y="63.943550768373015" width="3.4438356164383563" height="46.056449231626985" fill="#4988b6" /><rect x="110.53972602739726" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671203" fill="#0000ff" /><rect x="110.53972602739726" y="63.943550768373015" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="113.98356164383563" y="61.54489055600603" width="3.4438356164383563" height="48.45510944399397" fill="#4988b6" /><rect x="113.98356164383563" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716137" fill="#0000ff" /><rect x="113.98356164383563" y="61.54489055600603" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="117.42739726027398" y="59.324125693833516" width="3.4438356164383563" height="50.675874306166484" fill="#4988b6" /><rect x="117.42739726027398" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210699" fill="#0000ff" /><rect x="117.42739726027398" y="59.32412569383352" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="120.87123287671233" y="57.293835243454545" width="3.4438356164383563" height="52.706164756545455" fill="#4988b6" /><rect x="120.87123287671233" y="94.0184787533569" width="3.4438356164383563" height="15.9815212466431" fill="#0000ff" /><rect x="120.87123287671233" y="57.29383524345455" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="124.31506849315069" y="55.45663537220607" width="3.4438356164383563" height="54.54336462779393" fill="#4988b6" /><rect x="124.31506849315069" y="91.2609778058611" width="3.4438356164383563" height="18.739022194138897" fill="#0000ff" /><rect x="124.31506849315069" y="55.45663537220607" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="127.75890410958905" y="53.805549444816165" width="3.4438356164383563" height="56.194450555183835" fill="#4988b6" /><rect x="127.75890410958905" y="88.36086158453693" width="3.4438356164383563" height="21.639138415463062" fill="#0000ff" /><rect x="127.75890410958905" y="53.805549444816165" width="3.4438356164383563" height="34.55531213972077" fill="#ff0000" /><rect x="131.2027397260274" y="52.32469794342581" width="3.4438356164383563" height="57.67530205657419" fill="#4988b6" /><rect x="131.2027397260274" y="85.34020172496675" width="3.4438356164383563" height="24.659798275033253" fill="#0000ff" /><rect x="131.2027397260274" y="52.32469794342581" width="3.4438356164383563" height="33.015503781540936" fill="#ff0000" /><rect x="134.64657534246575" y="50.990283615707924" width="3.4438356164383563" height="59.009716384292076" fill="#4988b6" /><rect x="134.64657534246575" y="82.22198727260611" width="3.4438356164383563" height="27.778012727393882" fill="#0000ff" /><rect x="134.64657534246575" y="50.990283615707924" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="138.0904109589041" y="49.77183809233353" width="3.4438356164383563" height="60.22816190766647" fill="#4988b6" /><rect x="138.0904109589041" y="79.02994972226693" width="3.4438356164383563" height="30.97005027773306" fill="#0000ff" /><rect x="138.0904109589041" y="49.771838092333525" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="141.53424657534248" y="48.633688111412084" width="3.4438356164383563" height="61.366311888587916" fill="#4988b6" /><rect x="141.53424657534248" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="141.53424657534248" y="48.63368811141209" width="3.4438356164383563" height="27.154694295700146" fill="#ff0000" /><rect x="144.97808219178083" y="47.536592686203626" width="3.4438356164383563" height="62.463407313796374" fill="#4988b6" /><rect x="144.97808219178083" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827782" fill="#0000ff" /><rect x="144.97808219178083" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="148.42191780821918" y="46.43949726099517" width="3.4438356164383563" height="63.56050273900483" fill="#4988b6" /><rect x="148.42191780821918" y="69.25552881633213" width="3.4438356164383563" height="40.74447118366787" fill="#0000ff" /><rect x="148.42191780821918" y="46.43949726099517" width="3.4438356164383563" height="22.816031555336963" fill="#ff0000" /><rect x="151.86575342465756" y="45.30134728007371" width="3.4438356164383563" height="64.69865271992629" fill="#4988b6" /><rect x="151.86575342465756" y="66.01396150117742" width="3.4438356164383563" height="43.98603849882259" fill="#0000ff" /><rect x="151.86575342465756" y="45.30134728007371" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="155.3095890410959" y="44.082901756699286" width="3.4438356164383563" height="65.91709824330071" fill="#4988b6" /><rect x="155.3095890410959" y="62.821923950838205" width="3.4438356164383563" height="47.178076049161795" fill="#0000ff" /><rect x="155.3095890410959" y="44.082901756699286" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="158.75342465753425" y="42.74848742898146" width="3.4438356164383563" height="67.25151257101854" fill="#4988b6" /><rect x="158.75342465753425" y="59.703709498477636" width="3.4438356164383563" height="50.296290501522364" fill="#0000ff" /><rect x="158.75342465753425" y="42.74848742898146" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="162.1972602739726" y="41.26763592759107" width="3.4438356164383563" height="68.73236407240893" fill="#4988b6" /><rect x="162.1972602739726" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="162.1972602739726" y="41.267635927591066" width="3.4438356164383563" height="15.415413711316345" fill="#ff0000" /><rect x="165.64109589041095" y="39.61655000020117" width="3.4438356164383563" height="70.38344999979883" fill="#4988b6" /><rect x="165.64109589041095" y="53.78293341758326" width="3.4438356164383563" height="56.21706658241674" fill="#0000ff" /><rect x="165.64109589041095" y="39.61655000020118" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="169.08493150684933" y="37.7793501289527" width="3.4438356164383563" height="72.2206498710473" fill="#4988b6" /><rect x="169.08493150684933" y="51.02543247008746" width="3.4438356164383563" height="58.97456752991254" fill="#0000ff" /><rect x="169.08493150684933" y="37.7793501289527" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="172.52876712328768" y="35.749059678573715" width="3.4438356164383563" height="74.25094032142628" fill="#4988b6" /><rect x="172.52876712328768" y="48.43153304365505" width="3.4438356164383563" height="61.56846695634495" fill="#0000ff" /><rect x="172.52876712328768" y="35.74905967857372" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="175.97260273972603" y="33.528294816401214" width="3.4438356164383563" height="76.47170518359879" fill="#4988b6" /><rect x="175.97260273972603" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="175.97260273972603" y="33.528294816401214" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="179.4164383561644" y="31.129634604034223" width="3.4438356164383563" height="78.87036539596578" fill="#4988b6" /><rect x="179.4164383561644" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="179.4164383561644" y="31.12963460403422" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="182.86027397260276" y="28.575656593976063" width="3.4438356164383563" height="81.42434340602394" fill="#4988b6" /><rect x="182.86027397260276" y="41.821738935110815" width="3.4438356164383563" height="68.17826106488918" fill="#0000ff" /><rect x="182.86027397260276" y="28.575656593976063" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="186.3041095890411" y="25.898633669930675" width="3.4438356164383563" height="84.10136633006933" fill="#4988b6" /><rect x="186.3041095890411" y="40.065017087312754" width="3.4438356164383563" height="69.93498291268725" fill="#0000ff" /><rect x="186.3041095890411" y="25.898633669930675" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="189.74794520547945" y="23.139898428404408" width="3.4438356164383563" height="86.86010157159559" fill="#4988b6" /><rect x="189.74794520547945" y="38.55531213972077" width="3.4438356164383563" height="71.44468786027923" fill="#0000ff" /><rect x="189.74794520547945" y="23.139898428404425" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="193.1917808219178" y="20.348891789074585" width="3.4438356164383563" height="89.65110821092541" fill="#4988b6" /><rect x="193.1917808219178" y="37.30411385857076" width="3.4438356164383563" height="72.69588614142924" fill="#0000ff" /><rect x="193.1917808219178" y="20.34889178907458" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="196.63561643835618" y="17.581922424137616" width="3.4438356164383563" height="92.41807757586238" fill="#4988b6" /><rect x="196.63561643835618" y="36.32094461827654" width="3.4438356164383563" height="73.67905538172346" fill="#0000ff" /><rect x="196.63561643835618" y="17.581922424137634" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="200.07945205479453" y="14.900672709306775" width="3.4438356164383563" height="95.09932729069322" fill="#4988b6" /><rect x="200.07945205479453" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="200.07945205479453" y="14.900672709306775" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="203.52328767123288" y="12.370494941935746" width="3.4438356164383563" height="97.62950505806425" fill="#4988b6" /><rect x="203.52328767123288" y="35.18652649727271" width="3.4438356164383563" height="74.81347350272729" fill="#0000ff" /><rect x="203.52328767123288" y="12.370494941935757" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="206.96712328767126" y="10.058548297925782" width="3.4438356164383563" height="99.94145170207422" fill="#4988b6" /><rect x="206.96712328767126" y="35.043911223444326" width="3.4438356164383563" height="74.95608877655567" fill="#0000ff" /><rect x="206.96712328767126" y="10.058548297925771" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="210.4109589041096" y="8.031832201572541" width="3.4438356164383563" height="101.96816779842746" fill="#4988b6" /><rect x="210.4109589041096" y="35.186526497272695" width="3.4438356164383563" height="74.8134735027273" fill="#0000ff" /><rect x="210.4109589041096" y="8.031832201572545" width="3.4438356164383563" height="27.15469429570015" fill="#ff0000" /><rect x="213.85479452054796" y="6.355175300477072" width="3.4438356164383563" height="103.64482469952293" fill="#4988b6" /><rect x="213.85479452054796" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="213.85479452054796" y="6.355175300477075" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="217.2986301369863" y="5.089240961378337" width="3.4438356164383563" height="104.91075903862166" fill="#4988b6" /><rect x="217.2986301369863" y="36.32094461827653" width="3.4438356164383563" height="73.67905538172347" fill="#0000ff" /><rect x="217.2986301369863" y="5.089240961378341" width="3.4438356164383563" height="31.231703656898187" fill="#ff0000" /><rect x="220.74246575342465" y="4.28861007702983" width="3.4438356164383563" height="105.71138992297017" fill="#4988b6" /><rect x="220.74246575342465" y="37.30411385857077" width="3.4438356164383563" height="72.69588614142923" fill="#0000ff" /><rect x="220.74246575342465" y="4.288610077029844" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="224.18630136986303" y="4.0" width="3.4438356164383563" height="106.0" fill="#4988b6" /><rect x="224.18630136986303" y="38.555312139720755" width="3.4438356164383563" height="71.44468786027925" fill="#0000ff" /><rect x="224.18630136986303" y="3.999999999999993" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="227.63013698630138" y="4.260674653657716" width="3.4438356164383563" height="105.73932534634228" fill="#4988b6" /><rect x="227.63013698630138" y="40.06501708731274" width="3.4438356164383563" height="69.93498291268726" fill="#0000ff" /><rect x="227.63013698630138" y="4.260674653657709" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="231.07397260273973" y="5.097095425208451" width="3.4438356164383563" height="104.90290457479155" fill="#4988b6" /><rect x="231.07397260273973" y="41.8217389351108" width="3.4438356164383563" height="68.1782610648892" fill="#0000ff" /><rect x="231.07397260273973" y="5.097095425208451" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="234.5178082191781" y="6.523855483159764" width="3.4438356164383563" height="103.47614451684024" fill="#4988b6" /><rect x="234.5178082191781" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="234.5178082191781" y="6.523855483159764" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="237.96164383561646" y="8.542931890882656" width="3.4438356164383563" height="101.45706810911734" fill="#4988b6" /><rect x="237.96164383561646" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="237.96164383561646" y="8.542931890882663" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="241.4054794520548" y="11.143280557699256" width="3.4438356164383563" height="98.85671944230074" fill="#4988b6" /><rect x="241.4054794520548" y="48.431533043655044" width="3.4438356164383563" height="61.568466956344956" fill="#0000ff" /><rect x="241.4054794520548" y="11.143280557699264" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="244.84931506849315" y="14.300788960185102" width="3.4438356164383563" height="95.6992110398149" fill="#4988b6" /><rect x="244.84931506849315" y="51.02543247008745" width="3.4438356164383563" height="58.97456752991255" fill="#0000ff" /><rect x="244.84931506849315" y="14.300788960185095" width="3.4438356164383563" height="36.72464350990236" fill="#ff0000" /><rect x="248.2931506849315" y="17.978590983928214" width="3.4438356164383563" height="92.02140901607179" fill="#4988b6" /><rect x="248.2931506849315" y="53.78293341758325" width="3.4438356164383563" height="56.21706658241675" fill="#0000ff" /><rect x="248.2931506849315" y="17.97859098392822" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="251.73698630136988" y="22.12773749918665" width="3.4438356164383563" height="87.87226250081335" fill="#4988b6" /><rect x="251.73698630136988" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="251.73698630136988" y="22.12773749918665" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="255.18082191780823" y="26.688205716936665" width="3.4438356164383563" height="83.31179428306334" fill="#4988b6" /><rect x="255.18082191780823" y="59.70370949847761" width="3.4438356164383563" height="50.29629050152239" fill="#0000ff" /><rect x="255.18082191780823" y="26.68820571693668" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="258.6246575342466" y="31.59022029394002" width="3.4438356164383563" height="78.40977970605998" fill="#4988b6" /><rect x="258.6246575342466" y="62.82192395083821" width="3.4438356164383563" height="47.17807604916179" fill="#0000ff" /><rect x="258.6246575342466" y="31.590220293940018" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="262.06849315068496" y="36.75584987124398" width="3.4438356164383563" height="73.24415012875602" fill="#4988b6" /><rect x="262.06849315068496" y="66.01396150117739" width="3.4438356164383563" height="43.9860384988226" fill="#0000ff" /><rect x="262.06849315068496" y="36.75584987124398" width="3.4438356164383563" height="29.25811162993341" fill="#ff0000" /><rect x="265.51232876712334" y="42.10083452063198" width="3.4438356164383563" height="67.89916547936802" fill="#4988b6" /><rect x="265.51232876712334" y="69.25552881633212" width="3.4438356164383563" height="40.74447118366788" fill="#0000ff" /><rect x="265.51232876712334" y="42.10083452063198" width="3.4438356164383563" height="27.154694295700143" fill="#ff0000" /><rect x="268.95616438356166" y="47.53659268620362" width="3.4438356164383563" height="62.46340731379638" fill="#4988b6" /><rect x="268.95616438356166" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827783" fill="#0000ff" /><rect x="268.95616438356166" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="272.4" y="52.97235085177527" width="3.4438356164383563" height="57.02764914822473" fill="#4988b6" /><rect x="272.4" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="272.4" y="52.972350851775275" width="3.4438356164383563" height="22.81603155533696" fill="#ff0000" /><rect x="275.84383561643835" y="58.317335501163235" width="3.4438356164383563" height="51.682664498836765" fill="#4988b6" /><rect x="275.84383561643835" y="79.02994972226693" width="3.4438356164383563" height="30.970050277733062" fill="#0000ff" /><rect x="275.84383561643835" y="58.31733550116323" width="3.4438356164383563" height="20.712614221103703" fill="#ff0000" /><rect x="279.28767123287673" y="63.48296507846722" width="3.4438356164383563" height="46.51703492153278" fill="#4988b6" /><rect x="279.28767123287673" y="82.22198727260613" width="3.4438356164383563" height="27.778012727393868" fill="#0000ff" /><rect x="279.28767123287673" y="63.48296507846722" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="282.7315068493151" y="68.38497965547054" width="3.4438356164383563" height="41.615020344529455" fill="#4988b6" /><rect x="282.7315068493151" y="85.34020172496673" width="3.4438356164383563" height="24.659798275033275" fill="#0000ff" /><rect x="282.7315068493151" y="68.38497965547054" width="3.4438356164383563" height="16.95522206949618" fill="#ff0000" /><rect x="286.17534246575343" y="72.94544787322057" width="3.4438356164383563" height="37.05455212677943" fill="#4988b6" /><rect x="286.17534246575343" y="88.3608615845369" width="3.4438356164383563" height="21.639138415463087" fill="#0000ff" /><rect x="286.17534246575343" y="72.94544787322056" width="3.4438356164383563" height="15.415413711316347" fill="#ff0000" /><rect x="289.6191780821918" y="77.094594388479" width="3.4438356164383563" height="32.905405611521005" fill="#4988b6" /><rect x="289.6191780821918" y="91.26097780586107" width="3.4438356164383563" height="18.739022194138922" fill="#0000ff" /><rect x="289.6191780821918" y="77.094594388479" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="293.06301369863013" y="80.77239641222212" width="3.4438356164383563" height="29.227603587777875" fill="#4988b6" /><rect x="293.06301369863013" y="94.01847875335687" width="3.4438356164383563" height="15.98152124664312" fill="#0000ff" /><rect x="293.06301369863013" y="80.77239641222212" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="296.5068493150685" y="83.92990481470797" width="3.4438356164383563" height="26.07009518529203" fill="#4988b6" /><rect x="296.5068493150685" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210702" fill="#0000ff" /><rect x="296.5068493150685" y="83.92990481470798" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="299.9506849315069" y="86.53025348152458" width="3.4438356164383563" height="23.46974651847542" fill="#4988b6" /><rect x="299.9506849315069" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716144" fill="#0000ff" /><rect x="299.9506849315069" y="86.53025348152458" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="303.3945205479452" y="88.54932988924747" width="3.4438356164383563" height="21.45067011075253" fill="#4988b6" /><rect x="303.3945205479452" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671206" fill="#0000ff" /><rect x="303.3945205479452" y="88.54932988924747" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="306.8383561643836" y="89.97608994719877" width="3.4438356164383563" height="20.023910052801227" fill="#4988b6" /><rect x="306.8383561643836" y="103.22217228833352" width="3.4438356164383563" height="6.777827711666475" fill="#0000ff" /><rect x="306.8383561643836" y="89.97608994719877" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="310.2821917808219" y="90.81251071874951" width="3.4438356164383563" height="19.187489281250485" fill="#4988b6" /><rect x="310.2821917808219" y="104.9788941361316" width="3.4438356164383563" height="5.021105863868406" fill="#0000ff" /><rect x="310.2821917808219" y="90.81251071874952" width="3.4438356164383563" height="14.166383417382079" fill="#ff0000" /><rect x="313.7260273972603" y="91.07318537240724" width="3.4438356164383563" height="18.926814627592755" fill="#4988b6" /><rect x="313.7260273972603" y="106.48859908372359" width="3.4438356164383563" height="3.5114009162764113" fill="#0000ff" /><rect x="313.7260273972603" y="91.07318537240724" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="317.16986301369866" y="90.7845752953774" width="3.4438356164383563" height="19.21542470462261" fill="#4988b6" /><rect x="317.16986301369866" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264337" fill="#0000ff" /><rect x="317.16986301369866" y="90.7845752953774" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="320.613698630137" y="89.9839444110289" width="3.4438356164383563" height="20.0160555889711" fill="#4988b6" /><rect x="320.613698630137" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321904" fill="#0000ff" /><rect x="320.613698630137" y="89.9839444110289" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="324.05753424657536" y="88.71801007193015" width="3.4438356164383563" height="21.281989928069848" fill="#4988b6" /><rect x="324.05753424657536" y="89.2873857788963" width="3.4438356164383563" height="20.7126142211037" fill="#ff0000" /><rect x="327.50136986301374" y="87.0413531708347" width="3.4438356164383563" height="22.95864682916531" fill="#4988b6" /><rect x="327.50136986301374" y="87.18396844466305" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="330.94520547945206" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#4988b6" /><rect x="330.94520547945206" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="334.38904109589043" y="82.7026904304715" width="3.4438356164383563" height="27.2973095695285" fill="#4988b6" /><rect x="334.38904109589043" y="82.84530570429986" width="3.4438356164383563" height="27.15469429570014" fill="#ff0000" /><rect x="337.8328767123288" y="80.17251266310045" width="3.4438356164383563" height="29.82748733689955" fill="#4988b6" /><rect x="337.8328767123288" y="80.74188837006659" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="341.27671232876713" y="77.49126294826962" width="3.4438356164383563" height="32.50873705173037" fill="#4988b6" /><rect x="341.27671232876713" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321815" fill="#0000ff" /><rect x="341.27671232876713" y="77.49126294826962" width="3.4438356164383563" height="31.23170365689819" fill="#ff0000" /><rect x="344.7205479452055" y="74.72429358333264" width="3.4438356164383563" height="35.27570641666736" fill="#4988b6" /><rect x="344.7205479452055" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264293" fill="#0000ff" /><rect x="344.7205479452055" y="74.72429358333264" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="348.16438356164383" y="71.93328694400283" width="3.4438356164383563" height="38.06671305599717" fill="#4988b6" /><rect x="348.16438356164383" y="106.4885990837236" width="3.4438356164383563" height="3.511400916276407" fill="#0000ff" /><rect x="348.16438356164383" y="71.93328694400284" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="351.6082191780822" y="69.17455170247656" width="3.4438356164383563" height="40.82544829752344" fill="#4988b6" /><rect x="351.6082191780822" y="104.97889413613159" width="3.4438356164383563" height="5.021105863868411" fill="#0000ff" /><rect x="351.6082191780822" y="69.17455170247656" width="3.4438356164383563" height="35.80434243365502" fill="#ff0000" /><rect x="355.0520547945206" y="66.49752877843119" width="3.4438356164383563" height="43.50247122156881" fill="#4988b6" /><rect x="355.0520547945206" y="103.22217228833354" width="3.4438356164383563" height="6.777827711666462" fill="#0000ff" /><rect x="355.0520547945206" y="66.49752877843119" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="358.4958904109589" y="63.943550768373015" width="3.4438356164383563" height="46.056449231626985" fill="#4988b6" /><rect x="358.4958904109589" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671203" fill="#0000ff" /><rect x="358.4958904109589" y="63.943550768373015" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="361.9397260273973" y="61.54489055600603" width="3.4438356164383563" height="48.45510944399397" fill="#4988b6" /><rect x="361.9397260273973" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716137" fill="#0000ff" /><rect x="361.9397260273973" y="61.54489055600603" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="365.3835616438356" y="59.324125693833516" width="3.4438356164383563" height="50.675874306166484" fill="#4988b6" /><rect x="365.3835616438356" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210699" fill="#0000ff" /><rect x="365.3835616438356" y="59.32412569383352" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="368.827397260274" y="57.293835243454545" width="3.4438356164383563" height="52.706164756545455" fill="#4988b6" /><rect x="368.827397260274" y="94.0184787533569" width="3.4438356164383563" height="15.9815212466431" fill="#0000ff" /><rect x="368.827397260274" y="57.29383524345455" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="372.27123287671236" y="55.45663537220607" width="3.4438356164383563" height="54.54336462779393" fill="#4988b6" /><rect x="372.27123287671236" y="91.2609778058611" width="3.4438356164383563" height="18.739022194138897" fill="#0000ff" /><rect x="372.27123287671236" y="55.45663537220607" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="375.7150684931507" y="53.805549444816165" width="3.4438356164383563" height="56.194450555183835" fill="#4988b6" /><rect x="375.7150684931507" y="88.36086158453693" width="3.4438356164383563" height="21.639138415463062" fill="#0000ff" /><rect x="375.7150684931507" y="53.805549444816165" width="3.4438356164383563" height="34.55531213972077" fill="#ff0000" /><rect x="379.15890410958906" y="52.32469794342581" width="3.4438356164383563" height="57.67530205657419" fill="#4988b6" /><rect x="379.15890410958906" y="85.34020172496675" width="3.4438356164383563" height="24.659798275033253" fill="#0000ff" /><rect x="379.15890410958906" y="52.32469794342581" width="3.4438356164383563" height="33.015503781540936" fill="#ff0000" /><rect x="382.60273972602744" y="50.990283615707924" width="3.4438356164383563" height="59.009716384292076" fill="#4988b6" /><rect x="382.60273972602744" y="82.22198727260611" width="3.4438356164383563" height="27.778012727393882" fill="#0000ff" /><rect x="382.60273972602744" y="50.990283615707924" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="386.04657534246576" y="49.77183809233353" width="3.4438356164383563" height="60.22816190766647" fill="#4988b6" /><rect x="386.04657534246576" y="79.02994972226693" width="3.4438356164383563" height="30.97005027773306" fill="#0000ff" /><rect x="386.04657534246576" y="49.771838092333525" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="389.49041095890414" y="48.633688111412084" width="3.4438356164383563" height="61.366311888587916" fill="#4988b6" /><rect x="389.49041095890414" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="389.49041095890414" y="48.63368811141209" width="3.4438356164383563" height="27.154694295700146" fill="#ff0000" /><rect x="392.9342465753425" y="47.536592686203626" width="3.4438356164383563" height="62.463407313796374" fill="#4988b6" /><rect x="392.9342465753425" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827782" fill="#0000ff" /><rect x="392.9342465753425" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="396.37808219178083" y="46.43949726099517" width="3.4438356164383563" height="63.56050273900483" fill="#4988b6" /><rect x="396.37808219178083" y="69.25552881633213" width="3.4438356164383563" height="40.74447118366787" fill="#0000ff" /><rect x="396.37808219178083" y="46.43949726099517" width="3.4438356164383563" height="22.816031555336963" fill="#ff0000" /><rect x="399.8219178082192" y="45.30134728007371" width="3.4438356164383563" height="64.69865271992629" fill="#4988b6" /><rect x="399.8219178082192" y="66.01396150117742" width="3.4438356164383563" height="43.98603849882259" fill="#0000ff" /><rect x="399.8219178082192" y="45.30134728007371" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="403.26575342465753" y="44.082901756699286" width="3.4438356164383563" height="65.91709824330071" fill="#4988b6" /><rect x="403.26575342465753" y="62.821923950838205" width="3.4438356164383563" height="47.178076049161795" fill="#0000ff" /><rect x="403.26575342465753" y="44.082901756699286" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="406.7095890410959" y="42.74848742898146" width="3.4438356164383563" height="67.25151257101854" fill="#4988b6" /><rect x="406.7095890410959" y="59.703709498477636" width="3.4438356164383563" height="50.296290501522364" fill="#0000ff" /><rect x="406.7095890410959" y="42.74848742898146" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="410.1534246575343" y="41.26763592759107" width="3.4438356164383563" height="68.73236407240893" fill="#4988b6" /><rect x="410.1534246575343" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="410.1534246575343" y="41.267635927591066" width="3.4438356164383563" height="15.415413711316345" fill="#ff0000" /><rect x="413.5972602739726" y="39.61655000020117" width="3.4438356164383563" height="70.38344999979883" fill="#4988b6" /><rect x="413.5972602739726" y="53.78293341758326" width="3.4438356164383563" height="56.21706658241674" fill="#0000ff" /><rect x="413.5972602739726" y="39.61655000020118" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="417.041095890411" y="37.7793501289527" width="3.4438356164383563" height="72.2206498710473" fill="#4988b6" /><rect x="417.041095890411" y="51.02543247008746" width="3.4438356164383563" height="58.97456752991254" fill="#0000ff" /><rect x="417.041095890411" y="37.7793501289527" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="420.4849315068493" y="35.749059678573715" width="3.4438356164383563" height="74.25094032142628" fill="#4988b6" /><rect x="420.4849315068493" y="48.43153304365505" width="3.4438356164383563" height="61.56846695634495" fill="#0000ff" /><rect x="420.4849315068493" y="35.74905967857372" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="423.9287671232877" y="33.528294816401214" width="3.4438356164383563" height="76.47170518359879" fill="#4988b6" /><rect x="423.9287671232877" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="423.9287671232877" y="33.528294816401214" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="427.37260273972606" y="31.129634604034223" width="3.4438356164383563" height="78.87036539596578" fill="#4988b6" /><rect x="427.37260273972606" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="427.37260273972606" y="31.12963460403422" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="430.8164383561644" y="28.575656593976063" width="3.4438356164383563" height="81.42434340602394" fill="#4988b6" /><rect x="430.8164383561644" y="41.821738935110815" width="3.4438356164383563" height="68.17826106488918" fill="#0000ff" /><rect x="430.8164383561644" y="28.575656593976063" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="434.26027397260276" y="25.898633669930675" width="3.4438356164383563" height="84.10136633006933" fill="#4988b6" /><rect x="434.26027397260276" y="40.065017087312754" width="3.4438356164383563" height="69.93498291268725" fill="#0000ff" /><rect x="434.26027397260276" y="25.898633669930675" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="437.70410958904114" y="23.139898428404408" width="3.4438356164383563" height="86.86010157159559" fill="#4988b6" /><rect x="437.70410958904114" y="38.55531213972077" width="3.4438356164383563" height="71.44468786027923" fill="#0000ff" /><rect x="437.70410958904114" y="23.139898428404425" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="441.14794520547946" y="20.348891789074585" width="3.4438356164383563" height="89.65110821092541" fill="#4988b6" /><rect x="441.14794520547946" y="37.30411385857076" width="3.4438356164383563" height="72.69588614142924" fill="#0000ff" /><rect x="441.14794520547946" y="20.34889178907458" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="444.59178082191784" y="17.581922424137616" width="3.4438356164383563" height="92.41807757586238" fill="#4988b6" /><rect x="444.59178082191784" y="36.32094461827654" width="3.4438356164383563" height="73.67905538172346" fill="#0000ff" /><rect x="444.59178082191784" y="17.581922424137634" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="448.0356164383562" y="14.900672709306775" width="3.4438356164383563" height="95.09932729069322" fill="#4988b6" /><rect x="448.0356164383562" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="448.0356164383562" y="14.900672709306775" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="451.47945205479454" y="12.370494941935746" width="3.4438356164383563" height="97.62950505806425" fill="#4988b6" /><rect x="451.47945205479454" y="35.18652649727271" width="3.4438356164383563" height="74.81347350272729" fill="#0000ff" /><rect x="451.47945205479454" y="12.370494941935757" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="454.9232876712329" y="10.058548297925782" width="3.4438356164383563" height="99.94145170207422" fill="#4988b6" /><rect x="454.9232876712329" y="35.043911223444326" width="3.4438356164383563" height="74.95608877655567" fill="#0000ff" /><rect x="454.9232876712329" y="10.058548297925771" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="458.36712328767123" y="8.031832201572541" width="3.4438356164383563" height="101.96816779842746" fill="#4988b6" /><rect x="458.36712328767123" y="35.186526497272695" width="3.4438356164383563" height="74.8134735027273" fill="#0000ff" /><rect x="458.36712328767123" y="8.031832201572545" width="3.4438356164383563" height="27.15469429570015" fill="#ff0000" /><rect x="461.8109589041096" y="6.355175300477072" width="3.4438356164383563" height="103.64482469952293" fill="#4988b6" /><rect x="461.8109589041096" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="461.8109589041096" y="6.355175300477075" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="465.254794520548" y="5.089240961378337" width="3.4438356164383563" height="104.91075903862166" fill="#4988b6" /><rect x="465.254794520548" y="36.32094461827653" width="3.4438356164383563" height="73.67905538172347" fill="#0000ff" /><rect x="465.254794520548" y="5.089240961378341" width="3.4438356164383563" height="31.231703656898187" fill="#ff0000" /><rect x="468.6986301369863" y="4.28861007702983" width="3.4438356164383563" height="105.71138992297017" fill="#4988b6" /><rect x="468.6986301369863" y="37.30411385857077" width="3.4438356164383563" height="72.69588614142923" fill="#0000ff" /><rect x="468.6986301369863" y="4.288610077029844" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="472.1424657534247" y="4.0" width="3.4438356164383563" height="106.0" fill="#4988b6" /><rect x="472.1424657534247" y="38.555312139720755" width="3.4438356164383563" height="71.44468786027925" fill="#0000ff" /><rect x="472.1424657534247" y="3.999999999999993" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="475.586301369863" y="4.260674653657716" width="3.4438356164383563" height="105.73932534634228" fill="#4988b6" /><rect x="475.586301369863" y="40.06501708731274" width="3.4438356164383563" height="69.93498291268726" fill="#0000ff" /><rect x="475.586301369863" y="4.260674653657709" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="479.0301369863014" y="5.097095425208451" width="3.4438356164383563" height="104.90290457479155" fill="#4988b6" /><rect x="479.0301369863014" y="41.8217389351108" width="3.4438356164383563" height="68.1782610648892" fill="#0000ff" /><rect x="479.0301369863014" y="5.097095425208451" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="482.47397260273976" y="6.523855483159764" width="3.4438356164383563" height="103.47614451684024" fill="#4988b6" /><rect x="482.47397260273976" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="482.47397260273976" y="6.523855483159764" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="485.9178082191781" y="8.542931890882656" width="3.4438356164383563" height="101.45706810911734" fill="#4988b6" /><rect x="485.9178082191781" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="485.9178082191781" y="8.542931890882663" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="489.36164383561646" y="11.143280557699256" width="3.4438356164383563" height="98.85671944230074" fill="#4988b6" /><rect x="489.36164383561646" y="48.431533043655044" width="3.4438356164383563" height="61.568466956344956" fill="#0000ff" /><rect x="489.36164383561646" y="11.143280557699264" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="492.80547945205484" y="14.300788960185102" width="3.4438356164383563" height="95.6992110398149" fill="#4988b6" /><rect x="492.80547945205484" y="51.02543247008745" width="3.4438356164383563" height="58.97456752991255" fill="#0000ff" /><rect x="492.80547945205484" y="14.300788960185095" width="3.4438356164383563" height="36.72464350990236" fill="#ff0000" /><rect x="496.24931506849316" y="17.978590983928214" width="3.4438356164383563" height="92.02140901607179" fill="#4988b6" /><rect x="496.24931506849316" y="53.78293341758325" width="3.4438356164383563" height="56.21706658241675" fill="#0000ff" /><rect x="496.24931506849316" y="17.97859098392822" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="499.69315068493154" y="22.12773749918665" width="3.4438356164383563" height="87.87226250081335" fill="#4988b6" /><rect x="499.69315068493154" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="499.69315068493154" y="22.12773749918665" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="503.1369863013699" y="26.688205716936665" width="3.4438356164383563" height="83.31179428306334" fill="#4988b6" /><rect x="503.1369863013699" y="59.70370949847761" width="3.4438356164383563" height="50.29629050152239" fill="#0000ff" /><rect x="503.1369863013699" y="26.68820571693668" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="506.58082191780824" y="31.59022029394002" width="3.4438356164383563" height="78.40977970605998" fill="#4988b6" /><rect x="506.58082191780824" y="62.82192395083821" width="3.4438356164383563" height="47.17807604916179" fill="#0000ff" /><rect x="506.58082191780824" y="31.590220293940018" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="510.0246575342466" y="36.75584987124398" width="3.4438356164383563" height="73.24415012875602" fill="#4988b6" /><rect x="510.0246575342466" y="66.01396150117739" width="3.4438356164383563" height="43.9860384988226" fill="#0000ff" /><rect x="510.0246575342466" y="36.75584987124398" width="3.4438356164383563" height="29.25811162993341" fill="#ff0000" /><rect x="513.4684931506849" y="42.10083452063198" width="3.4438356164383563" height="67.89916547936802" fill="#4988b6" /><rect x="513.4684931506849" y="69.25552881633212" width="3.4438356164383563" height="40.74447118366788" fill="#0000ff" /><rect x="513.4684931506849" y="42.10083452063198" width="3.4438356164383563" height="27.154694295700143" fill="#ff0000" /><rect x="516.9123287671233" y="47.53659268620362" width="3.4438356164383563" height="62.46340731379638" fill="#4988b6" /><rect x="516.9123287671233" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827783" fill="#0000ff" /><rect x="516.9123287671233" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="520.3561643835617" y="52.97235085177527" width="3.4438356164383563" height="57.02764914822473" fill="#4988b6" /><rect x="520.3561643835617" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="520.3561643835617" y="52.972350851775275" width="3.4438356164383563" height="22.81603155533696" fill="#ff0000" /><rect x="523.8" y="58.317335501163235" width="3.4438356164383563" height="51.682664498836765" fill="#4988b6" /><rect x="523.8" y="79.02994972226693" width="3.4438356164383563" height="30.970050277733062" fill="#0000ff" /><rect x="523.8" y="58.31733550116323" width="3.4438356164383563" height="20.712614221103703" fill="#ff0000" /><rect x="527.2438356164384" y="63.48296507846722" width="3.4438356164383563" height="46.51703492153278" fill="#4988b6" /><rect x="527.2438356164384" y="82.22198727260613" width="3.4438356164383563" height="27.778012727393868" fill="#0000ff" /><rect x="527.2438356164384" y="63.48296507846722" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="530.6876712328767" y="68.38497965547054" width="3.4438356164383563" height="41.615020344529455" fill="#4988b6" /><rect x="530.6876712328767" y="85.34020172496673" width="3.4438356164383563" height="24.659798275033275" fill="#0000ff" /><rect x="530.6876712328767" y="68.38497965547054" width="3.4438356164383563" height="16.95522206949618" fill="#ff0000" /><rect x="534.1315068493151" y="72.94544787322057" width="3.4438356164383563" height="37.05455212677943" fill="#4988b6" /><rect x="534.1315068493151" y="88.3608615845369" width="3.4438356164383563" height="21.639138415463087" fill="#0000ff" /><rect x="534.1315068493151" y="72.94544787322056" width="3.4438356164383563" height="15.415413711316347" fill="#ff0000" /><rect x="537.5753424657535" y="77.094594388479" width="3.4438356164383563" height="32.905405611521005" fill="#4988b6" /><rect x="537.5753424657535" y="91.26097780586107" width="3.4438356164383563" height="18.739022194138922" fill="#0000ff" /><rect x="537.5753424657535" y="77.094594388479" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="541.0191780821918" y="80.77239641222212" width="3.4438356164383563" height="29.227603587777875" fill="#4988b6" /><rect x="541.0191780821918" y="94.01847875335687" width="3.4438356164383563" height="15.98152124664312" fill="#0000ff" /><rect x="541.0191780821918" y="80.77239641222212" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="544.4630136986302" y="83.92990481470797" width="3.4438356164383563" height="26.07009518529203" fill="#4988b6" /><rect x="544.4630136986302" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210702" fill="#0000ff" /><rect x="544.4630136986302" y="83.92990481470798" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="547.9068493150685" y="86.53025348152458" width="3.4438356164383563" height="23.46974651847542" fill="#4988b6" /><rect x="547.9068493150685" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716144" fill="#0000ff" /><rect x="547.9068493150685" y="86.53025348152458" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="551.3506849315069" y="88.54932988924747" width="3.4438356164383563" height="21.45067011075253" fill="#4988b6" /><rect x="551.3506849315069" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671206" fill="#0000ff" /><rect x="551.3506849315069" y="88.54932988924747" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="554.7945205479452" y="89.97608994719877" width="3.4438356164383563" height="20.023910052801227" fill="#4988b6" /><rect x="554.7945205479452" y="103.22217228833352" width="3.4438356164383563" height="6.777827711666475" fill="#0000ff" /><rect x="554.7945205479452" y="89.97608994719877" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="558.2383561643836" y="90.81251071874951" width="3.4438356164383563" height="19.187489281250485" fill="#4988b6" /><rect x="558.2383561643836" y="104.9788941361316" width="3.4438356164383563" height="5.021105863868406" fill="#0000ff" /><rect x="558.2383561643836" y="90.81251071874952" width="3.4438356164383563" height="14.166383417382079" fill="#ff0000" /><rect x="561.682191780822" y="91.07318537240724" width="3.4438356164383563" height="18.926814627592755" fill="#4988b6" /><rect x="561.682191780822" y="106.48859908372359" width="3.4438356164383563" height="3.5114009162764113" fill="#0000ff" /><rect x="561.682191780822" y="91.07318537240724" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="565.1260273972603" y="90.7845752953774" width="3.4438356164383563" height="19.21542470462261" fill="#4988b6" /><rect x="565.1260273972603" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264337" fill="#0000ff" /><rect x="565.1260273972603" y="90.7845752953774" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="568.5698630136986" y="89.9839444110289" width="3.4438356164383563" height="20.0160555889711" fill="#4988b6" /><rect x="568.5698630136986" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321904" fill="#0000ff" /><rect x="568.5698630136986" y="89.9839444110289" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="572.013698630137" y="88.71801007193015" width="3.4438356164383563" height="21.281989928069848" fill="#4988b6" /><rect x="572.013698630137" y="89.2873857788963" width="3.4438356164383563" height="20.7126142211037" fill="#ff0000" /><rect x="575.4575342465754" y="87.0413531708347" width="3.4438356164383563" height="22.95864682916531" fill="#4988b6" /><rect x="575.4575342465754" y="87.18396844466305" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="578.9013698630138" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#4988b6" /><rect x="578.9013698630138" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="582.345205479452" y="82.7026904304715" width="3.4438356164383563" height="27.2973095695285" fill="#4988b6" /><rect x="582.345205479452" y="82.84530570429986" width="3.4438356164383563" height="27.15469429570014" fill="#ff0000" /><rect x="585.7890410958904" y="80.17251266310045" width="3.4438356164383563" height="29.82748733689955" fill="#4988b6" /><rect x="585.7890410958904" y="80.74188837006659" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="589.2328767123288" y="77.49126294826962" width="3.4438356164383563" height="32.50873705173037" fill="#4988b6" /><rect x="589.2328767123288" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321815" fill="#0000ff" /><rect x="589.2328767123288" y="77.49126294826962" width="3.4438356164383563" height="31.23170365689819" fill="#ff0000" /><rect x="592.6767123287672" y="74.72429358333264" width="3.4438356164383563" height="35.27570641666736" fill="#4988b6" /><rect x="592.6767123287672" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264293" fill="#0000ff" /><rect x="592.6767123287672" y="74.72429358333264" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="596.1205479452055" y="71.93328694400283" width="3.4438356164383563" height="38.06671305599717" fill="#4988b6" /><rect x="596.1205479452055" y="106.4885990837236" width="3.4438356164383563" height="3.511400916276407" fill="#0000ff" /><rect x="596.1205479452055" y="71.93328694400284" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="599.5643835616438" y="69.17455170247656" width="3.4438356164383563" height="40.82544829752344" fill="#4988b6" /><rect x="599.5643835616438" y="104.97889413613159" width="3.4438356164383563" height="5.021105863868411" fill="#0000ff" /><rect x="599.5643835616438" y="69.17455170247656" width="3.4438356164383563" height="35.80434243365502" fill="#ff0000" /><rect x="603.0082191780822" y="66.49752877843119" width="3.4438356164383563" height="43.50247122156881" fill="#4988b6" /><rect x="603.0082191780822" y="103.22217228833354" width="3.4438356164383563" height="6.777827711666462" fill="#0000ff" /><rect x="603.0082191780822" y="66.49752877843119" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="606.4520547945206" y="63.943550768373015" width="3.4438356164383563" height="46.056449231626985" fill="#4988b6" /><rect x="606.4520547945206" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671203" fill="#0000ff" /><rect x="606.4520547945206" y="63.943550768373015" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="609.8958904109589" y="61.54489055600603" width="3.4438356164383563" height="48.45510944399397" fill="#4988b6" /><rect x="609.8958904109589" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716137" fill="#0000ff" /><rect x="609.8958904109589" y="61.54489055600603" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="613.3397260273973" y="59.324125693833516" width="3.4438356164383563" height="50.675874306166484" fill="#4988b6" /><rect x="613.3397260273973" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210699" fill="#0000ff" /><rect x="613.3397260273973" y="59.32412569383352" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="616.7835616438357" y="57.293835243454545" width="3.4438356164383563" height="52.706164756545455" fill="#4988b6" /><rect x="616.7835616438357" y="94.0184787533569" width="3.4438356164383563" height="15.9815212466431" fill="#0000ff" /><rect x="616.7835616438357" y="57.29383524345455" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="620.227397260274" y="55.45663537220607" width="3.4438356164383563" height="54.54336462779393" fill="#4988b6" /><rect x="620.227397260274" y="91.2609778058611" width="3.4438356164383563" height="18.739022194138897" fill="#0000ff" /><rect x="620.227397260274" y="55.45663537220607" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="623.6712328767123" y="53.805549444816165" width="3.4438356164383563" height="56.194450555183835" fill="#4988b6" /><rect x="623.6712328767123" y="88.36086158453693" width="3.4438356164383563" height="21.639138415463062" fill="#0000ff" /><rect x="623.6712328767123" y="53.805549444816165" width="3.4438356164383563" height="34.55531213972077" fill="#ff0000" /><rect x="627.1150684931507" y="52.32469794342581" width="3.4438356164383563" height="57.67530205657419" fill="#4988b6" /><rect x="627.1150684931507" y="85.34020172496675" width="3.4438356164383563" height="24.659798275033253" fill="#0000ff" /><rect x="627.1150684931507" y="52.32469794342581" width="3.4438356164383563" height="33.015503781540936" fill="#ff0000" /><rect x="630.5589041095891" y="50.990283615707924" width="3.4438356164383563" height="59.009716384292076" fill="#4988b6" /><rect x="630.5589041095891" y="82.22198727260611" width="3.4438356164383563" height="27.778012727393882" fill="#0000ff" /><rect x="630.5589041095891" y="50.990283615707924" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="634.0027397260275" y="49.77183809233353" width="3.4438356164383563" height="60.22816190766647" fill="#4988b6" /><rect x="634.0027397260275" y="79.02994972226693" width="3.4438356164383563" height="30.97005027773306" fill="#0000ff" /><rect x="634.0027397260275" y="49.771838092333525" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="637.4465753424657" y="48.633688111412084" width="3.4438356164383563" height="61.366311888587916" fill="#4988b6" /><rect x="637.4465753424657" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="637.4465753424657" y="48.63368811141209" width="3.4438356164383563" height="27.154694295700146" fill="#ff0000" /><rect x="640.8904109589041" y="47.536592686203626" width="3.4438356164383563" height="62.463407313796374" fill="#4988b6" /><rect x="640.8904109589041" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827782" fill="#0000ff" /><rect x="640.8904109589041" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="644.3342465753425" y="46.43949726099517" width="3.4438356164383563" height="63.56050273900483" fill="#4988b6" /><rect x="644.3342465753425" y="69.25552881633213" width="3.4438356164383563" height="40.74447118366787" fill="#0000ff" /><rect x="644.3342465753425" y="46.43949726099517" width="3.4438356164383563" height="22.816031555336963" fill="#ff0000" /><rect x="647.7780821917809" y="45.30134728007371" width="3.4438356164383563" height="64.69865271992629" fill="#4988b6" /><rect x="647.7780821917809" y="66.01396150117742" width="3.4438356164383563" height="43.98603849882259" fill="#0000ff" /><rect x="647.7780821917809" y="45.30134728007371" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="651.2219178082192" y="44.082901756699286" width="3.4438356164383563" height="65.91709824330071" fill="#4988b6" /><rect x="651.2219178082192" y="62.821923950838205" width="3.4438356164383563" height="47.178076049161795" fill="#0000ff" /><rect x="651.2219178082192" y="44.082901756699286" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="654.6657534246576" y="42.74848742898146" width="3.4438356164383563" height="67.25151257101854" fill="#4988b6" /><rect x="654.6657534246576" y="59.703709498477636" width="3.4438356164383563" height="50.296290501522364" fill="#0000ff" /><rect x="654.6657534246576" y="42.74848742898146" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="658.1095890410959" y="41.26763592759107" width="3.4438356164383563" height="68.73236407240893" fill="#4988b6" /><rect x="658.1095890410959" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="658.1095890410959" y="41.267635927591066" width="3.4438356164383563" height="15.415413711316345" fill="#ff0000" /><rect x="661.5534246575343" y="39.61655000020117" width="3.4438356164383563" height="70.38344999979883" fill="#4988b6" /><rect x="661.5534246575343" y="53.78293341758326" width="3.4438356164383563" height="56.21706658241674" fill="#0000ff" /><rect x="661.5534246575343" y="39.61655000020118" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="664.9972602739726" y="37.7793501289527" width="3.4438356164383563" height="72.2206498710473" fill="#4988b6" /><rect x="664.9972602739726" y="51.02543247008746" width="3.4438356164383563" height="58.97456752991254" fill="#0000ff" /><rect x="664.9972602739726" y="37.7793501289527" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="668.441095890411" y="35.749059678573715" width="3.4438356164383563" height="74.25094032142628" fill="#4988b6" /><rect x="668.441095890411" y="48.43153304365505" width="3.4438356164383563" height="61.56846695634495" fill="#0000ff" /><rect x="668.441095890411" y="35.74905967857372" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="671.8849315068494" y="33.528294816401214" width="3.4438356164383563" height="76.47170518359879" fill="#4988b6" /><rect x="671.8849315068494" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="671.8849315068494" y="33.528294816401214" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="675.3287671232877" y="31.129634604034223" width="3.4438356164383563" height="78.87036539596578" fill="#4988b6" /><rect x="675.3287671232877" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="675.3287671232877" y="31.12963460403422" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="678.772602739726" y="28.575656593976063" width="3.4438356164383563" height="81.42434340602394" fill="#4988b6" /><rect x="678.772602739726" y="41.821738935110815" width="3.4438356164383563" height="68.17826106488918" fill="#0000ff" /><rect x="678.772602739726" y="28.575656593976063" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="682.2164383561644" y="25.898633669930675" width="3.4438356164383563" height="84.10136633006933" fill="#4988b6" /><rect x="682.2164383561644" y="40.065017087312754" width="3.4438356164383563" height="69.93498291268725" fill="#0000ff" /><rect x="682.2164383561644" y="25.898633669930675" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="685.6602739726028" y="23.139898428404408" width="3.4438356164383563" height="86.86010157159559" fill="#4988b6" /><rect x="685.6602739726028" y="38.55531213972077" width="3.4438356164383563" height="71.44468786027923" fill="#0000ff" /><rect x="685.6602739726028" y="23.139898428404425" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="689.1041095890412" y="20.348891789074585" width="3.4438356164383563" height="89.65110821092541" fill="#4988b6" /><rect x="689.1041095890412" y="37.30411385857076" width="3.4438356164383563" height="72.69588614142924" fill="#0000ff" /><rect x="689.1041095890412" y="20.34889178907458" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="692.5479452054794" y="17.581922424137616" width="3.4438356164383563" height="92.41807757586238" fill="#4988b6" /><rect x="692.5479452054794" y="36.32094461827654" width="3.4438356164383563" height="73.67905538172346" fill="#0000ff" /><rect x="692.5479452054794" y="17.581922424137634" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="695.9917808219178" y="14.900672709306775" width="3.4438356164383563" height="95.09932729069322" fill="#4988b6" /><rect x="695.9917808219178" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="695.9917808219178" y="14.900672709306775" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="699.4356164383562" y="12.370494941935746" width="3.4438356164383563" height="97.62950505806425" fill="#4988b6" /><rect x="699.4356164383562" y="35.18652649727271" width="3.4438356164383563" height="74.81347350272729" fill="#0000ff" /><rect x="699.4356164383562" y="12.370494941935757" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="702.8794520547946" y="10.058548297925782" width="3.4438356164383563" height="99.94145170207422" fill="#4988b6" /><rect x="702.8794520547946" y="35.043911223444326" width="3.4438356164383563" height="74.95608877655567" fill="#0000ff" /><rect x="702.8794520547946" y="10.058548297925771" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="706.323287671233" y="8.031832201572541" width="3.4438356164383563" height="101.96816779842746" fill="#4988b6" /><rect x="706.323287671233" y="35.186526497272695" width="3.4438356164383563" height="74.8134735027273" fill="#0000ff" /><rect x="706.323287671233" y="8.031832201572545" width="3.4438356164383563" height="27.15469429570015" fill="#ff0000" /><rect x="709.7671232876712" y="6.355175300477072" width="3.4438356164383563" height="103.64482469952293" fill="#4988b6" /><rect x="709.7671232876712" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="709.7671232876712" y="6.355175300477075" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="713.2109589041096" y="5.089240961378337" width="3.4438356164383563" height="104.91075903862166" fill="#4988b6" /><rect x="713.2109589041096" y="36.32094461827653" width="3.4438356164383563" height="73.67905538172347" fill="#0000ff" /><rect x="713.2109589041096" y="5.089240961378341" width="3.4438356164383563" height="31.231703656898187" fill="#ff0000" /><rect x="716.654794520548" y="4.28861007702983" width="3.4438356164383563" height="105.71138992297017" fill="#4988b6" /><rect x="716.654794520548" y="37.30411385857077" width="3.4438356164383563" height="72.69588614142923" fill="#0000ff" /><rect x="716.654794520548" y="4.288610077029844" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="720.0986301369863" y="4.0" width="3.4438356164383563" height="106.0" fill="#4988b6" /><rect x="720.0986301369863" y="38.555312139720755" width="3.4438356164383563" height="71.44468786027925" fill="#0000ff" /><rect x="720.0986301369863" y="3.999999999999993" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="723.5424657534247" y="4.260674653657716" width="3.4438356164383563" height="105.73932534634228" fill="#4988b6" /><rect x="723.5424657534247" y="40.06501708731274" width="3.4438356164383563" height="69.93498291268726" fill="#0000ff" /><rect x="723.5424657534247" y="4.260674653657709" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="726.9863013698631" y="5.097095425208451" width="3.4438356164383563" height="104.90290457479155" fill="#4988b6" /><rect x="726.9863013698631" y="41.8217389351108" width="3.4438356164383563" height="68.1782610648892" fill="#0000ff" /><rect x="726.9863013698631" y="5.097095425208451" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="730.4301369863014" y="6.523855483159764" width="3.4438356164383563" height="103.47614451684024" fill="#4988b6" /><rect x="730.4301369863014" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="730.4301369863014" y="6.523855483159764" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="733.8739726027397" y="8.542931890882656" width="3.4438356164383563" height="101.45706810911734" fill="#4988b6" /><rect x="733.8739726027397" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="733.8739726027397" y="8.542931890882663" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="737.3178082191781" y="11.143280557699256" width="3.4438356164383563" height="98.85671944230074" fill="#4988b6" /><rect x="737.3178082191781" y="48.431533043655044" width="3.4438356164383563" height="61.568466956344956" fill="#0000ff" /><rect x="737.3178082191781" y="11.143280557699264" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="740.7616438356165" y="14.300788960185102" width="3.4438356164383563" height="95.6992110398149" fill="#4988b6" /><rect x="740.7616438356165" y="51.02543247008745" width="3.4438356164383563" height="58.97456752991255" fill="#0000ff" /><rect x="740.7616438356165" y="14.300788960185095" width="3.4438356164383563" height="36.72464350990236" fill="#ff0000" /><rect x="744.2054794520549" y="17.978590983928214" width="3.4438356164383563" height="92.02140901607179" fill="#4988b6" /><rect x="744.2054794520549" y="53.78293341758325" width="3.4438356164383563" height="56.21706658241675" fill="#0000ff" /><rect x="744.2054794520549" y="17.97859098392822" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="747.6493150684931" y="22.12773749918665" width="3.4438356164383563" height="87.87226250081335" fill="#4988b6" /><rect x="747.6493150684931" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="747.6493150684931" y="22.12773749918665" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="751.0931506849315" y="26.688205716936665" width="3.4438356164383563" height="83.31179428306334" fill="#4988b6" /><rect x="751.0931506849315" y="59.70370949847761" width="3.4438356164383563" height="50.29629050152239" fill="#0000ff" /><rect x="751.0931506849315" y="26.68820571693668" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="754.5369863013699" y="31.59022029394002" width="3.4438356164383563" height="78.40977970605998" fill="#4988b6" /><rect x="754.5369863013699" y="62.82192395083821" width="3.4438356164383563" height="47.17807604916179" fill="#0000ff" /><rect x="754.5369863013699" y="31.590220293940018" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="757.9808219178083" y="36.75584987124398" width="3.4438356164383563" height="73.24415012875602" fill="#4988b6" /><rect x="757.9808219178083" y="66.01396150117739" width="3.4438356164383563" height="43.9860384988226" fill="#0000ff" /><rect x="757.9808219178083" y="36.75584987124398" width="3.4438356164383563" height="29.25811162993341" fill="#ff0000" /><rect x="761.4246575342466" y="42.10083452063198" width="3.4438356164383563" height="67.89916547936802" fill="#4988b6" /><rect x="761.4246575342466" y="69.25552881633212" width="3.4438356164383563" height="40.74447118366788" fill="#0000ff" /><rect x="761.4246575342466" y="42.10083452063198" width="3.4438356164383563" height="27.154694295700143" fill="#ff0000" /><rect x="764.868493150685" y="47.53659268620362" width="3.4438356164383563" height="62.46340731379638" fill="#4988b6" /><rect x="764.868493150685" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827783" fill="#0000ff" /><rect x="764.868493150685" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="768.3123287671233" y="52.97235085177527" width="3.4438356164383563" height="57.02764914822473" fill="#4988b6" /><rect x="768.3123287671233" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="768.3123287671233" y="52.972350851775275" width="3.4438356164383563" height="22.81603155533696" fill="#ff0000" /><rect x="771.7561643835617" y="58.317335501163235" width="3.4438356164383563" height="51.682664498836765" fill="#4988b6" /><rect x="771.7561643835617" y="79.02994972226693" width="3.4438356164383563" height="30.970050277733062" fill="#0000ff" /><rect x="771.7561643835617" y="58.31733550116323" width="3.4438356164383563" height="20.712614221103703" fill="#ff0000" /><rect x="775.2" y="63.48296507846722" width="3.4438356164383563" height="46.51703492153278" fill="#4988b6" /><rect x="775.2" y="82.22198727260613" width="3.4438356164383563" height="27.778012727393868" fill="#0000ff" /><rect x="775.2" y="63.48296507846722" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="778.6438356164384" y="68.38497965547054" width="3.4438356164383563" height="41.615020344529455" fill="#4988b6" /><rect x="778.6438356164384" y="85.34020172496673" width="3.4438356164383563" height="24.659798275033275" fill="#0000ff" /><rect x="778.6438356164384" y="68.38497965547054" width="3.4438356164383563" height="16.95522206949618" fill="#ff0000" /><rect x="782.0876712328768" y="72.94544787322057" width="3.4438356164383563" height="37.05455212677943" fill="#4988b6" /><rect x="782.0876712328768" y="88.3608615845369" width="3.4438356164383563" height="21.639138415463087" fill="#0000ff" /><rect x="782.0876712328768" y="72.94544787322056" width="3.4438356164383563" height="15.415413711316347" fill="#ff0000" /><rect x="785.5315068493151" y="77.094594388479" width="3.4438356164383563" height="32.905405611521005" fill="#4988b6" /><rect x="785.5315068493151" y="91.26097780586107" width="3.4438356164383563" height="18.739022194138922" fill="#0000ff" /><rect x="785.5315068493151" y="77.094594388479" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="788.9753424657534" y="80.77239641222212" width="3.4438356164383563" height="29.227603587777875" fill="#4988b6" /><rect x="788.9753424657534" y="94.01847875335687" width="3.4438356164383563" height="15.98152124664312" fill="#0000ff" /><rect x="788.9753424657534" y="80.77239641222212" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="792.4191780821918" y="83.92990481470797" width="3.4438356164383563" height="26.07009518529203" fill="#4988b6" /><rect x="792.4191780821918" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210702" fill="#0000ff" /><rect x="792.4191780821918" y="83.92990481470798" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="795.8630136986302" y="86.53025348152458" width="3.4438356164383563" height="23.46974651847542" fill="#4988b6" /><rect x="795.8630136986302" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716144" fill="#0000ff" /><rect x="795.8630136986302" y="86.53025348152458" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="799.3068493150686" y="88.54932988924747" width="3.4438356164383563" height="21.45067011075253" fill="#4988b6" /><rect x="799.3068493150686" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671206" fill="#0000ff" /><rect x="799.3068493150686" y="88.54932988924747" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="802.7506849315068" y="89.97608994719877" width="3.4438356164383563" height="20.023910052801227" fill="#4988b6" /><rect x="802.7506849315068" y="103.22217228833352" width="3.4438356164383563" height="6.777827711666475" fill="#0000ff" /><rect x="802.7506849315068" y="89.97608994719877" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="806.1945205479452" y="90.81251071874951" width="3.4438356164383563" height="19.187489281250485" fill="#4988b6" /><rect x="806.1945205479452" y="104.9788941361316" width="3.4438356164383563" height="5.021105863868406" fill="#0000ff" /><rect x="806.1945205479452" y="90.81251071874952" width="3.4438356164383563" height="14.166383417382079" fill="#ff0000" /><rect x="809.6383561643836" y="91.07318537240724" width="3.4438356164383563" height="18.926814627592755" fill="#4988b6" /><rect x="809.6383561643836" y="106.48859908372359" width="3.4438356164383563" height="3.5114009162764113" fill="#0000ff" /><rect x="809.6383561643836" y="91.07318537240724" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="813.082191780822" y="90.7845752953774" width="3.4438356164383563" height="19.21542470462261" fill="#4988b6" /><rect x="813.082191780822" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264337" fill="#0000ff" /><rect x="813.082191780822" y="90.7845752953774" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="816.5260273972603" y="89.9839444110289" width="3.4438356164383563" height="20.0160555889711" fill="#4988b6" /><rect x="816.5260273972603" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321904" fill="#0000ff" /><rect x="816.5260273972603" y="89.9839444110289" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="819.9698630136986" y="88.71801007193015" width="3.4438356164383563" height="21.281989928069848" fill="#4988b6" /><rect x="819.9698630136986" y="89.2873857788963" width="3.4438356164383563" height="20.7126142211037" fill="#ff0000" /><rect x="823.413698630137" y="87.0413531708347" width="3.4438356164383563" height="22.95864682916531" fill="#4988b6" /><rect x="823.413698630137" y="87.18396844466305" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="826.8575342465754" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#4988b6" /><rect x="826.8575342465754" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="830.3013698630137" y="82.7026904304715" width="3.4438356164383563" height="27.2973095695285" fill="#4988b6" /><rect x="830.3013698630137" y="82.84530570429986" width="3.4438356164383563" height="27.15469429570014" fill="#ff0000" /><rect x="833.7452054794521" y="80.17251266310045" width="3.4438356164383563" height="29.82748733689955" fill="#4988b6" /><rect x="833.7452054794521" y="80.74188837006659" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="837.1890410958905" y="77.49126294826962" width="3.4438356164383563" height="32.50873705173037" fill="#4988b6" /><rect x="837.1890410958905" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321815" fill="#0000ff" /><rect x="837.1890410958905" y="77.49126294826962" width="3.4438356164383563" height="31.23170365689819" fill="#ff0000" /><rect x="840.6328767123288" y="74.72429358333264" width="3.4438356164383563" height="35.27570641666736" fill="#4988b6" /><rect x="840.6328767123288" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264293" fill="#0000ff" /><rect x="840.6328767123288" y="74.72429358333264" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="844.0767123287671" y="71.93328694400283" width="3.4438356164383563" height="38.06671305599717" fill="#4988b6" /><rect x="844.0767123287671" y="106.4885990837236" width="3.4438356164383563" height="3.511400916276407" fill="#0000ff" /><rect x="844.0767123287671" y="71.93328694400284" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="847.5205479452055" y="69.17455170247656" width="3.4438356164383563" height="40.82544829752344" fill="#4988b6" /><rect x="847.5205479452055" y="104.97889413613159" width="3.4438356164383563" height="5.021105863868411" fill="#0000ff" /><rect x="847.5205479452055" y="69.17455170247656" width="3.4438356164383563" height="35.80434243365502" fill="#ff0000" /><rect x="850.9643835616439" y="66.49752877843119" width="3.4438356164383563" height="43.50247122156881" fill="#4988b6" /><rect x="850.9643835616439" y="103.22217228833354" width="3.4438356164383563" height="6.777827711666462" fill="#0000ff" /><rect x="850.9643835616439" y="66.49752877843119" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="854.4082191780823" y="63.943550768373015" width="3.4438356164383563" height="46.056449231626985" fill="#4988b6" /><rect x="854.4082191780823" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671203" fill="#0000ff" /><rect x="854.4082191780823" y="63.943550768373015" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="857.8520547945205" y="61.54489055600603" width="3.4438356164383563" height="48.45510944399397" fill="#4988b6" /><rect x="857.8520547945205" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716137" fill="#0000ff" /><rect x="857.8520547945205" y="61.54489055600603" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="861.2958904109589" y="59.324125693833516" width="3.4438356164383563" height="50.675874306166484" fill="#4988b6" /><rect x="861.2958904109589" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210699" fill="#0000ff" /><rect x="861.2958904109589" y="59.32412569383352" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="864.7397260273973" y="57.293835243454545" width="3.4438356164383563" height="52.706164756545455" fill="#4988b6" /><rect x="864.7397260273973" y="94.0184787533569" width="3.4438356164383563" height="15.9815212466431" fill="#0000ff" /><rect x="864.7397260273973" y="57.29383524345455" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="868.1835616438357" y="55.45663537220607" width="3.4438356164383563" height="54.54336462779393" fill="#4988b6" /><rect x="868.1835616438357" y="91.2609778058611" width="3.4438356164383563" height="18.739022194138897" fill="#0000ff" /><rect x="868.1835616438357" y="55.45663537220607" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="871.627397260274" y="53.805549444816165" width="3.4438356164383563" height="56.194450555183835" fill="#4988b6" /><rect x="871.627397260274" y="88.36086158453693" width="3.4438356164383563" height="21.639138415463062" fill="#0000ff" /><rect x="871.627397260274" y="53.805549444816165" width="3.4438356164383563" height="34.55531213972077" fill="#ff0000" /><rect x="875.0712328767124" y="52.32469794342581" width="3.4438356164383563" height="57.67530205657419" fill="#4988b6" /><rect x="875.0712328767124" y="85.34020172496675" width="3.4438356164383563" height="24.659798275033253" fill="#0000ff" /><rect x="875.0712328767124" y="52.32469794342581" width="3.4438356164383563" height="33.015503781540936" fill="#ff0000" /><rect x="878.5150684931507" y="50.990283615707924" width="3.4438356164383563" height="59.009716384292076" fill="#4988b6" /><rect x="878.5150684931507" y="82.22198727260611" width="3.4438356164383563" height="27.778012727393882" fill="#0000ff" /><rect x="878.5150684931507" y="50.990283615707924" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="881.9589041095891" y="49.77183809233353" width="3.4438356164383563" height="60.22816190766647" fill="#4988b6" /><rect x="881.9589041095891" y="79.02994972226693" width="3.4438356164383563" height="30.97005027773306" fill="#0000ff" /><rect x="881.9589041095891" y="49.771838092333525" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="885.4027397260274" y="48.633688111412084" width="3.4438356164383563" height="61.366311888587916" fill="#4988b6" /><rect x="885.4027397260274" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="885.4027397260274" y="48.63368811141209" width="3.4438356164383563" height="27.154694295700146" fill="#ff0000" /><rect x="888.8465753424658" y="47.536592686203626" width="3.4438356164383563" height="62.463407313796374" fill="#4988b6" /><rect x="888.8465753424658" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827782" fill="#0000ff" /><rect x="888.8465753424658" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="892.2904109589042" y="46.43949726099517" width="3.4438356164383563" height="63.56050273900483" fill="#4988b6" /><rect x="892.2904109589042" y="69.25552881633213" width="3.4438356164383563" height="40.74447118366787" fill="#0000ff" /><rect x="892.2904109589042" y="46.43949726099517" width="3.4438356164383563" height="22.816031555336963" fill="#ff0000" /><rect x="895.7342465753425" y="45.30134728007371" width="3.4438356164383563" height="64.69865271992629" fill="#4988b6" /><rect x="895.7342465753425" y="66.01396150117742" width="3.4438356164383563" height="43.98603849882259" fill="#0000ff" /><rect x="895.7342465753425" y="45.30134728007371" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="899.1780821917808" y="44.082901756699286" width="3.4438356164383563" height="65.91709824330071" fill="#4988b6" /><rect x="899.1780821917808" y="62.821923950838205" width="3.4438356164383563" height="47.178076049161795" fill="#0000ff" /><rect x="899.1780821917808" y="44.082901756699286" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="902.6219178082192" y="42.74848742898146" width="3.4438356164383563" height="67.25151257101854" fill="#4988b6" /><rect x="902.6219178082192" y="59.703709498477636" width="3.4438356164383563" height="50.296290501522364" fill="#0000ff" /><rect x="902.6219178082192" y="42.74848742898146" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="906.0657534246576" y="41.26763592759107" width="3.4438356164383563" height="68.73236407240893" fill="#4988b6" /><rect x="906.0657534246576" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="906.0657534246576" y="41.267635927591066" width="3.4438356164383563" height="15.415413711316345" fill="#ff0000" /><rect x="909.509589041096" y="39.61655000020117" width="3.4438356164383563" height="70.38344999979883" fill="#4988b6" /><rect x="909.509589041096" y="53.78293341758326" width="3.4438356164383563" height="56.21706658241674" fill="#0000ff" /><rect x="909.509589041096" y="39.61655000020118" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="912.9534246575342" y="37.7793501289527" width="3.4438356164383563" height="72.2206498710473" fill="#4988b6" /><rect x="912.9534246575342" y="51.02543247008746" width="3.4438356164383563" height="58.97456752991254" fill="#0000ff" /><rect x="912.9534246575342" y="37.7793501289527" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="916.3972602739726" y="35.749059678573715" width="3.4438356164383563" height="74.25094032142628" fill="#4988b6" /><rect x="916.3972602739726" y="48.43153304365505" width="3.4438356164383563" height="61.56846695634495" fill="#0000ff" /><rect x="916.3972602739726" y="35.74905967857372" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="919.841095890411" y="33.528294816401214" width="3.4438356164383563" height="76.47170518359879" fill="#4988b6" /><rect x="919.841095890411" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="919.841095890411" y="33.528294816401214" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="923.2849315068494" y="31.129634604034223" width="3.4438356164383563" height="78.87036539596578" fill="#4988b6" /><rect x="923.2849315068494" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="923.2849315068494" y="31.12963460403422" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="926.7287671232878" y="28.575656593976063" width="3.4438356164383563" height="81.42434340602394" fill="#4988b6" /><rect x="926.7287671232878" y="41.821738935110815" width="3.4438356164383563" height="68.17826106488918" fill="#0000ff" /><rect x="926.7287671232878" y="28.575656593976063" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="930.172602739726" y="25.898633669930675" width="3.4438356164383563" height="84.10136633006933" fill="#4988b6" /><rect x="930.172602739726" y="40.065017087312754" width="3.4438356164383563" height="69.93498291268725" fill="#0000ff" /><rect x="930.172602739726" y="25.898633669930675" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="933.6164383561644" y="23.139898428404408" width="3.4438356164383563" height="86.86010157159559" fill="#4988b6" /><rect x="933.6164383561644" y="38.55531213972077" width="3.4438356164383563" height="71.44468786027923" fill="#0000ff" /><rect x="933.6164383561644" y="23.139898428404425" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="937.0602739726028" y="20.348891789074585" width="3.4438356164383563" height="89.65110821092541" fill="#4988b6" /><rect x="937.0602739726028" y="37.30411385857076" width="3.4438356164383563" height="72.69588614142924" fill="#0000ff" /><rect x="937.0602739726028" y="20.34889178907458" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="940.5041095890411" y="17.581922424137616" width="3.4438356164383563" height="92.41807757586238" fill="#4988b6" /><rect x="940.5041095890411" y="36.32094461827654" width="3.4438356164383563" height="73.67905538172346" fill="#0000ff" /><rect x="940.5041095890411" y="17.581922424137634" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="943.9479452054795" y="14.900672709306775" width="3.4438356164383563" height="95.09932729069322" fill="#4988b6" /><rect x="943.9479452054795" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="943.9479452054795" y="14.900672709306775" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="947.3917808219179" y="12.370494941935746" width="3.4438356164383563" height="97.62950505806425" fill="#4988b6" /><rect x="947.3917808219179" y="35.18652649727271" width="3.4438356164383563" height="74.81347350272729" fill="#0000ff" /><rect x="947.3917808219179" y="12.370494941935757" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="950.8356164383562" y="10.058548297925782" width="3.4438356164383563" height="99.94145170207422" fill="#4988b6" /><rect x="950.8356164383562" y="35.043911223444326" width="3.4438356164383563" height="74.95608877655567" fill="#0000ff" /><rect x="950.8356164383562" y="10.058548297925771" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="954.2794520547945" y="8.031832201572541" width="3.4438356164383563" height="101.96816779842746" fill="#4988b6" /><rect x="954.2794520547945" y="35.186526497272695" width="3.4438356164383563" height="74.8134735027273" fill="#0000ff" /><rect x="954.2794520547945" y="8.031832201572545" width="3.4438356164383563" height="27.15469429570015" fill="#ff0000" /><rect x="957.7232876712329" y="6.355175300477072" width="3.4438356164383563" height="103.64482469952293" fill="#4988b6" /><rect x="957.7232876712329" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="957.7232876712329" y="6.355175300477075" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="961.1671232876713" y="5.089240961378337" width="3.4438356164383563" height="104.91075903862166" fill="#4988b6" /><rect x="961.1671232876713" y="36.32094461827653" width="3.4438356164383563" height="73.67905538172347" fill="#0000ff" /><rect x="961.1671232876713" y="5.089240961378341" width="3.4438356164383563" height="31.231703656898187" fill="#ff0000" /><rect x="964.6109589041097" y="4.28861007702983" width="3.4438356164383563" height="105.71138992297017" fill="#4988b6" /><rect x="964.6109589041097" y="37.30411385857077" width="3.4438356164383563" height="72.69588614142923" fill="#0000ff" /><rect x="964.6109589041097" y="4.288610077029844" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="968.054794520548" y="4.0" width="3.4438356164383563" height="106.0" fill="#4988b6" /><rect x="968.054794520548" y="38.555312139720755" width="3.4438356164383563" height="71.44468786027925" fill="#0000ff" /><rect x="968.054794520548" y="3.999999999999993" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="971.4986301369863" y="4.260674653657716" width="3.4438356164383563" height="105.73932534634228" fill="#4988b6" /><rect x="971.4986301369863" y="40.06501708731274" width="3.4438356164383563" height="69.93498291268726" fill="#0000ff" /><rect x="971.4986301369863" y="4.260674653657709" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="974.9424657534247" y="5.097095425208451" width="3.4438356164383563" height="104.90290457479155" fill="#4988b6" /><rect x="974.9424657534247" y="41.8217389351108" width="3.4438356164383563" height="68.1782610648892" fill="#0000ff" /><rect x="974.9424657534247" y="5.097095425208451" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="978.3863013698631" y="6.523855483159764" width="3.4438356164383563" height="103.47614451684024" fill="#4988b6" /><rect x="978.3863013698631" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="978.3863013698631" y="6.523855483159764" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="981.8301369863015" y="8.542931890882656" width="3.4438356164383563" height="101.45706810911734" fill="#4988b6" /><rect x="981.8301369863015" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="981.8301369863015" y="8.542931890882663" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="985.2739726027398" y="11.143280557699256" width="3.4438356164383563" height="98.85671944230074" fill="#4988b6" /><rect x="985.2739726027398" y="48.431533043655044" width="3.4438356164383563" height="61.568466956344956" fill="#0000ff" /><rect x="985.2739726027398" y="11.143280557699264" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="988.7178082191781" y="14.300788960185102" width="3.4438356164383563" height="95.6992110398149" fill="#4988b6" /><rect x="988.7178082191781" y="51.02543247008745" width="3.4438356164383563" height="58.97456752991255" fill="#0000ff" /><rect x="988.7178082191781" y="14.300788960185095" width="3.4438356164383563" height="36.72464350990236" fill="#ff0000" /><rect x="992.1616438356165" y="17.978590983928214" width="3.4438356164383563" height="92.02140901607179" fill="#4988b6" /><rect x="992.1616438356165" y="53.78293341758325" width="3.4438356164383563" height="56.21706658241675" fill="#0000ff" /><rect x="992.1616438356165" y="17.97859098392822" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="995.6054794520549" y="22.12773749918665" width="3.4438356164383563" height="87.87226250081335" fill="#4988b6" /><rect x="995.6054794520549" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="995.6054794520549" y="22.12773749918665" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="999.0493150684932" y="26.688205716936665" width="3.4438356164383563" height="83.31179428306334" fill="#4988b6" /><rect x="999.0493150684932" y="59.70370949847761" width="3.4438356164383563" height="50.29629050152239" fill="#0000ff" /><rect x="999.0493150684932" y="26.68820571693668" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="1002.4931506849316" y="31.59022029394002" width="3.4438356164383563" height="78.40977970605998" fill="#4988b6" /><rect x="1002.4931506849316" y="62.82192395083821" width="3.4438356164383563" height="47.17807604916179" fill="#0000ff" /><rect x="1002.4931506849316" y="31.590220293940018" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="1005.9369863013699" y="36.75584987124398" width="3.4438356164383563" height="73.24415012875602" fill="#4988b6" /><rect x="1005.9369863013699" y="66.01396150117739" width="3.4438356164383563" height="43.9860384988226" fill="#0000ff" /><rect x="1005.9369863013699" y="36.75584987124398" width="3.4438356164383563" height="29.25811162993341" fill="#ff0000" /><rect x="1009.3808219178082" y="42.10083452063198" width="3.4438356164383563" height="67.89916547936802" fill="#4988b6" /><rect x="1009.3808219178082" y="69.25552881633212" width="3.4438356164383563" height="40.74447118366788" fill="#0000ff" /><rect x="1009.3808219178082" y="42.10083452063198" width="3.4438356164383563" height="27.154694295700143" fill="#ff0000" /><rect x="1012.8246575342466" y="47.53659268620362" width="3.4438356164383563" height="62.46340731379638" fill="#4988b6" /><rect x="1012.8246575342466" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827783" fill="#0000ff" /><rect x="1012.8246575342466" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="1016.268493150685" y="52.97235085177527" width="3.4438356164383563" height="57.02764914822473" fill="#4988b6" /><rect x="1016.268493150685" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="1016.268493150685" y="52.972350851775275" width="3.4438356164383563" height="22.81603155533696" fill="#ff0000" /><rect x="1019.7123287671234" y="58.317335501163235" width="3.4438356164383563" height="51.682664498836765" fill="#4988b6" /><rect x="1019.7123287671234" y="79.02994972226693" width="3.4438356164383563" height="30.970050277733062" fill="#0000ff" /><rect x="1019.7123287671234" y="58.31733550116323" width="3.4438356164383563" height="20.712614221103703" fill="#ff0000" /><rect x="1023.1561643835616" y="63.48296507846722" width="3.4438356164383563" height="46.51703492153278" fill="#4988b6" /><rect x="1023.1561643835616" y="82.22198727260613" width="3.4438356164383563" height="27.778012727393868" fill="#0000ff" /><rect x="1023.1561643835616" y="63.48296507846722" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="1026.6" y="68.38497965547054" width="3.4438356164383563" height="41.615020344529455" fill="#4988b6" /><rect x="1026.6" y="85.34020172496673" width="3.4438356164383563" height="24.659798275033275" fill="#0000ff" /><rect x="1026.6" y="68.38497965547054" width="3.4438356164383563" height="16.95522206949618" fill="#ff0000" /><rect x="1030.0438356164384" y="72.94544787322057" width="3.4438356164383563" height="37.05455212677943" fill="#4988b6" /><rect x="1030.0438356164384" y="88.3608615845369" width="3.4438356164383563" height="21.639138415463087" fill="#0000ff" /><rect x="1030.0438356164384" y="72.94544787322056" width="3.4438356164383563" height="15.415413711316347" fill="#ff0000" /><rect x="1033.487671232877" y="77.094594388479" width="3.4438356164383563" height="32.905405611521005" fill="#4988b6" /><rect x="1033.487671232877" y="91.26097780586107" width="3.4438356164383563" height="18.739022194138922" fill="#0000ff" /><rect x="1033.487671232877" y="77.094594388479" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="1036.9315068493152" y="80.77239641222212" width="3.4438356164383563" height="29.227603587777875" fill="#4988b6" /><rect x="1036.9315068493152" y="94.01847875335687" width="3.4438356164383563" height="15.98152124664312" fill="#0000ff" /><rect x="1036.9315068493152" y="80.77239641222212" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="1040.3753424657534" y="83.92990481470797" width="3.4438356164383563" height="26.07009518529203" fill="#4988b6" /><rect x="1040.3753424657534" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210702" fill="#0000ff" /><rect x="1040.3753424657534" y="83.92990481470798" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="1043.8191780821917" y="86.53025348152458" width="3.4438356164383563" height="23.46974651847542" fill="#4988b6" /><rect x="1043.8191780821917" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716144" fill="#0000ff" /><rect x="1043.8191780821917" y="86.53025348152458" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="1047.2630136986302" y="88.54932988924747" width="3.4438356164383563" height="21.45067011075253" fill="#4988b6" /><rect x="1047.2630136986302" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671206" fill="#0000ff" /><rect x="1047.2630136986302" y="88.54932988924747" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="1050.7068493150684" y="89.97608994719877" width="3.4438356164383563" height="20.023910052801227" fill="#4988b6" /><rect x="1050.7068493150684" y="103.22217228833352" width="3.4438356164383563" height="6.777827711666475" fill="#0000ff" /><rect x="1050.7068493150684" y="89.97608994719877" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="1054.150684931507" y="90.81251071874951" width="3.4438356164383563" height="19.187489281250485" fill="#4988b6" /><rect x="1054.150684931507" y="104.9788941361316" width="3.4438356164383563" height="5.021105863868406" fill="#0000ff" /><rect x="1054.150684931507" y="90.81251071874952" width="3.4438356164383563" height="14.166383417382079" fill="#ff0000" /><rect x="1057.5945205479452" y="91.07318537240724" width="3.4438356164383563" height="18.926814627592755" fill="#4988b6" /><rect x="1057.5945205479452" y="106.48859908372359" width="3.4438356164383563" height="3.5114009162764113" fill="#0000ff" /><rect x="1057.5945205479452" y="91.07318537240724" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="1061.0383561643837" y="90.7845752953774" width="3.4438356164383563" height="19.21542470462261" fill="#4988b6" /><rect x="1061.0383561643837" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264337" fill="#0000ff" /><rect x="1061.0383561643837" y="90.7845752953774" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="1064.482191780822" y="89.9839444110289" width="3.4438356164383563" height="20.0160555889711" fill="#4988b6" /><rect x="1064.482191780822" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321904" fill="#0000ff" /><rect x="1064.482191780822" y="89.9839444110289" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="1067.9260273972604" y="88.71801007193015" width="3.4438356164383563" height="21.281989928069848" fill="#4988b6" /><rect x="1067.9260273972604" y="89.2873857788963" width="3.4438356164383563" height="20.7126142211037" fill="#ff0000" /><rect x="1071.3698630136987" y="87.0413531708347" width="3.4438356164383563" height="22.95864682916531" fill="#4988b6" /><rect x="1071.3698630136987" y="87.18396844466305" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="1074.813698630137" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#4988b6" /><rect x="1074.813698630137" y="85.01463707448144" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="1078.2575342465755" y="82.7026904304715" width="3.4438356164383563" height="27.2973095695285" fill="#4988b6" /><rect x="1078.2575342465755" y="82.84530570429986" width="3.4438356164383563" height="27.15469429570014" fill="#ff0000" /><rect x="1081.7013698630137" y="80.17251266310045" width="3.4438356164383563" height="29.82748733689955" fill="#4988b6" /><rect x="1081.7013698630137" y="80.74188837006659" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="1085.1452054794522" y="77.49126294826962" width="3.4438356164383563" height="32.50873705173037" fill="#4988b6" /><rect x="1085.1452054794522" y="108.72296660516781" width="3.4438356164383563" height="1.2770333948321815" fill="#0000ff" /><rect x="1085.1452054794522" y="77.49126294826962" width="3.4438356164383563" height="31.23170365689819" fill="#ff0000" /><rect x="1088.5890410958905" y="74.72429358333264" width="3.4438356164383563" height="35.27570641666736" fill="#4988b6" /><rect x="1088.5890410958905" y="107.73979736487357" width="3.4438356164383563" height="2.2602026351264293" fill="#0000ff" /><rect x="1088.5890410958905" y="74.72429358333264" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="1092.0328767123287" y="71.93328694400283" width="3.4438356164383563" height="38.06671305599717" fill="#4988b6" /><rect x="1092.0328767123287" y="106.4885990837236" width="3.4438356164383563" height="3.511400916276407" fill="#0000ff" /><rect x="1092.0328767123287" y="71.93328694400284" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="1095.4767123287672" y="69.17455170247656" width="3.4438356164383563" height="40.82544829752344" fill="#4988b6" /><rect x="1095.4767123287672" y="104.97889413613159" width="3.4438356164383563" height="5.021105863868411" fill="#0000ff" /><rect x="1095.4767123287672" y="69.17455170247656" width="3.4438356164383563" height="35.80434243365502" fill="#ff0000" /><rect x="1098.9205479452055" y="66.49752877843119" width="3.4438356164383563" height="43.50247122156881" fill="#4988b6" /><rect x="1098.9205479452055" y="103.22217228833354" width="3.4438356164383563" height="6.777827711666462" fill="#0000ff" /><rect x="1098.9205479452055" y="66.49752877843119" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="1102.364383561644" y="63.943550768373015" width="3.4438356164383563" height="46.056449231626985" fill="#4988b6" /><rect x="1102.364383561644" y="101.2318032543288" width="3.4438356164383563" height="8.768196745671203" fill="#0000ff" /><rect x="1102.364383561644" y="63.943550768373015" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="1105.8082191780823" y="61.54489055600603" width="3.4438356164383563" height="48.45510944399397" fill="#4988b6" /><rect x="1105.8082191780823" y="99.02293494428386" width="3.4438356164383563" height="10.977065055716137" fill="#0000ff" /><rect x="1105.8082191780823" y="61.54489055600603" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="1109.2520547945205" y="59.324125693833516" width="3.4438356164383563" height="50.675874306166484" fill="#4988b6" /><rect x="1109.2520547945205" y="96.6123781797893" width="3.4438356164383563" height="13.387621820210699" fill="#0000ff" /><rect x="1109.2520547945205" y="59.32412569383352" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="1112.695890410959" y="57.293835243454545" width="3.4438356164383563" height="52.706164756545455" fill="#4988b6" /><rect x="1112.695890410959" y="94.0184787533569" width="3.4438356164383563" height="15.9815212466431" fill="#0000ff" /><rect x="1112.695890410959" y="57.29383524345455" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="1116.1397260273973" y="55.45663537220607" width="3.4438356164383563" height="54.54336462779393" fill="#4988b6" /><rect x="1116.1397260273973" y="91.2609778058611" width="3.4438356164383563" height="18.739022194138897" fill="#0000ff" /><rect x="1116.1397260273973" y="55.45663537220607" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="1119.5835616438358" y="53.805549444816165" width="3.4438356164383563" height="56.194450555183835" fill="#4988b6" /><rect x="1119.5835616438358" y="88.36086158453693" width="3.4438356164383563" height="21.639138415463062" fill="#0000ff" /><rect x="1119.5835616438358" y="53.805549444816165" width="3.4438356164383563" height="34.55531213972077" fill="#ff0000" /><rect x="1123.027397260274" y="52.32469794342581" width="3.4438356164383563" height="57.67530205657419" fill="#4988b6" /><rect x="1123.027397260274" y="85.34020172496675" width="3.4438356164383563" height="24.659798275033253" fill="#0000ff" /><rect x="1123.027397260274" y="52.32469794342581" width="3.4438356164383563" height="33.015503781540936" fill="#ff0000" /><rect x="1126.4712328767123" y="50.990283615707924" width="3.4438356164383563" height="59.009716384292076" fill="#4988b6" /><rect x="1126.4712328767123" y="82.22198727260611" width="3.4438356164383563" height="27.778012727393882" fill="#0000ff" /><rect x="1126.4712328767123" y="50.990283615707924" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="1129.9150684931508" y="49.77183809233353" width="3.4438356164383563" height="60.22816190766647" fill="#4988b6" /><rect x="1129.9150684931508" y="79.02994972226693" width="3.4438356164383563" height="30.97005027773306" fill="#0000ff" /><rect x="1129.9150684931508" y="49.771838092333525" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="1133.358904109589" y="48.633688111412084" width="3.4438356164383563" height="61.366311888587916" fill="#4988b6" /><rect x="1133.358904109589" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="1133.358904109589" y="48.63368811141209" width="3.4438356164383563" height="27.154694295700146" fill="#ff0000" /><rect x="1136.8027397260275" y="47.536592686203626" width="3.4438356164383563" height="62.463407313796374" fill="#4988b6" /><rect x="1136.8027397260275" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827782" fill="#0000ff" /><rect x="1136.8027397260275" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="1140.2465753424658" y="46.43949726099517" width="3.4438356164383563" height="63.56050273900483" fill="#4988b6" /><rect x="1140.2465753424658" y="69.25552881633213" width="3.4438356164383563" height="40.74447118366787" fill="#0000ff" /><rect x="1140.2465753424658" y="46.43949726099517" width="3.4438356164383563" height="22.816031555336963" fill="#ff0000" /><rect x="1143.690410958904" y="45.30134728007371" width="3.4438356164383563" height="64.69865271992629" fill="#4988b6" /><rect x="1143.690410958904" y="66.01396150117742" width="3.4438356164383563" height="43.98603849882259" fill="#0000ff" /><rect x="1143.690410958904" y="45.30134728007371" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="1147.1342465753426" y="44.082901756699286" width="3.4438356164383563" height="65.91709824330071" fill="#4988b6" /><rect x="1147.1342465753426" y="62.821923950838205" width="3.4438356164383563" height="47.178076049161795" fill="#0000ff" /><rect x="1147.1342465753426" y="44.082901756699286" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="1150.5780821917808" y="42.74848742898146" width="3.4438356164383563" height="67.25151257101854" fill="#4988b6" /><rect x="1150.5780821917808" y="59.703709498477636" width="3.4438356164383563" height="50.296290501522364" fill="#0000ff" /><rect x="1150.5780821917808" y="42.74848742898146" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="1154.0219178082193" y="41.26763592759107" width="3.4438356164383563" height="68.73236407240893" fill="#4988b6" /><rect x="1154.0219178082193" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="1154.0219178082193" y="41.267635927591066" width="3.4438356164383563" height="15.415413711316345" fill="#ff0000" /><rect x="1157.4657534246576" y="39.61655000020117" width="3.4438356164383563" height="70.38344999979883" fill="#4988b6" /><rect x="1157.4657534246576" y="53.78293341758326" width="3.4438356164383563" height="56.21706658241674" fill="#0000ff" /><rect x="1157.4657534246576" y="39.61655000020118" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="1160.9095890410958" y="37.7793501289527" width="3.4438356164383563" height="72.2206498710473" fill="#4988b6" /><rect x="1160.9095890410958" y="51.02543247008746" width="3.4438356164383563" height="58.97456752991254" fill="#0000ff" /><rect x="1160.9095890410958" y="37.7793501289527" width="3.4438356164383563" height="13.246082341134755" fill="#ff0000" /><rect x="1164.3534246575343" y="35.749059678573715" width="3.4438356164383563" height="74.25094032142628" fill="#4988b6" /><rect x="1164.3534246575343" y="48.43153304365505" width="3.4438356164383563" height="61.56846695634495" fill="#0000ff" /><rect x="1164.3534246575343" y="35.74905967857372" width="3.4438356164383563" height="12.682473365081327" fill="#ff0000" /><rect x="1167.7972602739726" y="33.528294816401214" width="3.4438356164383563" height="76.47170518359879" fill="#4988b6" /><rect x="1167.7972602739726" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="1167.7972602739726" y="33.528294816401214" width="3.4438356164383563" height="12.492681462759275" fill="#ff0000" /><rect x="1171.241095890411" y="31.129634604034223" width="3.4438356164383563" height="78.87036539596578" fill="#4988b6" /><rect x="1171.241095890411" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="1171.241095890411" y="31.12963460403422" width="3.4438356164383563" height="12.682473365081325" fill="#ff0000" /><rect x="1174.6849315068494" y="28.575656593976063" width="3.4438356164383563" height="81.42434340602394" fill="#4988b6" /><rect x="1174.6849315068494" y="41.821738935110815" width="3.4438356164383563" height="68.17826106488918" fill="#0000ff" /><rect x="1174.6849315068494" y="28.575656593976063" width="3.4438356164383563" height="13.246082341134752" fill="#ff0000" /><rect x="1178.1287671232876" y="25.898633669930675" width="3.4438356164383563" height="84.10136633006933" fill="#4988b6" /><rect x="1178.1287671232876" y="40.065017087312754" width="3.4438356164383563" height="69.93498291268725" fill="#0000ff" /><rect x="1178.1287671232876" y="25.898633669930675" width="3.4438356164383563" height="14.16638341738208" fill="#ff0000" /><rect x="1181.572602739726" y="23.139898428404408" width="3.4438356164383563" height="86.86010157159559" fill="#4988b6" /><rect x="1181.572602739726" y="38.55531213972077" width="3.4438356164383563" height="71.44468786027923" fill="#0000ff" /><rect x="1181.572602739726" y="23.139898428404425" width="3.4438356164383563" height="15.415413711316344" fill="#ff0000" /><rect x="1185.0164383561644" y="20.348891789074585" width="3.4438356164383563" height="89.65110821092541" fill="#4988b6" /><rect x="1185.0164383561644" y="37.30411385857076" width="3.4438356164383563" height="72.69588614142924" fill="#0000ff" /><rect x="1185.0164383561644" y="20.34889178907458" width="3.4438356164383563" height="16.955222069496177" fill="#ff0000" /><rect x="1188.4602739726029" y="17.581922424137616" width="3.4438356164383563" height="92.41807757586238" fill="#4988b6" /><rect x="1188.4602739726029" y="36.32094461827654" width="3.4438356164383563" height="73.67905538172346" fill="#0000ff" /><rect x="1188.4602739726029" y="17.581922424137634" width="3.4438356164383563" height="18.739022194138908" fill="#ff0000" /><rect x="1191.9041095890411" y="14.900672709306775" width="3.4438356164383563" height="95.09932729069322" fill="#4988b6" /><rect x="1191.9041095890411" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="1191.9041095890411" y="14.900672709306775" width="3.4438356164383563" height="20.712614221103706" fill="#ff0000" /><rect x="1195.3479452054796" y="12.370494941935746" width="3.4438356164383563" height="97.62950505806425" fill="#4988b6" /><rect x="1195.3479452054796" y="35.18652649727271" width="3.4438356164383563" height="74.81347350272729" fill="#0000ff" /><rect x="1195.3479452054796" y="12.370494941935757" width="3.4438356164383563" height="22.816031555336952" fill="#ff0000" /><rect x="1198.7917808219179" y="10.058548297925782" width="3.4438356164383563" height="99.94145170207422" fill="#4988b6" /><rect x="1198.7917808219179" y="35.043911223444326" width="3.4438356164383563" height="74.95608877655567" fill="#0000ff" /><rect x="1198.7917808219179" y="10.058548297925771" width="3.4438356164383563" height="24.985362925518555" fill="#ff0000" /><rect x="1202.2356164383561" y="8.031832201572541" width="3.4438356164383563" height="101.96816779842746" fill="#4988b6" /><rect x="1202.2356164383561" y="35.186526497272695" width="3.4438356164383563" height="74.8134735027273" fill="#0000ff" /><rect x="1202.2356164383561" y="8.031832201572545" width="3.4438356164383563" height="27.15469429570015" fill="#ff0000" /><rect x="1205.6794520547946" y="6.355175300477072" width="3.4438356164383563" height="103.64482469952293" fill="#4988b6" /><rect x="1205.6794520547946" y="35.61328693041048" width="3.4438356164383563" height="74.38671306958952" fill="#0000ff" /><rect x="1205.6794520547946" y="6.355175300477075" width="3.4438356164383563" height="29.258111629933406" fill="#ff0000" /><rect x="1209.123287671233" y="5.089240961378337" width="3.4438356164383563" height="104.91075903862166" fill="#4988b6" /><rect x="1209.123287671233" y="36.32094461827653" width="3.4438356164383563" height="73.67905538172347" fill="#0000ff" /><rect x="1209.123287671233" y="5.089240961378341" width="3.4438356164383563" height="31.231703656898187" fill="#ff0000" /><rect x="1212.5671232876714" y="4.28861007702983" width="3.4438356164383563" height="105.71138992297017" fill="#4988b6" /><rect x="1212.5671232876714" y="37.30411385857077" width="3.4438356164383563" height="72.69588614142923" fill="#0000ff" /><rect x="1212.5671232876714" y="4.288610077029844" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="1216.0109589041097" y="4.0" width="3.4438356164383563" height="106.0" fill="#4988b6" /><rect x="1216.0109589041097" y="38.555312139720755" width="3.4438356164383563" height="71.44468786027925" fill="#0000ff" /><rect x="1216.0109589041097" y="3.999999999999993" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="1219.454794520548" y="4.260674653657716" width="3.4438356164383563" height="105.73932534634228" fill="#4988b6" /><rect x="1219.454794520548" y="40.06501708731274" width="3.4438356164383563" height="69.93498291268726" fill="#0000ff" /><rect x="1219.454794520548" y="4.260674653657709" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="1222.8986301369864" y="5.097095425208451" width="3.4438356164383563" height="104.90290457479155" fill="#4988b6" /><rect x="1222.8986301369864" y="41.8217389351108" width="3.4438356164383563" height="68.1782610648892" fill="#0000ff" /><rect x="1222.8986301369864" y="5.097095425208451" width="3.4438356164383563" height="36.72464350990235" fill="#ff0000" /><rect x="1226.3424657534247" y="6.523855483159764" width="3.4438356164383563" height="103.47614451684024" fill="#4988b6" /><rect x="1226.3424657534247" y="43.812107969115544" width="3.4438356164383563" height="66.18789203088446" fill="#0000ff" /><rect x="1226.3424657534247" y="6.523855483159764" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="1229.7863013698632" y="8.542931890882656" width="3.4438356164383563" height="101.45706810911734" fill="#4988b6" /><rect x="1229.7863013698632" y="46.02097627916049" width="3.4438356164383563" height="63.97902372083951" fill="#0000ff" /><rect x="1229.7863013698632" y="8.542931890882663" width="3.4438356164383563" height="37.47804438827783" fill="#ff0000" /><rect x="1233.2301369863014" y="11.143280557699256" width="3.4438356164383563" height="98.85671944230074" fill="#4988b6" /><rect x="1233.2301369863014" y="48.431533043655044" width="3.4438356164383563" height="61.568466956344956" fill="#0000ff" /><rect x="1233.2301369863014" y="11.143280557699264" width="3.4438356164383563" height="37.28825248595578" fill="#ff0000" /><rect x="1236.6739726027397" y="14.300788960185102" width="3.4438356164383563" height="95.6992110398149" fill="#4988b6" /><rect x="1236.6739726027397" y="51.02543247008745" width="3.4438356164383563" height="58.97456752991255" fill="#0000ff" /><rect x="1236.6739726027397" y="14.300788960185095" width="3.4438356164383563" height="36.72464350990236" fill="#ff0000" /><rect x="1240.1178082191782" y="17.978590983928214" width="3.4438356164383563" height="92.02140901607179" fill="#4988b6" /><rect x="1240.1178082191782" y="53.78293341758325" width="3.4438356164383563" height="56.21706658241675" fill="#0000ff" /><rect x="1240.1178082191782" y="17.97859098392822" width="3.4438356164383563" height="35.80434243365503" fill="#ff0000" /><rect x="1243.5616438356165" y="22.12773749918665" width="3.4438356164383563" height="87.87226250081335" fill="#4988b6" /><rect x="1243.5616438356165" y="56.68304963890741" width="3.4438356164383563" height="53.31695036109259" fill="#0000ff" /><rect x="1243.5616438356165" y="22.12773749918665" width="3.4438356164383563" height="34.55531213972076" fill="#ff0000" /><rect x="1247.005479452055" y="26.688205716936665" width="3.4438356164383563" height="83.31179428306334" fill="#4988b6" /><rect x="1247.005479452055" y="59.70370949847761" width="3.4438356164383563" height="50.29629050152239" fill="#0000ff" /><rect x="1247.005479452055" y="26.68820571693668" width="3.4438356164383563" height="33.01550378154093" fill="#ff0000" /><rect x="1250.4493150684932" y="31.59022029394002" width="3.4438356164383563" height="78.40977970605998" fill="#4988b6" /><rect x="1250.4493150684932" y="62.82192395083821" width="3.4438356164383563" height="47.17807604916179" fill="#0000ff" /><rect x="1250.4493150684932" y="31.590220293940018" width="3.4438356164383563" height="31.231703656898194" fill="#ff0000" /><rect x="1253.8931506849315" y="36.75584987124398" width="3.4438356164383563" height="73.24415012875602" fill="#4988b6" /><rect x="1253.8931506849315" y="66.01396150117739" width="3.4438356164383563" height="43.9860384988226" fill="#0000ff" /><rect x="1253.8931506849315" y="36.75584987124398" width="3.4438356164383563" height="29.25811162993341" fill="#ff0000" /><rect x="1257.33698630137" y="42.10083452063198" width="3.4438356164383563" height="67.89916547936802" fill="#4988b6" /><rect x="1257.33698630137" y="69.25552881633212" width="3.4438356164383563" height="40.74447118366788" fill="#0000ff" /><rect x="1257.33698630137" y="42.10083452063198" width="3.4438356164383563" height="27.154694295700143" fill="#ff0000" /><rect x="1260.7808219178082" y="47.53659268620362" width="3.4438356164383563" height="62.46340731379638" fill="#4988b6" /><rect x="1260.7808219178082" y="72.52195561172218" width="3.4438356164383563" height="37.47804438827783" fill="#0000ff" /><rect x="1260.7808219178082" y="47.536592686203626" width="3.4438356164383563" height="24.98536292551855" fill="#ff0000" /><rect x="1264.2246575342467" y="52.97235085177527" width="3.4438356164383563" height="57.02764914822473" fill="#4988b6" /><rect x="1264.2246575342467" y="75.78838240711224" width="3.4438356164383563" height="34.21161759288777" fill="#0000ff" /><rect x="1264.2246575342467" y="52.972350851775275" width="3.4438356164383563" height="22.81603155533696" fill="#ff0000" /><rect x="1267.668493150685" y="58.317335501163235" width="3.4438356164383563" height="51.682664498836765" fill="#4988b6" /><rect x="1267.668493150685" y="79.02994972226693" width="3.4438356164383563" height="30.970050277733062" fill="#0000ff" /><rect x="1267.668493150685" y="58.31733550116323" width="3.4438356164383563" height="20.712614221103703" fill="#ff0000" /><rect x="1271.1123287671232" y="63.48296507846722" width="3.4438356164383563" height="46.51703492153278" fill="#4988b6" /><rect x="1271.1123287671232" y="82.22198727260613" width="3.4438356164383563" height="27.778012727393868" fill="#0000ff" /><rect x="1271.1123287671232" y="63.48296507846722" width="3.4438356164383563" height="18.739022194138915" fill="#ff0000" /><rect x="1274.5561643835617" y="68.38497965547054" width="3.4438356164383563" height="41.615020344529455" fill="#4988b6" /><rect x="1274.5561643835617" y="85.34020172496673" width="3.4438356164383563" height="24.659798275033275" fill="#0000ff" /><rect x="1274.5561643835617" y="68.38497965547054" width="3.4438356164383563" height="16.95522206949618" fill="#ff0000" /><text x="20" text-anchor="start" y="125" font-family="Times, serif" fill="#000000" font-size="14px">2021-01-01</text><text x="1277" text-anchor="end" y="125" font-family="Times, serif" fill="#000000" font-size="14px">2021-12-31</text><text x="648.5" text-anchor="middle" y="125" font-family="Times, serif" fill="#000000" font-size="14px">Days</text><text x="17" text-anchor="end" y="3" font-family="Times, serif" fill="#000000" font-size="14px" transform="rotate(-90,17,3)">42</text><text x="17" text-anchor="start" y="109" font-family="Times, serif" fill="#000000" font-size="14px" transform="rotate(-90,17,109)">count</text><rect width="1279" height="127" x="0" y="0" fill-opacity="0.0" stroke="#000000" /></svg>

# %% [markdown]
# ## Simple Periodic Barchart Example

# %%
# Simple periodic barchart example

_timestamps, _types, _counts = [], [], []
_phase_0, _phase_1 = 90, 180
for _date in pd.date_range(start='2021-01-01', end='2021-01-13', freq='H'):
    _timestamps.append(_date)
    _types.     append('blue')
    _counts.    append(15 + cos(_phase_0 * pi/180)*15)

    _timestamps.append(_date)
    _types.     append('red')
    _counts.    append(10 + sin(_phase_1 * pi/180)*5)

    _phase_0 = (_phase_0 + 5)  % 360
    _phase_1 = (_phase_1 + 10) % 360

df = pd.DataFrame({'timestamp':_timestamps, 'type':_types, 'count':_counts})
rt.periodicBarChart(df, count_by='count', color_by='type', time_period='day_of_week_hour')

# %% [markdown]
# <svg id="periodicbarchart_27598" x="0" y="0" width="512" height="128" xmlns="http://www.w3.org/2000/svg"><rect width="511" height="127" x="0" y="0" fill="#ffffff" stroke="#ffffff" /><line x1="20" y1="111" x2="20"            y2="3" stroke="#101010" stroke-width="1" /><line x1="20" y1="111" x2="509" y2="111"      stroke="#101010" stroke-width="1" /><rect x="370.2857142857143" y="45.008920516454154" width="2.9107142857142856" height="64.99107948354585" fill="#4988b6" /><rect x="370.2857142857143" y="83.25882220620045" width="2.9107142857142856" height="26.741177793799555" fill="#0000ff" /><rect x="370.2857142857143" y="45.00892051645416" width="2.9107142857142856" height="38.24990168974629" fill="#ff0000" /><rect x="373.19642857142856" y="46.74476297782074" width="2.9107142857142856" height="63.25523702217926" fill="#4988b6" /><rect x="373.19642857142856" y="84.20875386789756" width="2.9107142857142856" height="25.79124613210244" fill="#0000ff" /><rect x="373.19642857142856" y="46.744762977820734" width="2.9107142857142856" height="37.46399089007682" fill="#ff0000" /><rect x="376.10714285714283" y="48.500911143682586" width="2.9107142857142856" height="61.499088856317414" fill="#4988b6" /><rect x="376.10714285714283" y="84.99602880146728" width="2.9107142857142856" height="25.003971198532724" fill="#0000ff" /><rect x="376.10714285714283" y="48.500911143682586" width="2.9107142857142856" height="36.49511765778469" fill="#ff0000" /><rect x="379.0178571428571" y="50.241934653535935" width="2.9107142857142856" height="59.758065346464065" fill="#4988b6" /><rect x="379.0178571428571" y="85.61465536929555" width="2.9107142857142856" height="24.38534463070445" fill="#0000ff" /><rect x="379.0178571428571" y="50.241934653535935" width="2.9107142857142856" height="35.37272071575961" fill="#ff0000" /><rect x="381.9285714285714" y="51.9290219225395" width="2.9107142857142856" height="58.0709780774605" fill="#4988b6" /><rect x="381.9285714285714" y="86.05992544966426" width="2.9107142857142856" height="23.940074550335744" fill="#0000ff" /><rect x="381.9285714285714" y="51.92902192253951" width="2.9107142857142856" height="34.13090352712475" fill="#ff0000" /><rect x="384.8392857142857" y="53.5210521896334" width="2.9107142857142856" height="56.4789478103666" fill="#4988b6" /><rect x="384.8392857142857" y="86.32845026840037" width="2.9107142857142856" height="23.671549731599626" fill="#0000ff" /><rect x="384.8392857142857" y="53.5210521896334" width="2.9107142857142856" height="32.80739807876697" fill="#ff0000" /><rect x="387.75" y="54.975767775485046" width="2.9107142857142856" height="55.024232224514954" fill="#4988b6" /><rect x="387.75" y="86.4181861894936" width="2.9107142857142856" height="23.581813810506404" fill="#0000ff" /><rect x="387.75" y="54.97576777548505" width="2.9107142857142856" height="31.442418414008547" fill="#ff0000" /><rect x="390.6607142857143" y="56.25101151915025" width="2.9107142857142856" height="53.74898848084975" fill="#4988b6" /><rect x="390.6607142857143" y="86.32845026840037" width="2.9107142857142856" height="23.671549731599626" fill="#0000ff" /><rect x="390.6607142857143" y="56.25101151915025" width="2.9107142857142856" height="30.077438749250117" fill="#ff0000" /><rect x="393.57142857142856" y="57.30599214877193" width="2.9107142857142856" height="52.69400785122807" fill="#4988b6" /><rect x="393.57142857142856" y="86.05992544966426" width="2.9107142857142856" height="23.94007455033573" fill="#0000ff" /><rect x="393.57142857142856" y="57.30599214877192" width="2.9107142857142856" height="28.753933300892342" fill="#ff0000" /><rect x="396.48214285714283" y="58.10253925703806" width="2.9107142857142856" height="51.89746074296194" fill="#4988b6" /><rect x="396.48214285714283" y="85.61465536929555" width="2.9107142857142856" height="24.38534463070446" fill="#0000ff" /><rect x="396.48214285714283" y="58.102539257038075" width="2.9107142857142856" height="27.512116112257477" fill="#ff0000" /><rect x="399.3928571428571" y="58.60630963123487" width="2.9107142857142856" height="51.39369036876513" fill="#4988b6" /><rect x="399.3928571428571" y="84.99602880146728" width="2.9107142857142856" height="25.003971198532728" fill="#0000ff" /><rect x="399.3928571428571" y="58.60630963123488" width="2.9107142857142856" height="26.3897191702324" fill="#ff0000" /><rect x="402.3035714285714" y="58.78790792995727" width="2.9107142857142856" height="51.21209207004273" fill="#4988b6" /><rect x="402.3035714285714" y="84.20875386789756" width="2.9107142857142856" height="25.791246132102447" fill="#0000ff" /><rect x="402.3035714285714" y="58.787907929957285" width="2.9107142857142856" height="25.420845937940275" fill="#ff0000" /><rect x="405.2142857142857" y="58.62388706792966" width="2.9107142857142856" height="51.37611293207034" fill="#4988b6" /><rect x="405.2142857142857" y="83.25882220620045" width="2.9107142857142856" height="26.74117779379955" fill="#0000ff" /><rect x="405.2142857142857" y="58.62388706792966" width="2.9107142857142856" height="24.634935138270794" fill="#ff0000" /><rect x="408.125" y="58.09759709672405" width="2.9107142857142856" height="51.90240290327595" fill="#4988b6" /><rect x="408.125" y="82.1534633699059" width="2.9107142857142856" height="27.846536630094104" fill="#0000ff" /><rect x="408.125" y="58.09759709672406" width="2.9107142857142856" height="24.055866273181838" fill="#ff0000" /><rect x="411.0357142857143" y="57.19985575007581" width="2.9107142857142856" height="52.80014424992419" fill="#4988b6" /><rect x="411.0357142857143" y="80.901089807192" width="2.9107142857142856" height="29.098910192808003" fill="#0000ff" /><rect x="411.0357142857143" y="57.19985575007581" width="2.9107142857142856" height="23.701234057116185" fill="#ff0000" /><rect x="413.94642857142856" y="55.92941902656843" width="2.9107142857142856" height="54.07058097343157" fill="#4988b6" /><rect x="413.94642857142856" y="79.51123283707483" width="2.9107142857142856" height="30.488767162925164" fill="#0000ff" /><rect x="413.94642857142856" y="55.929419026568425" width="2.9107142857142856" height="23.5818138105064" fill="#ff0000" /><rect x="416.85714285714283" y="54.29323605319944" width="2.9107142857142856" height="55.70676394680056" fill="#4988b6" /><rect x="416.85714285714283" y="77.99447011031563" width="2.9107142857142856" height="32.00552988968437" fill="#0000ff" /><rect x="416.85714285714283" y="54.29323605319944" width="2.9107142857142856" height="23.70123405711619" fill="#ff0000" /><rect x="419.7678571428571" y="52.30647883392948" width="2.9107142857142856" height="57.69352116607052" fill="#4988b6" /><rect x="419.7678571428571" y="76.36234510711134" width="2.9107142857142856" height="33.63765489288867" fill="#0000ff" /><rect x="419.7678571428571" y="52.306478833929496" width="2.9107142857142856" height="24.05586627318184" fill="#ff0000" /><rect x="422.6785714285714" y="49.99234414596959" width="2.9107142857142856" height="60.00765585403041" fill="#4988b6" /><rect x="422.6785714285714" y="74.62727928424039" width="2.9107142857142856" height="35.37272071575961" fill="#0000ff" /><rect x="422.6785714285714" y="49.9923441459696" width="2.9107142857142856" height="24.63493513827079" fill="#ff0000" /><rect x="425.5892857142857" y="47.38163160233594" width="2.9107142857142856" height="62.61836839766406" fill="#4988b6" /><rect x="425.5892857142857" y="72.80247754027621" width="2.9107142857142856" height="37.19752245972378" fill="#0000ff" /><rect x="425.5892857142857" y="47.38163160233593" width="2.9107142857142856" height="25.420845937940282" fill="#ff0000" /><rect x="428.5" y="44.51210854810343" width="2.9107142857142856" height="65.48789145189657" fill="#4988b6" /><rect x="428.5" y="70.90182771833582" width="2.9107142857142856" height="39.09817228166417" fill="#0000ff" /><rect x="428.5" y="44.51210854810343" width="2.9107142857142856" height="26.3897191702324" fill="#ff0000" /><rect x="431.4107142857143" y="41.427678798950424" width="2.9107142857142856" height="68.57232120104958" fill="#4988b6" /><rect x="431.4107142857143" y="68.9397949112079" width="2.9107142857142856" height="41.0602050887921" fill="#0000ff" /><rect x="431.4107142857143" y="41.427678798950424" width="2.9107142857142856" height="27.512116112257473" fill="#ff0000" /><rect x="434.32142857142856" y="38.177378072370146" width="2.9107142857142856" height="71.82262192762985" fill="#4988b6" /><rect x="434.32142857142856" y="66.93131137326247" width="2.9107142857142856" height="43.068688626737526" fill="#0000ff" /><rect x="434.32142857142856" y="38.17737807237014" width="2.9107142857142856" height="28.753933300892335" fill="#ff0000" /><rect x="437.23214285714283" y="34.814224127728735" width="2.9107142857142856" height="75.18577587227126" fill="#4988b6" /><rect x="437.23214285714283" y="64.89166287697886" width="2.9107142857142856" height="45.108337123021144" fill="#0000ff" /><rect x="437.23214285714283" y="34.81422412772874" width="2.9107142857142856" height="30.077438749250113" fill="#ff0000" /><rect x="90.85714285714286" y="45.008920516454154" width="2.9107142857142856" height="64.99107948354585" fill="#4988b6" /><rect x="90.85714285714286" y="83.25882220620045" width="2.9107142857142856" height="26.741177793799555" fill="#0000ff" /><rect x="90.85714285714286" y="45.00892051645416" width="2.9107142857142856" height="38.24990168974629" fill="#ff0000" /><rect x="93.76785714285714" y="46.74476297782074" width="2.9107142857142856" height="63.25523702217926" fill="#4988b6" /><rect x="93.76785714285714" y="84.20875386789756" width="2.9107142857142856" height="25.79124613210244" fill="#0000ff" /><rect x="93.76785714285714" y="46.744762977820734" width="2.9107142857142856" height="37.46399089007682" fill="#ff0000" /><rect x="96.67857142857143" y="48.500911143682586" width="2.9107142857142856" height="61.499088856317414" fill="#4988b6" /><rect x="96.67857142857143" y="84.99602880146728" width="2.9107142857142856" height="25.003971198532724" fill="#0000ff" /><rect x="96.67857142857143" y="48.500911143682586" width="2.9107142857142856" height="36.49511765778469" fill="#ff0000" /><rect x="99.58928571428571" y="50.241934653535935" width="2.9107142857142856" height="59.758065346464065" fill="#4988b6" /><rect x="99.58928571428571" y="85.61465536929555" width="2.9107142857142856" height="24.38534463070445" fill="#0000ff" /><rect x="99.58928571428571" y="50.241934653535935" width="2.9107142857142856" height="35.37272071575961" fill="#ff0000" /><rect x="102.5" y="51.9290219225395" width="2.9107142857142856" height="58.0709780774605" fill="#4988b6" /><rect x="102.5" y="86.05992544966426" width="2.9107142857142856" height="23.940074550335744" fill="#0000ff" /><rect x="102.5" y="51.92902192253951" width="2.9107142857142856" height="34.13090352712475" fill="#ff0000" /><rect x="105.41071428571428" y="53.5210521896334" width="2.9107142857142856" height="56.4789478103666" fill="#4988b6" /><rect x="105.41071428571428" y="86.32845026840037" width="2.9107142857142856" height="23.671549731599626" fill="#0000ff" /><rect x="105.41071428571428" y="53.5210521896334" width="2.9107142857142856" height="32.80739807876697" fill="#ff0000" /><rect x="108.32142857142857" y="54.975767775485046" width="2.9107142857142856" height="55.024232224514954" fill="#4988b6" /><rect x="108.32142857142857" y="86.4181861894936" width="2.9107142857142856" height="23.581813810506404" fill="#0000ff" /><rect x="108.32142857142857" y="54.97576777548505" width="2.9107142857142856" height="31.442418414008547" fill="#ff0000" /><rect x="111.23214285714285" y="56.25101151915025" width="2.9107142857142856" height="53.74898848084975" fill="#4988b6" /><rect x="111.23214285714285" y="86.32845026840037" width="2.9107142857142856" height="23.671549731599626" fill="#0000ff" /><rect x="111.23214285714285" y="56.25101151915025" width="2.9107142857142856" height="30.077438749250117" fill="#ff0000" /><rect x="114.14285714285714" y="57.30599214877193" width="2.9107142857142856" height="52.69400785122807" fill="#4988b6" /><rect x="114.14285714285714" y="86.05992544966426" width="2.9107142857142856" height="23.94007455033573" fill="#0000ff" /><rect x="114.14285714285714" y="57.30599214877192" width="2.9107142857142856" height="28.753933300892342" fill="#ff0000" /><rect x="117.05357142857143" y="58.10253925703806" width="2.9107142857142856" height="51.89746074296194" fill="#4988b6" /><rect x="117.05357142857143" y="85.61465536929555" width="2.9107142857142856" height="24.38534463070446" fill="#0000ff" /><rect x="117.05357142857143" y="58.102539257038075" width="2.9107142857142856" height="27.512116112257477" fill="#ff0000" /><rect x="119.96428571428571" y="58.60630963123487" width="2.9107142857142856" height="51.39369036876513" fill="#4988b6" /><rect x="119.96428571428571" y="84.99602880146728" width="2.9107142857142856" height="25.003971198532728" fill="#0000ff" /><rect x="119.96428571428571" y="58.60630963123488" width="2.9107142857142856" height="26.3897191702324" fill="#ff0000" /><rect x="122.875" y="58.78790792995727" width="2.9107142857142856" height="51.21209207004273" fill="#4988b6" /><rect x="122.875" y="84.20875386789756" width="2.9107142857142856" height="25.791246132102447" fill="#0000ff" /><rect x="122.875" y="58.787907929957285" width="2.9107142857142856" height="25.420845937940275" fill="#ff0000" /><rect x="125.78571428571428" y="58.62388706792966" width="2.9107142857142856" height="51.37611293207034" fill="#4988b6" /><rect x="125.78571428571428" y="83.25882220620045" width="2.9107142857142856" height="26.74117779379955" fill="#0000ff" /><rect x="125.78571428571428" y="58.62388706792966" width="2.9107142857142856" height="24.634935138270794" fill="#ff0000" /><rect x="128.69642857142856" y="58.09759709672405" width="2.9107142857142856" height="51.90240290327595" fill="#4988b6" /><rect x="128.69642857142856" y="82.1534633699059" width="2.9107142857142856" height="27.846536630094104" fill="#0000ff" /><rect x="128.69642857142856" y="58.09759709672406" width="2.9107142857142856" height="24.055866273181838" fill="#ff0000" /><rect x="131.60714285714283" y="57.19985575007581" width="2.9107142857142856" height="52.80014424992419" fill="#4988b6" /><rect x="131.60714285714283" y="80.901089807192" width="2.9107142857142856" height="29.098910192808003" fill="#0000ff" /><rect x="131.60714285714283" y="57.19985575007581" width="2.9107142857142856" height="23.701234057116185" fill="#ff0000" /><rect x="134.51785714285714" y="55.92941902656843" width="2.9107142857142856" height="54.07058097343157" fill="#4988b6" /><rect x="134.51785714285714" y="79.51123283707483" width="2.9107142857142856" height="30.488767162925164" fill="#0000ff" /><rect x="134.51785714285714" y="55.929419026568425" width="2.9107142857142856" height="23.5818138105064" fill="#ff0000" /><rect x="137.42857142857142" y="54.29323605319944" width="2.9107142857142856" height="55.70676394680056" fill="#4988b6" /><rect x="137.42857142857142" y="77.99447011031563" width="2.9107142857142856" height="32.00552988968437" fill="#0000ff" /><rect x="137.42857142857142" y="54.29323605319944" width="2.9107142857142856" height="23.70123405711619" fill="#ff0000" /><rect x="140.33928571428572" y="52.30647883392948" width="2.9107142857142856" height="57.69352116607052" fill="#4988b6" /><rect x="140.33928571428572" y="76.36234510711134" width="2.9107142857142856" height="33.63765489288867" fill="#0000ff" /><rect x="140.33928571428572" y="52.306478833929496" width="2.9107142857142856" height="24.05586627318184" fill="#ff0000" /><rect x="143.25" y="49.99234414596959" width="2.9107142857142856" height="60.00765585403041" fill="#4988b6" /><rect x="143.25" y="74.62727928424039" width="2.9107142857142856" height="35.37272071575961" fill="#0000ff" /><rect x="143.25" y="49.9923441459696" width="2.9107142857142856" height="24.63493513827079" fill="#ff0000" /><rect x="146.16071428571428" y="47.38163160233594" width="2.9107142857142856" height="62.61836839766406" fill="#4988b6" /><rect x="146.16071428571428" y="72.80247754027621" width="2.9107142857142856" height="37.19752245972378" fill="#0000ff" /><rect x="146.16071428571428" y="47.38163160233593" width="2.9107142857142856" height="25.420845937940282" fill="#ff0000" /><rect x="149.07142857142856" y="44.51210854810343" width="2.9107142857142856" height="65.48789145189657" fill="#4988b6" /><rect x="149.07142857142856" y="70.90182771833582" width="2.9107142857142856" height="39.09817228166417" fill="#0000ff" /><rect x="149.07142857142856" y="44.51210854810343" width="2.9107142857142856" height="26.3897191702324" fill="#ff0000" /><rect x="151.98214285714286" y="41.427678798950424" width="2.9107142857142856" height="68.57232120104958" fill="#4988b6" /><rect x="151.98214285714286" y="68.9397949112079" width="2.9107142857142856" height="41.0602050887921" fill="#0000ff" /><rect x="151.98214285714286" y="41.427678798950424" width="2.9107142857142856" height="27.512116112257473" fill="#ff0000" /><rect x="154.89285714285714" y="38.177378072370146" width="2.9107142857142856" height="71.82262192762985" fill="#4988b6" /><rect x="154.89285714285714" y="66.93131137326247" width="2.9107142857142856" height="43.068688626737526" fill="#0000ff" /><rect x="154.89285714285714" y="38.17737807237014" width="2.9107142857142856" height="28.753933300892335" fill="#ff0000" /><rect x="157.80357142857142" y="34.814224127728735" width="2.9107142857142856" height="75.18577587227126" fill="#4988b6" /><rect x="157.80357142857142" y="64.89166287697886" width="2.9107142857142856" height="45.108337123021144" fill="#0000ff" /><rect x="157.80357142857142" y="34.81422412772874" width="2.9107142857142856" height="30.077438749250113" fill="#ff0000" /><rect x="440.1428571428571" y="31.393953964978635" width="2.9107142857142856" height="78.60604603502136" fill="#4988b6" /><rect x="440.1428571428571" y="62.83637237898718" width="2.9107142857142856" height="47.16362762101282" fill="#0000ff" /><rect x="440.1428571428571" y="31.393953964978635" width="2.9107142857142856" height="31.442418414008543" fill="#ff0000" /><rect x="443.0535714285714" y="27.97368380222855" width="2.9107142857142856" height="82.02631619777145" fill="#4988b6" /><rect x="443.0535714285714" y="60.78108188099552" width="2.9107142857142856" height="49.21891811900448" fill="#0000ff" /><rect x="443.0535714285714" y="27.97368380222855" width="2.9107142857142856" height="32.80739807876697" fill="#ff0000" /><rect x="445.9642857142857" y="24.61052985758714" width="2.9107142857142856" height="85.38947014241286" fill="#4988b6" /><rect x="445.9642857142857" y="58.7414333847119" width="2.9107142857142856" height="51.2585666152881" fill="#0000ff" /><rect x="445.9642857142857" y="24.610529857587146" width="2.9107142857142856" height="34.13090352712475" fill="#ff0000" /><rect x="448.875" y="21.36022913100686" width="2.9107142857142856" height="88.63977086899314" fill="#4988b6" /><rect x="448.875" y="56.73294984676648" width="2.9107142857142856" height="53.26705015323352" fill="#0000ff" /><rect x="448.875" y="21.360229131006868" width="2.9107142857142856" height="35.37272071575961" fill="#ff0000" /><rect x="451.7857142857143" y="18.275799381853872" width="2.9107142857142856" height="91.72420061814613" fill="#4988b6" /><rect x="451.7857142857143" y="54.77091703963856" width="2.9107142857142856" height="55.22908296036144" fill="#0000ff" /><rect x="451.7857142857143" y="18.27579938185388" width="2.9107142857142856" height="36.49511765778468" fill="#ff0000" /><rect x="454.69642857142856" y="15.406276327621327" width="2.9107142857142856" height="94.59372367237867" fill="#4988b6" /><rect x="454.69642857142856" y="52.87026721769814" width="2.9107142857142856" height="57.12973278230186" fill="#0000ff" /><rect x="454.69642857142856" y="15.406276327621327" width="2.9107142857142856" height="37.463990890076815" fill="#ff0000" /><rect x="457.60714285714283" y="12.795563783987689" width="2.9107142857142856" height="97.20443621601231" fill="#4988b6" /><rect x="457.60714285714283" y="51.04546547373399" width="2.9107142857142856" height="58.95453452626601" fill="#0000ff" /><rect x="457.60714285714283" y="12.795563783987689" width="2.9107142857142856" height="38.2499016897463" fill="#ff0000" /><rect x="460.5178571428571" y="10.481429096027796" width="2.9107142857142856" height="99.5185709039722" fill="#4988b6" /><rect x="460.5178571428571" y="49.31039965086304" width="2.9107142857142856" height="60.68960034913696" fill="#0000ff" /><rect x="460.5178571428571" y="10.481429096027789" width="2.9107142857142856" height="38.82897055483525" fill="#ff0000" /><rect x="463.4285714285714" y="8.494671876757835" width="2.9107142857142856" height="101.50532812324217" fill="#4988b6" /><rect x="463.4285714285714" y="47.678274647658746" width="2.9107142857142856" height="62.321725352341254" fill="#0000ff" /><rect x="463.4285714285714" y="8.494671876757835" width="2.9107142857142856" height="39.18360277090091" fill="#ff0000" /><rect x="466.3392857142857" y="6.858488903388846" width="2.9107142857142856" height="103.14151109661115" fill="#4988b6" /><rect x="466.3392857142857" y="46.16151192089953" width="2.9107142857142856" height="63.83848807910047" fill="#0000ff" /><rect x="466.3392857142857" y="6.858488903388846" width="2.9107142857142856" height="39.30302301751068" fill="#ff0000" /><rect x="469.25" y="5.588052179881458" width="2.9107142857142856" height="104.41194782011854" fill="#4988b6" /><rect x="469.25" y="44.77165495078238" width="2.9107142857142856" height="65.22834504921762" fill="#0000ff" /><rect x="469.25" y="5.588052179881473" width="2.9107142857142856" height="39.183602770900904" fill="#ff0000" /><rect x="472.1607142857143" y="4.690310833233241" width="2.9107142857142856" height="105.30968916676676" fill="#4988b6" /><rect x="472.1607142857143" y="43.51928138806849" width="2.9107142857142856" height="66.48071861193151" fill="#0000ff" /><rect x="472.1607142857143" y="4.690310833233255" width="2.9107142857142856" height="38.82897055483524" fill="#ff0000" /><rect x="475.07142857142856" y="4.1640208620275985" width="2.9107142857142856" height="105.8359791379724" fill="#4988b6" /><rect x="475.07142857142856" y="42.413922551773894" width="2.9107142857142856" height="67.5860774482261" fill="#0000ff" /><rect x="475.07142857142856" y="4.164020862027584" width="2.9107142857142856" height="38.24990168974631" fill="#ff0000" /><rect x="477.98214285714283" y="4.0" width="2.9107142857142856" height="106.0" fill="#4988b6" /><rect x="477.98214285714283" y="41.4639908900768" width="2.9107142857142856" height="68.5360091099232" fill="#0000ff" /><rect x="477.98214285714283" y="3.999999999999986" width="2.9107142857142856" height="37.463990890076815" fill="#ff0000" /><rect x="480.8928571428571" y="4.181598298722406" width="2.9107142857142856" height="105.8184017012776" fill="#4988b6" /><rect x="480.8928571428571" y="40.676715956507095" width="2.9107142857142856" height="69.3232840434929" fill="#0000ff" /><rect x="480.8928571428571" y="4.181598298722413" width="2.9107142857142856" height="36.49511765778468" fill="#ff0000" /><rect x="483.8035714285714" y="4.685368672919196" width="2.9107142857142856" height="105.3146313270808" fill="#4988b6" /><rect x="483.8035714285714" y="40.05808938867881" width="2.9107142857142856" height="69.94191061132119" fill="#0000ff" /><rect x="483.8035714285714" y="4.685368672919196" width="2.9107142857142856" height="35.37272071575961" fill="#ff0000" /><rect x="486.71428571428567" y="5.481915781185364" width="2.9107142857142856" height="104.51808421881464" fill="#4988b6" /><rect x="486.71428571428567" y="39.61281930831012" width="2.9107142857142856" height="70.38718069168988" fill="#0000ff" /><rect x="486.71428571428567" y="5.481915781185364" width="2.9107142857142856" height="34.13090352712476" fill="#ff0000" /><rect x="489.625" y="6.536896410807003" width="2.9107142857142856" height="103.463103589193" fill="#4988b6" /><rect x="489.625" y="39.34429448957398" width="2.9107142857142856" height="70.65570551042602" fill="#0000ff" /><rect x="489.625" y="6.536896410807003" width="2.9107142857142856" height="32.80739807876698" fill="#ff0000" /><rect x="492.5357142857143" y="7.812140154472232" width="2.9107142857142856" height="102.18785984552777" fill="#4988b6" /><rect x="492.5357142857143" y="39.254558568480775" width="2.9107142857142856" height="70.74544143151923" fill="#0000ff" /><rect x="492.5357142857143" y="7.812140154472228" width="2.9107142857142856" height="31.442418414008547" fill="#ff0000" /><rect x="495.44642857142856" y="9.26685574032389" width="2.9107142857142856" height="100.73314425967611" fill="#4988b6" /><rect x="495.44642857142856" y="39.344294489574" width="2.9107142857142856" height="70.655705510426" fill="#0000ff" /><rect x="495.44642857142856" y="9.26685574032388" width="2.9107142857142856" height="30.077438749250117" fill="#ff0000" /><rect x="498.35714285714283" y="10.858886007417766" width="2.9107142857142856" height="99.14111399258223" fill="#4988b6" /><rect x="498.35714285714283" y="39.61281930831011" width="2.9107142857142856" height="70.38718069168989" fill="#0000ff" /><rect x="498.35714285714283" y="10.85888600741777" width="2.9107142857142856" height="28.75393330089234" fill="#ff0000" /><rect x="501.2678571428571" y="12.54597327642135" width="2.9107142857142856" height="97.45402672357865" fill="#4988b6" /><rect x="501.2678571428571" y="40.05808938867882" width="2.9107142857142856" height="69.94191061132118" fill="#0000ff" /><rect x="501.2678571428571" y="12.545973276421346" width="2.9107142857142856" height="27.512116112257477" fill="#ff0000" /><rect x="504.1785714285714" y="14.286996786274685" width="2.9107142857142856" height="95.71300321372532" fill="#4988b6" /><rect x="504.1785714285714" y="40.67671595650708" width="2.9107142857142856" height="69.32328404349292" fill="#0000ff" /><rect x="504.1785714285714" y="14.286996786274678" width="2.9107142857142856" height="26.389719170232404" fill="#ff0000" /><rect x="507.08928571428567" y="16.04314495213653" width="2.9107142857142856" height="93.95685504786347" fill="#4988b6" /><rect x="507.08928571428567" y="41.463990890076815" width="2.9107142857142856" height="68.53600910992319" fill="#0000ff" /><rect x="507.08928571428567" y="16.04314495213654" width="2.9107142857142856" height="25.420845937940275" fill="#ff0000" /><rect x="21.0" y="17.77898741350313" width="2.9107142857142856" height="92.22101258649687" fill="#4988b6" /><rect x="21.0" y="42.41392255177392" width="2.9107142857142856" height="67.58607744822608" fill="#0000ff" /><rect x="21.0" y="17.778987413503135" width="2.9107142857142856" height="24.634935138270787" fill="#ff0000" /><rect x="23.910714285714285" y="19.46341511488663" width="2.9107142857142856" height="90.53658488511337" fill="#4988b6" /><rect x="23.910714285714285" y="43.51928138806848" width="2.9107142857142856" height="66.48071861193152" fill="#0000ff" /><rect x="23.910714285714285" y="19.46341511488663" width="2.9107142857142856" height="24.05586627318185" fill="#ff0000" /><rect x="26.82142857142857" y="21.07042089366618" width="2.9107142857142856" height="88.92957910633382" fill="#4988b6" /><rect x="26.82142857142857" y="44.77165495078238" width="2.9107142857142856" height="65.22834504921762" fill="#0000ff" /><rect x="26.82142857142857" y="21.07042089366619" width="2.9107142857142856" height="23.70123405711619" fill="#ff0000" /><rect x="29.732142857142858" y="22.57969811039311" width="2.9107142857142856" height="87.42030188960689" fill="#4988b6" /><rect x="29.732142857142858" y="46.16151192089952" width="2.9107142857142856" height="63.83848807910048" fill="#0000ff" /><rect x="29.732142857142858" y="22.579698110393114" width="2.9107142857142856" height="23.581813810506407" fill="#ff0000" /><rect x="32.64285714285714" y="23.977040590542543" width="2.9107142857142856" height="86.02295940945746" fill="#4988b6" /><rect x="32.64285714285714" y="47.67827464765873" width="2.9107142857142856" height="62.32172535234127" fill="#0000ff" /><rect x="32.64285714285714" y="23.977040590542536" width="2.9107142857142856" height="23.701234057116196" fill="#ff0000" /><rect x="35.55357142857143" y="25.254533377681184" width="2.9107142857142856" height="84.74546662231882" fill="#4988b6" /><rect x="35.55357142857143" y="49.31039965086303" width="2.9107142857142856" height="60.68960034913697" fill="#0000ff" /><rect x="35.55357142857143" y="25.254533377681188" width="2.9107142857142856" height="24.055866273181845" fill="#ff0000" /><rect x="38.464285714285715" y="26.410530335463193" width="2.9107142857142856" height="83.58946966453681" fill="#4988b6" /><rect x="38.464285714285715" y="51.045465473733984" width="2.9107142857142856" height="58.954534526266016" fill="#0000ff" /><rect x="38.464285714285715" y="26.410530335463196" width="2.9107142857142856" height="24.634935138270787" fill="#ff0000" /><rect x="41.375" y="27.449421279757857" width="2.9107142857142856" height="82.55057872024214" fill="#4988b6" /><rect x="41.375" y="52.870267217698135" width="2.9107142857142856" height="57.129732782301865" fill="#0000ff" /><rect x="41.375" y="27.449421279757853" width="2.9107142857142856" height="25.420845937940282" fill="#ff0000" /><rect x="44.285714285714285" y="28.38119786940615" width="2.9107142857142856" height="81.61880213059385" fill="#4988b6" /><rect x="44.285714285714285" y="54.770917039638555" width="2.9107142857142856" height="55.229082960361445" fill="#0000ff" /><rect x="44.285714285714285" y="28.381197869406154" width="2.9107142857142856" height="26.3897191702324" fill="#ff0000" /><rect x="47.19642857142857" y="29.220833734509" width="2.9107142857142856" height="80.779166265491" fill="#4988b6" /><rect x="47.19642857142857" y="56.73294984676647" width="2.9107142857142856" height="53.26705015323353" fill="#0000ff" /><rect x="47.19642857142857" y="29.220833734508997" width="2.9107142857142856" height="27.512116112257477" fill="#ff0000" /><rect x="50.107142857142854" y="29.987500083819555" width="2.9107142857142856" height="80.01249991618045" fill="#4988b6" /><rect x="50.107142857142854" y="58.74143338471188" width="2.9107142857142856" height="51.25856661528812" fill="#0000ff" /><rect x="50.107142857142854" y="29.987500083819548" width="2.9107142857142856" height="28.753933300892335" fill="#ff0000" /><rect x="53.01785714285714" y="30.703643131745395" width="2.9107142857142856" height="79.2963568682546" fill="#4988b6" /><rect x="53.01785714285714" y="60.78108188099551" width="2.9107142857142856" height="49.21891811900449" fill="#0000ff" /><rect x="53.01785714285714" y="30.703643131745395" width="2.9107142857142856" height="30.077438749250113" fill="#ff0000" /><rect x="55.92857142857143" y="31.393953964978635" width="2.9107142857142856" height="78.60604603502136" fill="#4988b6" /><rect x="55.92857142857143" y="62.83637237898718" width="2.9107142857142856" height="47.16362762101282" fill="#0000ff" /><rect x="55.92857142857143" y="31.393953964978635" width="2.9107142857142856" height="31.442418414008543" fill="#ff0000" /><rect x="58.839285714285715" y="32.084264798211876" width="2.9107142857142856" height="77.91573520178812" fill="#4988b6" /><rect x="58.839285714285715" y="64.89166287697884" width="2.9107142857142856" height="45.10833712302116" fill="#0000ff" /><rect x="58.839285714285715" y="32.08426479821187" width="2.9107142857142856" height="32.80739807876697" fill="#ff0000" /><rect x="61.75" y="32.80040784613773" width="2.9107142857142856" height="77.19959215386227" fill="#4988b6" /><rect x="61.75" y="66.93131137326247" width="2.9107142857142856" height="43.068688626737526" fill="#0000ff" /><rect x="61.75" y="32.80040784613772" width="2.9107142857142856" height="34.13090352712475" fill="#ff0000" /><rect x="64.66071428571428" y="33.56707419544827" width="2.9107142857142856" height="76.43292580455173" fill="#4988b6" /><rect x="64.66071428571428" y="68.93979491120788" width="2.9107142857142856" height="41.06020508879212" fill="#0000ff" /><rect x="64.66071428571428" y="33.567074195448264" width="2.9107142857142856" height="35.37272071575962" fill="#ff0000" /><rect x="67.57142857142857" y="34.40671006055112" width="2.9107142857142856" height="75.59328993944888" fill="#4988b6" /><rect x="67.57142857142857" y="70.90182771833582" width="2.9107142857142856" height="39.09817228166418" fill="#0000ff" /><rect x="67.57142857142857" y="34.406710060551134" width="2.9107142857142856" height="36.49511765778469" fill="#ff0000" /><rect x="70.48214285714286" y="35.338486650199414" width="2.9107142857142856" height="74.66151334980059" fill="#4988b6" /><rect x="70.48214285714286" y="72.80247754027621" width="2.9107142857142856" height="37.19752245972378" fill="#0000ff" /><rect x="70.48214285714286" y="35.33848665019941" width="2.9107142857142856" height="37.46399089007681" fill="#ff0000" /><rect x="73.39285714285714" y="36.37737759449408" width="2.9107142857142856" height="73.62262240550592" fill="#4988b6" /><rect x="73.39285714285714" y="74.62727928424039" width="2.9107142857142856" height="35.37272071575961" fill="#0000ff" /><rect x="73.39285714285714" y="36.377377594494085" width="2.9107142857142856" height="38.2499016897463" fill="#ff0000" /><rect x="76.30357142857142" y="37.533374552276086" width="2.9107142857142856" height="72.46662544772391" fill="#4988b6" /><rect x="76.30357142857142" y="76.36234510711134" width="2.9107142857142856" height="33.63765489288867" fill="#0000ff" /><rect x="76.30357142857142" y="37.53337455227609" width="2.9107142857142856" height="38.828970554835244" fill="#ff0000" /><rect x="79.21428571428571" y="38.81086733941471" width="2.9107142857142856" height="71.18913266058529" fill="#4988b6" /><rect x="79.21428571428571" y="77.99447011031562" width="2.9107142857142856" height="32.00552988968438" fill="#0000ff" /><rect x="79.21428571428571" y="38.81086733941472" width="2.9107142857142856" height="39.1836027709009" fill="#ff0000" /><rect x="82.125" y="40.20820981956416" width="2.9107142857142856" height="69.79179018043584" fill="#4988b6" /><rect x="82.125" y="79.51123283707484" width="2.9107142857142856" height="30.488767162925157" fill="#0000ff" /><rect x="82.125" y="40.20820981956416" width="2.9107142857142856" height="39.30302301751068" fill="#ff0000" /><rect x="85.03571428571428" y="41.717487036291075" width="2.9107142857142856" height="68.28251296370892" fill="#4988b6" /><rect x="85.03571428571428" y="80.90108980719198" width="2.9107142857142856" height="29.098910192808017" fill="#0000ff" /><rect x="85.03571428571428" y="41.71748703629106" width="2.9107142857142856" height="39.18360277090092" fill="#ff0000" /><rect x="87.94642857142857" y="43.32449281507064" width="2.9107142857142856" height="66.67550718492936" fill="#4988b6" /><rect x="87.94642857142857" y="82.1534633699059" width="2.9107142857142856" height="27.84653663009411" fill="#0000ff" /><rect x="87.94642857142857" y="43.32449281507065" width="2.9107142857142856" height="38.828970554835244" fill="#ff0000" /><rect x="300.42857142857144" y="70.69697698248932" width="2.9107142857142856" height="39.30302301751068" fill="#4988b6" /><rect x="300.42857142857144" y="86.41818618949358" width="2.9107142857142856" height="23.58181381050641" fill="#0000ff" /><rect x="300.42857142857144" y="70.6969769824893" width="2.9107142857142856" height="15.721209207004271" fill="#ff0000" /><rect x="303.3392857142857" y="74.11724714523942" width="2.9107142857142856" height="35.88275285476058" fill="#4988b6" /><rect x="303.3392857142857" y="88.47347668748526" width="2.9107142857142856" height="21.52652331251474" fill="#0000ff" /><rect x="303.3392857142857" y="74.11724714523942" width="2.9107142857142856" height="14.356229542245842" fill="#ff0000" /><rect x="306.25" y="77.48040108988081" width="2.9107142857142856" height="32.519598910119186" fill="#4988b6" /><rect x="306.25" y="90.51312518376888" width="2.9107142857142856" height="19.486874816231122" fill="#0000ff" /><rect x="306.25" y="77.48040108988081" width="2.9107142857142856" height="13.032724093888062" fill="#ff0000" /><rect x="309.1607142857143" y="80.73070181646109" width="2.9107142857142856" height="29.269298183538908" fill="#4988b6" /><rect x="309.1607142857143" y="92.5216087217143" width="2.9107142857142856" height="17.478391278285702" fill="#0000ff" /><rect x="309.1607142857143" y="80.73070181646109" width="2.9107142857142856" height="11.790906905253204" fill="#ff0000" /><rect x="312.07142857142856" y="83.8151315656141" width="2.9107142857142856" height="26.1848684343859" fill="#4988b6" /><rect x="312.07142857142856" y="94.48364152884223" width="2.9107142857142856" height="15.516358471157773" fill="#0000ff" /><rect x="312.07142857142856" y="83.8151315656141" width="2.9107142857142856" height="10.668509963228129" fill="#ff0000" /><rect x="314.98214285714283" y="86.68465461984663" width="2.9107142857142856" height="23.315345380153378" fill="#4988b6" /><rect x="314.98214285714283" y="96.38429135078263" width="2.9107142857142856" height="13.615708649217375" fill="#0000ff" /><rect x="314.98214285714283" y="86.68465461984663" width="2.9107142857142856" height="9.699636730936005" fill="#ff0000" /><rect x="317.8928571428571" y="89.29536716348028" width="2.9107142857142856" height="20.70463283651973" fill="#4988b6" /><rect x="317.8928571428571" y="98.20909309474679" width="2.9107142857142856" height="11.79090690525321" fill="#0000ff" /><rect x="317.8928571428571" y="89.29536716348028" width="2.9107142857142856" height="8.913725931266518" fill="#ff0000" /><rect x="320.8035714285714" y="91.60950185144016" width="2.9107142857142856" height="18.39049814855984" fill="#4988b6" /><rect x="320.8035714285714" y="99.94415891761774" width="2.9107142857142856" height="10.055841082382264" fill="#0000ff" /><rect x="320.8035714285714" y="91.60950185144017" width="2.9107142857142856" height="8.334657066177575" fill="#ff0000" /><rect x="323.7142857142857" y="93.59625907071012" width="2.9107142857142856" height="16.40374092928989" fill="#4988b6" /><rect x="323.7142857142857" y="101.57628392082202" width="2.9107142857142856" height="8.423716079177971" fill="#0000ff" /><rect x="323.7142857142857" y="93.5962590707101" width="2.9107142857142856" height="7.980024850111915" fill="#ff0000" /><rect x="326.625" y="95.23244204407911" width="2.9107142857142856" height="14.767557955920887" fill="#4988b6" /><rect x="326.625" y="103.09304664758125" width="2.9107142857142856" height="6.906953352418751" fill="#0000ff" /><rect x="326.625" y="95.23244204407911" width="2.9107142857142856" height="7.860604603502136" fill="#ff0000" /><rect x="329.5357142857143" y="96.50287876758648" width="2.9107142857142856" height="13.49712123241352" fill="#4988b6" /><rect x="329.5357142857143" y="104.4829036176984" width="2.9107142857142856" height="5.517096382301606" fill="#0000ff" /><rect x="329.5357142857143" y="96.50287876758648" width="2.9107142857142856" height="7.980024850111915" fill="#ff0000" /><rect x="332.44642857142856" y="97.40062011423473" width="2.9107142857142856" height="12.59937988576528" fill="#4988b6" /><rect x="332.44642857142856" y="105.7352771804123" width="2.9107142857142856" height="4.264722819587709" fill="#0000ff" /><rect x="332.44642857142856" y="97.40062011423473" width="2.9107142857142856" height="8.334657066177572" fill="#ff0000" /><rect x="335.35714285714283" y="97.92691008544034" width="2.9107142857142856" height="12.073089914559661" fill="#4988b6" /><rect x="335.35714285714283" y="106.84063601670685" width="2.9107142857142856" height="3.1593639832931433" fill="#0000ff" /><rect x="335.35714285714283" y="97.92691008544034" width="2.9107142857142856" height="8.913725931266518" fill="#ff0000" /><rect x="338.2678571428571" y="98.09093094746797" width="2.9107142857142856" height="11.909069052532038" fill="#4988b6" /><rect x="338.2678571428571" y="107.79056767840396" width="2.9107142857142856" height="2.2094323215960348" fill="#0000ff" /><rect x="338.2678571428571" y="98.09093094746795" width="2.9107142857142856" height="9.699636730936003" fill="#ff0000" /><rect x="341.1785714285714" y="97.90933264874556" width="2.9107142857142856" height="12.09066735125444" fill="#4988b6" /><rect x="341.1785714285714" y="108.57784261197368" width="2.9107142857142856" height="1.4221573880263152" fill="#0000ff" /><rect x="341.1785714285714" y="97.90933264874556" width="2.9107142857142856" height="10.668509963228125" fill="#ff0000" /><rect x="344.0892857142857" y="97.40556227454876" width="2.9107142857142856" height="12.594437725451247" fill="#4988b6" /><rect x="344.0892857142857" y="98.2090930947468" width="2.9107142857142856" height="11.790906905253202" fill="#ff0000" /><rect x="347.0" y="96.6090151662826" width="2.9107142857142856" height="13.390984833717399" fill="#4988b6" /><rect x="347.0" y="96.96727590611194" width="2.9107142857142856" height="13.032724093888062" fill="#ff0000" /><rect x="349.9107142857143" y="95.55403453666094" width="2.9107142857142856" height="14.445965463339059" fill="#4988b6" /><rect x="349.9107142857143" y="95.64377045775416" width="2.9107142857142856" height="14.356229542245837" fill="#ff0000" /><rect x="352.82142857142856" y="94.27879079299572" width="2.9107142857142856" height="15.721209207004273" fill="#4988b6" /><rect x="352.82142857142856" y="94.27879079299572" width="2.9107142857142856" height="15.721209207004273" fill="#ff0000" /><rect x="355.73214285714283" y="92.82407520714408" width="2.9107142857142856" height="17.175924792855923" fill="#4988b6" /><rect x="355.73214285714283" y="92.9138111282373" width="2.9107142857142856" height="17.086188871762705" fill="#ff0000" /><rect x="358.6428571428571" y="91.23204494005017" width="2.9107142857142856" height="18.76795505994982" fill="#4988b6" /><rect x="358.6428571428571" y="91.59030567987952" width="2.9107142857142856" height="18.409694320120483" fill="#ff0000" /><rect x="361.5535714285714" y="89.54495767104662" width="2.9107142857142856" height="20.45504232895338" fill="#4988b6" /><rect x="361.5535714285714" y="90.34848849124467" width="2.9107142857142856" height="19.65151150875534" fill="#ff0000" /><rect x="364.4642857142857" y="87.80393416119327" width="2.9107142857142856" height="22.19606583880673" fill="#4988b6" /><rect x="364.4642857142857" y="108.5778426119737" width="2.9107142857142856" height="1.4221573880263125" fill="#0000ff" /><rect x="364.4642857142857" y="87.80393416119327" width="2.9107142857142856" height="20.77390845078042" fill="#ff0000" /><rect x="367.375" y="86.04778599533142" width="2.9107142857142856" height="23.952214004668573" fill="#4988b6" /><rect x="367.375" y="107.79056767840397" width="2.9107142857142856" height="2.2094323215960316" fill="#0000ff" /><rect x="367.375" y="86.04778599533144" width="2.9107142857142856" height="21.74278168307254" fill="#ff0000" /><rect x="160.71428571428572" y="31.393953964978635" width="2.9107142857142856" height="78.60604603502136" fill="#4988b6" /><rect x="160.71428571428572" y="62.83637237898718" width="2.9107142857142856" height="47.16362762101282" fill="#0000ff" /><rect x="160.71428571428572" y="31.393953964978635" width="2.9107142857142856" height="31.442418414008543" fill="#ff0000" /><rect x="163.625" y="27.97368380222855" width="2.9107142857142856" height="82.02631619777145" fill="#4988b6" /><rect x="163.625" y="60.78108188099552" width="2.9107142857142856" height="49.21891811900448" fill="#0000ff" /><rect x="163.625" y="27.97368380222855" width="2.9107142857142856" height="32.80739807876697" fill="#ff0000" /><rect x="166.53571428571428" y="24.61052985758714" width="2.9107142857142856" height="85.38947014241286" fill="#4988b6" /><rect x="166.53571428571428" y="58.7414333847119" width="2.9107142857142856" height="51.2585666152881" fill="#0000ff" /><rect x="166.53571428571428" y="24.610529857587146" width="2.9107142857142856" height="34.13090352712475" fill="#ff0000" /><rect x="169.44642857142856" y="21.36022913100686" width="2.9107142857142856" height="88.63977086899314" fill="#4988b6" /><rect x="169.44642857142856" y="56.73294984676648" width="2.9107142857142856" height="53.26705015323352" fill="#0000ff" /><rect x="169.44642857142856" y="21.360229131006868" width="2.9107142857142856" height="35.37272071575961" fill="#ff0000" /><rect x="172.35714285714286" y="18.275799381853872" width="2.9107142857142856" height="91.72420061814613" fill="#4988b6" /><rect x="172.35714285714286" y="54.77091703963856" width="2.9107142857142856" height="55.22908296036144" fill="#0000ff" /><rect x="172.35714285714286" y="18.27579938185388" width="2.9107142857142856" height="36.49511765778468" fill="#ff0000" /><rect x="175.26785714285714" y="15.406276327621327" width="2.9107142857142856" height="94.59372367237867" fill="#4988b6" /><rect x="175.26785714285714" y="52.87026721769814" width="2.9107142857142856" height="57.12973278230186" fill="#0000ff" /><rect x="175.26785714285714" y="15.406276327621327" width="2.9107142857142856" height="37.463990890076815" fill="#ff0000" /><rect x="178.17857142857142" y="12.795563783987689" width="2.9107142857142856" height="97.20443621601231" fill="#4988b6" /><rect x="178.17857142857142" y="51.04546547373399" width="2.9107142857142856" height="58.95453452626601" fill="#0000ff" /><rect x="178.17857142857142" y="12.795563783987689" width="2.9107142857142856" height="38.2499016897463" fill="#ff0000" /><rect x="181.0892857142857" y="10.481429096027796" width="2.9107142857142856" height="99.5185709039722" fill="#4988b6" /><rect x="181.0892857142857" y="49.31039965086304" width="2.9107142857142856" height="60.68960034913696" fill="#0000ff" /><rect x="181.0892857142857" y="10.481429096027789" width="2.9107142857142856" height="38.82897055483525" fill="#ff0000" /><rect x="184.0" y="8.494671876757835" width="2.9107142857142856" height="101.50532812324217" fill="#4988b6" /><rect x="184.0" y="47.678274647658746" width="2.9107142857142856" height="62.321725352341254" fill="#0000ff" /><rect x="184.0" y="8.494671876757835" width="2.9107142857142856" height="39.18360277090091" fill="#ff0000" /><rect x="186.91071428571428" y="6.858488903388846" width="2.9107142857142856" height="103.14151109661115" fill="#4988b6" /><rect x="186.91071428571428" y="46.16151192089953" width="2.9107142857142856" height="63.83848807910047" fill="#0000ff" /><rect x="186.91071428571428" y="6.858488903388846" width="2.9107142857142856" height="39.30302301751068" fill="#ff0000" /><rect x="189.82142857142856" y="5.588052179881458" width="2.9107142857142856" height="104.41194782011854" fill="#4988b6" /><rect x="189.82142857142856" y="44.77165495078238" width="2.9107142857142856" height="65.22834504921762" fill="#0000ff" /><rect x="189.82142857142856" y="5.588052179881473" width="2.9107142857142856" height="39.183602770900904" fill="#ff0000" /><rect x="192.73214285714286" y="4.690310833233241" width="2.9107142857142856" height="105.30968916676676" fill="#4988b6" /><rect x="192.73214285714286" y="43.51928138806849" width="2.9107142857142856" height="66.48071861193151" fill="#0000ff" /><rect x="192.73214285714286" y="4.690310833233255" width="2.9107142857142856" height="38.82897055483524" fill="#ff0000" /><rect x="195.64285714285714" y="4.1640208620275985" width="2.9107142857142856" height="105.8359791379724" fill="#4988b6" /><rect x="195.64285714285714" y="42.413922551773894" width="2.9107142857142856" height="67.5860774482261" fill="#0000ff" /><rect x="195.64285714285714" y="4.164020862027584" width="2.9107142857142856" height="38.24990168974631" fill="#ff0000" /><rect x="198.55357142857142" y="4.0" width="2.9107142857142856" height="106.0" fill="#4988b6" /><rect x="198.55357142857142" y="41.4639908900768" width="2.9107142857142856" height="68.5360091099232" fill="#0000ff" /><rect x="198.55357142857142" y="3.999999999999986" width="2.9107142857142856" height="37.463990890076815" fill="#ff0000" /><rect x="201.4642857142857" y="4.181598298722406" width="2.9107142857142856" height="105.8184017012776" fill="#4988b6" /><rect x="201.4642857142857" y="40.676715956507095" width="2.9107142857142856" height="69.3232840434929" fill="#0000ff" /><rect x="201.4642857142857" y="4.181598298722413" width="2.9107142857142856" height="36.49511765778468" fill="#ff0000" /><rect x="204.375" y="4.685368672919196" width="2.9107142857142856" height="105.3146313270808" fill="#4988b6" /><rect x="204.375" y="40.05808938867881" width="2.9107142857142856" height="69.94191061132119" fill="#0000ff" /><rect x="204.375" y="4.685368672919196" width="2.9107142857142856" height="35.37272071575961" fill="#ff0000" /><rect x="207.28571428571428" y="5.481915781185364" width="2.9107142857142856" height="104.51808421881464" fill="#4988b6" /><rect x="207.28571428571428" y="39.61281930831012" width="2.9107142857142856" height="70.38718069168988" fill="#0000ff" /><rect x="207.28571428571428" y="5.481915781185364" width="2.9107142857142856" height="34.13090352712476" fill="#ff0000" /><rect x="210.19642857142856" y="6.536896410807003" width="2.9107142857142856" height="103.463103589193" fill="#4988b6" /><rect x="210.19642857142856" y="39.34429448957398" width="2.9107142857142856" height="70.65570551042602" fill="#0000ff" /><rect x="210.19642857142856" y="6.536896410807003" width="2.9107142857142856" height="32.80739807876698" fill="#ff0000" /><rect x="213.10714285714286" y="7.812140154472232" width="2.9107142857142856" height="102.18785984552777" fill="#4988b6" /><rect x="213.10714285714286" y="39.254558568480775" width="2.9107142857142856" height="70.74544143151923" fill="#0000ff" /><rect x="213.10714285714286" y="7.812140154472228" width="2.9107142857142856" height="31.442418414008547" fill="#ff0000" /><rect x="216.01785714285714" y="9.26685574032389" width="2.9107142857142856" height="100.73314425967611" fill="#4988b6" /><rect x="216.01785714285714" y="39.344294489574" width="2.9107142857142856" height="70.655705510426" fill="#0000ff" /><rect x="216.01785714285714" y="9.26685574032388" width="2.9107142857142856" height="30.077438749250117" fill="#ff0000" /><rect x="218.92857142857142" y="10.858886007417766" width="2.9107142857142856" height="99.14111399258223" fill="#4988b6" /><rect x="218.92857142857142" y="39.61281930831011" width="2.9107142857142856" height="70.38718069168989" fill="#0000ff" /><rect x="218.92857142857142" y="10.85888600741777" width="2.9107142857142856" height="28.75393330089234" fill="#ff0000" /><rect x="221.8392857142857" y="12.54597327642135" width="2.9107142857142856" height="97.45402672357865" fill="#4988b6" /><rect x="221.8392857142857" y="40.05808938867882" width="2.9107142857142856" height="69.94191061132118" fill="#0000ff" /><rect x="221.8392857142857" y="12.545973276421346" width="2.9107142857142856" height="27.512116112257477" fill="#ff0000" /><rect x="224.75" y="14.286996786274685" width="2.9107142857142856" height="95.71300321372532" fill="#4988b6" /><rect x="224.75" y="40.67671595650708" width="2.9107142857142856" height="69.32328404349292" fill="#0000ff" /><rect x="224.75" y="14.286996786274678" width="2.9107142857142856" height="26.389719170232404" fill="#ff0000" /><rect x="227.66071428571428" y="16.04314495213653" width="2.9107142857142856" height="93.95685504786347" fill="#4988b6" /><rect x="227.66071428571428" y="41.463990890076815" width="2.9107142857142856" height="68.53600910992319" fill="#0000ff" /><rect x="227.66071428571428" y="16.04314495213654" width="2.9107142857142856" height="25.420845937940275" fill="#ff0000" /><rect x="230.57142857142856" y="17.77898741350313" width="2.9107142857142856" height="92.22101258649687" fill="#4988b6" /><rect x="230.57142857142856" y="42.41392255177392" width="2.9107142857142856" height="67.58607744822608" fill="#0000ff" /><rect x="230.57142857142856" y="17.778987413503135" width="2.9107142857142856" height="24.634935138270787" fill="#ff0000" /><rect x="233.48214285714286" y="55.34616796964721" width="2.9107142857142856" height="54.65383203035279" fill="#4988b6" /><rect x="233.48214285714286" y="65.04580470058323" width="2.9107142857142856" height="44.954195299416774" fill="#0000ff" /><rect x="233.48214285714286" y="55.346167969647226" width="2.9107142857142856" height="9.699636730936003" fill="#ff0000" /><rect x="236.39285714285714" y="53.59001980378537" width="2.9107142857142856" height="56.40998019621463" fill="#4988b6" /><rect x="236.39285714285714" y="64.2585297670135" width="2.9107142857142856" height="45.74147023298651" fill="#0000ff" /><rect x="236.39285714285714" y="53.590019803785374" width="2.9107142857142856" height="10.668509963228125" fill="#ff0000" /><rect x="239.30357142857142" y="51.84899629393202" width="2.9107142857142856" height="58.15100370606798" fill="#4988b6" /><rect x="239.30357142857142" y="63.63990319918522" width="2.9107142857142856" height="46.36009680081478" fill="#0000ff" /><rect x="239.30357142857142" y="51.84899629393202" width="2.9107142857142856" height="11.790906905253202" fill="#ff0000" /><rect x="242.2142857142857" y="50.161909024928455" width="2.9107142857142856" height="59.838090975071545" fill="#4988b6" /><rect x="242.2142857142857" y="63.194633118816526" width="2.9107142857142856" height="46.805366881183474" fill="#0000ff" /><rect x="242.2142857142857" y="50.16190902492846" width="2.9107142857142856" height="13.032724093888062" fill="#ff0000" /><rect x="245.125" y="48.569878757834566" width="2.9107142857142856" height="61.430121242165434" fill="#4988b6" /><rect x="245.125" y="62.92610830008041" width="2.9107142857142856" height="47.07389169991959" fill="#0000ff" /><rect x="245.125" y="48.56987875783457" width="2.9107142857142856" height="14.356229542245838" fill="#ff0000" /><rect x="248.03571428571428" y="47.11516317198291" width="2.9107142857142856" height="62.88483682801709" fill="#4988b6" /><rect x="248.03571428571428" y="62.83637237898718" width="2.9107142857142856" height="47.16362762101282" fill="#0000ff" /><rect x="248.03571428571428" y="47.11516317198291" width="2.9107142857142856" height="15.721209207004273" fill="#ff0000" /><rect x="250.94642857142856" y="45.839919428317685" width="2.9107142857142856" height="64.16008057168231" fill="#4988b6" /><rect x="250.94642857142856" y="62.926108300080394" width="2.9107142857142856" height="47.073891699919606" fill="#0000ff" /><rect x="250.94642857142856" y="45.839919428317685" width="2.9107142857142856" height="17.086188871762705" fill="#ff0000" /><rect x="253.85714285714283" y="44.78493879869603" width="2.9107142857142856" height="65.21506120130397" fill="#4988b6" /><rect x="253.85714285714283" y="63.19463311881652" width="2.9107142857142856" height="46.80536688118348" fill="#0000ff" /><rect x="253.85714285714283" y="44.78493879869603" width="2.9107142857142856" height="18.409694320120483" fill="#ff0000" /><rect x="256.7678571428571" y="43.98839169042989" width="2.9107142857142856" height="66.01160830957011" fill="#4988b6" /><rect x="256.7678571428571" y="63.63990319918523" width="2.9107142857142856" height="46.36009680081477" fill="#0000ff" /><rect x="256.7678571428571" y="43.98839169042989" width="2.9107142857142856" height="19.651511508755338" fill="#ff0000" /><rect x="259.67857142857144" y="43.484621316233074" width="2.9107142857142856" height="66.51537868376693" fill="#4988b6" /><rect x="259.67857142857144" y="64.2585297670135" width="2.9107142857142856" height="45.74147023298651" fill="#0000ff" /><rect x="259.67857142857144" y="43.48462131623308" width="2.9107142857142856" height="20.773908450780418" fill="#ff0000" /><rect x="262.58928571428567" y="43.30302301751068" width="2.9107142857142856" height="66.69697698248932" fill="#4988b6" /><rect x="262.58928571428567" y="65.04580470058322" width="2.9107142857142856" height="44.95419529941678" fill="#0000ff" /><rect x="262.58928571428567" y="43.303023017510675" width="2.9107142857142856" height="21.742781683072543" fill="#ff0000" /><rect x="265.5" y="43.467043879538295" width="2.9107142857142856" height="66.5329561204617" fill="#4988b6" /><rect x="265.5" y="65.99573636228033" width="2.9107142857142856" height="44.004263637719674" fill="#0000ff" /><rect x="265.5" y="43.467043879538295" width="2.9107142857142856" height="22.52869248274203" fill="#ff0000" /><rect x="268.4107142857143" y="43.99333385074391" width="2.9107142857142856" height="66.00666614925609" fill="#4988b6" /><rect x="268.4107142857143" y="67.10109519857488" width="2.9107142857142856" height="42.89890480142512" fill="#0000ff" /><rect x="268.4107142857143" y="43.99333385074391" width="2.9107142857142856" height="23.10776134783097" fill="#ff0000" /><rect x="271.32142857142856" y="44.891075197392155" width="2.9107142857142856" height="65.10892480260785" fill="#4988b6" /><rect x="271.32142857142856" y="68.35346876128878" width="2.9107142857142856" height="41.64653123871121" fill="#0000ff" /><rect x="271.32142857142856" y="44.891075197392155" width="2.9107142857142856" height="23.46239356389663" fill="#ff0000" /><rect x="274.23214285714283" y="46.16151192089953" width="2.9107142857142856" height="63.83848807910047" fill="#4988b6" /><rect x="274.23214285714283" y="69.74332573140593" width="2.9107142857142856" height="40.25667426859407" fill="#0000ff" /><rect x="274.23214285714283" y="46.16151192089953" width="2.9107142857142856" height="23.581813810506407" fill="#ff0000" /><rect x="277.1428571428571" y="47.797694894268524" width="2.9107142857142856" height="62.202305105731476" fill="#4988b6" /><rect x="277.1428571428571" y="71.26008845816514" width="2.9107142857142856" height="38.73991154183485" fill="#0000ff" /><rect x="277.1428571428571" y="47.79769489426852" width="2.9107142857142856" height="23.462393563896626" fill="#ff0000" /><rect x="280.05357142857144" y="49.78445211353847" width="2.9107142857142856" height="60.21554788646153" fill="#4988b6" /><rect x="280.05357142857144" y="72.89221346136944" width="2.9107142857142856" height="37.107786538630556" fill="#0000ff" /><rect x="280.05357142857144" y="49.784452113538464" width="2.9107142857142856" height="23.107761347830973" fill="#ff0000" /><rect x="282.9642857142857" y="52.09858680149835" width="2.9107142857142856" height="57.90141319850165" fill="#4988b6" /><rect x="282.9642857142857" y="74.62727928424039" width="2.9107142857142856" height="35.37272071575961" fill="#0000ff" /><rect x="282.9642857142857" y="52.09858680149836" width="2.9107142857142856" height="22.52869248274203" fill="#ff0000" /><rect x="285.875" y="54.70929934513201" width="2.9107142857142856" height="55.29070065486799" fill="#4988b6" /><rect x="285.875" y="76.45208102820455" width="2.9107142857142856" height="33.547918971795454" fill="#0000ff" /><rect x="285.875" y="54.709299345132" width="2.9107142857142856" height="21.742781683072543" fill="#ff0000" /><rect x="288.7857142857143" y="57.578822399364526" width="2.9107142857142856" height="52.421177600635474" fill="#4988b6" /><rect x="288.7857142857143" y="78.35273085014495" width="2.9107142857142856" height="31.64726914985505" fill="#0000ff" /><rect x="288.7857142857143" y="57.57882239936453" width="2.9107142857142856" height="20.773908450780418" fill="#ff0000" /><rect x="291.69642857142856" y="60.66325214851754" width="2.9107142857142856" height="49.33674785148246" fill="#4988b6" /><rect x="291.69642857142856" y="80.31476365727289" width="2.9107142857142856" height="29.685236342727116" fill="#0000ff" /><rect x="291.69642857142856" y="60.66325214851755" width="2.9107142857142856" height="19.65151150875534" fill="#ff0000" /><rect x="294.60714285714283" y="63.913552875097814" width="2.9107142857142856" height="46.086447124902186" fill="#4988b6" /><rect x="294.60714285714283" y="82.3232471952183" width="2.9107142857142856" height="27.6767528047817" fill="#0000ff" /><rect x="294.60714285714283" y="63.913552875097814" width="2.9107142857142856" height="18.409694320120487" fill="#ff0000" /><rect x="297.5178571428571" y="67.27670681973922" width="2.9107142857142856" height="42.72329318026078" fill="#4988b6" /><rect x="297.5178571428571" y="84.36289569150192" width="2.9107142857142856" height="25.63710430849808" fill="#0000ff" /><rect x="297.5178571428571" y="67.27670681973922" width="2.9107142857142856" height="17.086188871762705" fill="#ff0000" /><text x="20" text-anchor="start" y="125" font-family="Times, serif" fill="#000000" font-size="14px">Sun-00</text><text x="509" text-anchor="end" y="125" font-family="Times, serif" fill="#000000" font-size="14px">Sat-23</text><text x="264.5" text-anchor="middle" y="125" font-family="Times, serif" fill="#000000" font-size="14px">day_of_week_hour</text><text x="17" text-anchor="end" y="3" font-family="Times, serif" fill="#000000" font-size="14px" transform="rotate(-90,17,3)">67</text><text x="17" text-anchor="start" y="109" font-family="Times, serif" fill="#000000" font-size="14px" transform="rotate(-90,17,109)">count</text><rect width="511" height="127" x="0" y="0" fill-opacity="0.0" stroke="#000000" /></svg>

# %% [markdown]
# ## Simple XY Scatterplot Example (Temporal)

# %%
# Simple xy scatterplot example
# dataframe is assumed to be from the periodic barchart example above
rt.xy(df, x_field='timestamp', y_field='count', color_by='type', line_groupby_field='type', w=1024, h=512)

# %% [markdown]
# <svg id="xy_51962" x="0" y="0" width="1024" height="512" xmlns="http://www.w3.org/2000/svg"><rect width="1023" height="511" x="0" y="0" fill="#ffffff" fill-opacity="1.0" stroke="#ffffff" stroke-opacity="1.0" /><line x1="17.0" y1="3" x2="17.0" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="100.5" y1="3" x2="100.5" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="184.0" y1="3" x2="184.0" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="267.5" y1="3" x2="267.5" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="351.0" y1="3" x2="351.0" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="434.5" y1="3" x2="434.5" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="518.0" y1="3" x2="518.0" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="601.5" y1="3" x2="601.5" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="685.0" y1="3" x2="685.0" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="768.5" y1="3" x2="768.5" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="852.0" y1="3" x2="852.0" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="935.5" y1="3" x2="935.5" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="1019.0" y1="3" x2="1019.0" y2="8" stroke="#909090" stroke-width="0.8" /><line x1="17.0" y1="3" x2="17.0" y2="493" stroke="#909090" stroke-width="0.8" /><text x="19.0" text-anchor="start" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">01-01</text><line x1="184.0" y1="3" x2="184.0" y2="493" stroke="#909090" stroke-width="0.8" /><text x="186.0" text-anchor="start" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">01-03</text><line x1="351.0" y1="3" x2="351.0" y2="493" stroke="#909090" stroke-width="0.8" /><text x="353.0" text-anchor="start" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">01-05</text><line x1="518.0" y1="3" x2="518.0" y2="493" stroke="#909090" stroke-width="0.8" /><text x="520.0" text-anchor="start" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">01-07</text><line x1="685.0" y1="3" x2="685.0" y2="493" stroke="#909090" stroke-width="0.8" /><text x="687.0" text-anchor="start" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">01-09</text><line x1="852.0" y1="3" x2="852.0" y2="493" stroke="#909090" stroke-width="0.8" /><text x="854.0" text-anchor="start" y="16" font-family="Times, serif" fill="#808080" font-size="9.0px">01-11</text><line x1="17" y1="495" x2="17"                 y2="3"      stroke="#101010" stroke-width=".6" /><line x1="17" y1="495" x2="1019" y2="495"   stroke="#101010" stroke-width=".6" /><polyline points="17,247 20,269 23,290 27,311 30,331 34,351 37,370 41,388 44,405 48,421 51,435 55,448 58,460 62,470 65,478 69,484 72,489 76,492 79,493 83,492 86,489 90,484 93,478 97,470 100,460 103,448 107,435 110,421 114,405 117,388 121,370 124,351 128,331 131,311 135,290 138,269 142,248 145,226 149,205 152,184 156,164 159,144 163,125 166,107 170,90 173,74 177,60 180,47 184,35 187,25 190,17 194,11 197,6 201,3 204,3 208,3 211,6 215,11 218,17 222,25 225,35 229,47 232,60 236,74 239,90 243,107 246,125 250,144 253,164 257,184 260,205 264,226 267,247 270,269 274,290 277,311 281,331 284,351 288,370 291,388 295,405 298,421 302,435 305,448 309,460 312,470 316,478 319,484 323,489 326,492 330,493 333,492 337,489 340,484 344,478 347,470 351,460 354,448 357,435 361,421 364,405 368,388 371,370 375,351 378,331 382,311 385,290 389,269 392,248 396,226 399,205 403,184 406,164 410,144 413,125 417,107 420,90 424,74 427,60 431,47 434,35 437,25 441,17 444,11 448,6 451,3 455,3 458,3 462,6 465,11 469,17 472,25 476,35 479,47 483,60 486,74 490,90 493,107 497,125 500,144 504,164 507,184 511,205 514,226 518,247 521,269 524,290 528,311 531,331 535,351 538,370 542,388 545,405 549,421 552,435 556,448 559,460 563,470 566,478 570,484 573,489 577,492 580,493 584,492 587,489 591,484 594,478 598,470 601,460 604,448 608,435 611,421 615,405 618,388 622,370 625,351 629,331 632,311 636,290 639,269 643,248 646,226 650,205 653,184 657,164 660,144 664,125 667,107 671,90 674,74 678,60 681,47 685,35 688,25 691,17 695,11 698,6 702,3 705,3 709,3 712,6 716,11 719,17 723,25 726,35 730,47 733,60 737,74 740,90 744,107 747,125 751,144 754,164 758,184 761,205 765,226 768,247 771,269 775,290 778,311 782,331 785,351 789,370 792,388 796,405 799,421 803,435 806,448 810,460 813,470 817,478 820,484 824,489 827,492 831,493 834,492 838,489 841,484 845,478 848,470 852,460 855,448 858,435 862,421 865,405 869,388 872,370 876,351 879,331 883,311 886,290 890,269 893,248 897,226 900,205 904,184 907,164 911,144 914,125 918,107 921,90 925,74 928,60 932,47 935,35 938,25 942,17 945,11 949,6 952,3 956,3 959,3 963,6 966,11 970,17 973,25 977,35 980,47 984,60 987,74 991,90 994,107 998,125 1001,144 1005,164 1008,184 1012,205 1015,226 1019,247 " stroke="#0000ff" stroke-width="1" fill="none" /><polyline points="17,329 20,343 23,357 27,370 30,382 34,392 37,400 41,406 44,410 48,411 51,410 55,406 58,400 62,392 65,382 69,370 72,357 76,343 79,329 83,315 86,301 90,288 93,277 97,267 100,258 103,252 107,249 110,248 114,249 117,252 121,258 124,267 128,277 131,288 135,301 138,315 142,329 145,343 149,357 152,370 156,382 159,392 163,400 166,406 170,410 173,411 177,410 180,406 184,400 187,392 190,382 194,370 197,357 201,343 204,329 208,315 211,301 215,288 218,277 222,267 225,258 229,252 232,249 236,248 239,249 243,252 246,258 250,267 253,277 257,288 260,301 264,315 267,329 270,343 274,357 277,370 281,382 284,392 288,400 291,406 295,410 298,411 302,410 305,406 309,400 312,392 316,382 319,370 323,357 326,343 330,329 333,315 337,301 340,288 344,277 347,267 351,258 354,252 357,249 361,248 364,249 368,252 371,258 375,267 378,277 382,288 385,301 389,315 392,329 396,343 399,357 403,370 406,382 410,392 413,400 417,406 420,410 424,411 427,410 431,406 434,400 437,392 441,382 444,370 448,357 451,343 455,329 458,315 462,301 465,288 469,277 472,267 476,258 479,252 483,249 486,248 490,249 493,252 497,258 500,267 504,277 507,288 511,301 514,315 518,329 521,343 524,357 528,370 531,382 535,392 538,400 542,406 545,410 549,411 552,410 556,406 559,400 563,392 566,382 570,370 573,357 577,343 580,329 584,315 587,301 591,288 594,277 598,267 601,258 604,252 608,249 611,248 615,249 618,252 622,258 625,267 629,277 632,288 636,301 639,315 643,329 646,343 650,357 653,370 657,382 660,392 664,400 667,406 671,410 674,411 678,410 681,406 685,400 688,392 691,382 695,370 698,357 702,343 705,329 709,315 712,301 716,288 719,277 723,267 726,258 730,252 733,249 737,248 740,249 744,252 747,258 751,267 754,277 758,288 761,301 765,315 768,329 771,343 775,357 778,370 782,382 785,392 789,400 792,406 796,410 799,411 803,410 806,406 810,400 813,392 817,382 820,370 824,357 827,343 831,329 834,315 838,301 841,288 845,277 848,267 852,258 855,252 858,249 862,248 865,249 869,252 872,258 876,267 879,277 883,288 886,301 890,315 893,329 897,343 900,357 904,370 907,382 911,392 914,400 918,406 921,410 925,411 928,410 932,406 935,400 938,392 942,382 945,370 949,357 952,343 956,329 959,315 963,301 966,288 970,277 973,267 977,258 980,252 984,249 987,248 991,249 994,252 998,258 1001,267 1005,277 1008,288 1012,301 1015,315 1019,329 " stroke="#ff0000" stroke-width="1" fill="none" /><circle cx="17" cy="247" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="17" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="20" cy="269" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="20" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="23" cy="290" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="23" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="27" cy="311" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="27" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="30" cy="331" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="30" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="34" cy="351" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="34" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="37" cy="370" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="37" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="41" cy="388" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="41" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="44" cy="405" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="44" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="48" cy="411" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="48" cy="421" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="51" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="51" cy="435" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="55" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="55" cy="448" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="58" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="58" cy="460" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="62" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="62" cy="470" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="65" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="65" cy="478" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="69" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="69" cy="484" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="72" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="72" cy="489" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="76" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="76" cy="492" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="79" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="79" cy="493" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="83" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="83" cy="492" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="86" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="86" cy="489" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="90" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="90" cy="484" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="93" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="93" cy="478" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="97" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="97" cy="470" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="100" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="100" cy="460" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="103" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="103" cy="448" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="107" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="107" cy="435" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="110" cy="248" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="110" cy="421" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="114" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="114" cy="405" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="117" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="117" cy="388" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="121" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="121" cy="370" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="124" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="124" cy="351" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="128" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="128" cy="331" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="131" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="131" cy="311" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="135" cy="290" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="135" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="138" cy="269" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="138" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="142" cy="248" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="142" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="145" cy="226" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="145" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="149" cy="205" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="149" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="152" cy="184" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="152" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="156" cy="164" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="156" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="159" cy="144" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="159" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="163" cy="125" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="163" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="166" cy="107" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="166" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="170" cy="90" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="170" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="173" cy="74" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="173" cy="411" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="177" cy="60" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="177" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="180" cy="47" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="180" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="184" cy="35" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="184" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="187" cy="25" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="187" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="190" cy="17" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="190" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="194" cy="11" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="194" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="197" cy="6" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="197" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="201" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="201" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="204" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="204" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="208" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="208" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="211" cy="6" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="211" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="215" cy="11" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="215" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="218" cy="17" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="218" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="222" cy="25" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="222" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="225" cy="35" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="225" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="229" cy="47" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="229" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="232" cy="60" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="232" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="236" cy="74" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="236" cy="248" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="239" cy="90" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="239" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="243" cy="107" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="243" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="246" cy="125" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="246" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="250" cy="144" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="250" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="253" cy="164" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="253" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="257" cy="184" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="257" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="260" cy="205" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="260" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="264" cy="226" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="264" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="267" cy="247" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="267" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="270" cy="269" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="270" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="274" cy="290" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="274" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="277" cy="311" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="277" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="281" cy="331" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="281" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="284" cy="351" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="284" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="288" cy="370" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="288" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="291" cy="388" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="291" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="295" cy="405" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="295" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="298" cy="411" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="298" cy="421" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="302" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="302" cy="435" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="305" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="305" cy="448" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="309" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="309" cy="460" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="312" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="312" cy="470" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="316" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="316" cy="478" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="319" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="319" cy="484" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="323" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="323" cy="489" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="326" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="326" cy="492" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="330" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="330" cy="493" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="333" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="333" cy="492" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="337" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="337" cy="489" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="340" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="340" cy="484" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="344" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="344" cy="478" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="347" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="347" cy="470" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="351" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="351" cy="460" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="354" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="354" cy="448" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="357" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="357" cy="435" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="361" cy="248" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="361" cy="421" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="364" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="364" cy="405" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="368" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="368" cy="388" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="371" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="371" cy="370" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="375" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="375" cy="351" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="378" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="378" cy="331" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="382" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="382" cy="311" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="385" cy="290" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="385" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="389" cy="269" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="389" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="392" cy="248" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="392" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="396" cy="226" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="396" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="399" cy="205" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="399" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="403" cy="184" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="403" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="406" cy="164" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="406" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="410" cy="144" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="410" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="413" cy="125" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="413" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="417" cy="107" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="417" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="420" cy="90" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="420" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="424" cy="74" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="424" cy="411" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="427" cy="60" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="427" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="431" cy="47" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="431" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="434" cy="35" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="434" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="437" cy="25" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="437" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="441" cy="17" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="441" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="444" cy="11" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="444" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="448" cy="6" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="448" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="451" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="451" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="455" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="455" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="458" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="458" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="462" cy="6" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="462" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="465" cy="11" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="465" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="469" cy="17" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="469" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="472" cy="25" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="472" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="476" cy="35" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="476" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="479" cy="47" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="479" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="483" cy="60" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="483" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="486" cy="74" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="486" cy="248" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="490" cy="90" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="490" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="493" cy="107" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="493" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="497" cy="125" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="497" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="500" cy="144" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="500" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="504" cy="164" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="504" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="507" cy="184" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="507" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="511" cy="205" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="511" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="514" cy="226" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="514" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="518" cy="247" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="518" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="521" cy="269" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="521" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="524" cy="290" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="524" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="528" cy="311" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="528" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="531" cy="331" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="531" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="535" cy="351" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="535" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="538" cy="370" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="538" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="542" cy="388" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="542" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="545" cy="405" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="545" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="549" cy="411" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="549" cy="421" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="552" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="552" cy="435" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="556" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="556" cy="448" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="559" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="559" cy="460" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="563" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="563" cy="470" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="566" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="566" cy="478" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="570" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="570" cy="484" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="573" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="573" cy="489" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="577" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="577" cy="492" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="580" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="580" cy="493" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="584" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="584" cy="492" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="587" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="587" cy="489" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="591" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="591" cy="484" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="594" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="594" cy="478" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="598" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="598" cy="470" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="601" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="601" cy="460" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="604" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="604" cy="448" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="608" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="608" cy="435" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="611" cy="248" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="611" cy="421" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="615" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="615" cy="405" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="618" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="618" cy="388" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="622" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="622" cy="370" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="625" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="625" cy="351" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="629" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="629" cy="331" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="632" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="632" cy="311" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="636" cy="290" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="636" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="639" cy="269" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="639" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="643" cy="248" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="643" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="646" cy="226" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="646" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="650" cy="205" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="650" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="653" cy="184" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="653" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="657" cy="164" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="657" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="660" cy="144" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="660" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="664" cy="125" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="664" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="667" cy="107" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="667" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="671" cy="90" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="671" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="674" cy="74" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="674" cy="411" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="678" cy="60" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="678" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="681" cy="47" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="681" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="685" cy="35" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="685" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="688" cy="25" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="688" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="691" cy="17" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="691" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="695" cy="11" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="695" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="698" cy="6" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="698" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="702" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="702" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="705" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="705" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="709" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="709" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="712" cy="6" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="712" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="716" cy="11" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="716" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="719" cy="17" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="719" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="723" cy="25" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="723" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="726" cy="35" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="726" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="730" cy="47" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="730" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="733" cy="60" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="733" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="737" cy="74" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="737" cy="248" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="740" cy="90" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="740" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="744" cy="107" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="744" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="747" cy="125" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="747" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="751" cy="144" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="751" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="754" cy="164" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="754" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="758" cy="184" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="758" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="761" cy="205" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="761" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="765" cy="226" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="765" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="768" cy="247" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="768" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="771" cy="269" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="771" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="775" cy="290" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="775" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="778" cy="311" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="778" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="782" cy="331" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="782" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="785" cy="351" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="785" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="789" cy="370" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="789" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="792" cy="388" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="792" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="796" cy="405" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="796" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="799" cy="411" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="799" cy="421" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="803" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="803" cy="435" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="806" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="806" cy="448" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="810" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="810" cy="460" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="813" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="813" cy="470" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="817" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="817" cy="478" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="820" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="820" cy="484" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="824" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="824" cy="489" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="827" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="827" cy="492" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="831" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="831" cy="493" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="834" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="834" cy="492" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="838" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="838" cy="489" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="841" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="841" cy="484" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="845" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="845" cy="478" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="848" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="848" cy="470" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="852" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="852" cy="460" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="855" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="855" cy="448" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="858" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="858" cy="435" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="862" cy="248" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="862" cy="421" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="865" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="865" cy="405" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="869" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="869" cy="388" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="872" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="872" cy="370" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="876" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="876" cy="351" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="879" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="879" cy="331" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="883" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="883" cy="311" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="886" cy="290" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="886" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="890" cy="269" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="890" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="893" cy="248" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="893" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="897" cy="226" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="897" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="900" cy="205" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="900" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="904" cy="184" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="904" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="907" cy="164" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="907" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="911" cy="144" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="911" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="914" cy="125" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="914" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="918" cy="107" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="918" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="921" cy="90" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="921" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="925" cy="74" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="925" cy="411" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="928" cy="60" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="928" cy="410" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="932" cy="47" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="932" cy="406" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="935" cy="35" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="935" cy="400" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="938" cy="25" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="938" cy="392" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="942" cy="17" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="942" cy="382" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="945" cy="11" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="945" cy="370" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="949" cy="6" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="949" cy="357" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="952" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="952" cy="343" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="956" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="956" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="959" cy="3" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="959" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="963" cy="6" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="963" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="966" cy="11" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="966" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="970" cy="17" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="970" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="973" cy="25" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="973" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="977" cy="35" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="977" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="980" cy="47" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="980" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="984" cy="60" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="984" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="987" cy="74" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="987" cy="248" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="991" cy="90" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="991" cy="249" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="994" cy="107" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="994" cy="252" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="998" cy="125" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="998" cy="258" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1001" cy="144" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1001" cy="267" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1005" cy="164" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1005" cy="277" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1008" cy="184" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1008" cy="288" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1012" cy="205" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1012" cy="301" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1015" cy="226" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1015" cy="315" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1019" cy="247" r="2" fill="#0000ff" stroke="#0000ff" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="1019" cy="329" r="2" fill="#ff0000" stroke="#ff0000" fill-opacity="1.0" stroke-opacity="1.0" /><text x="17" text-anchor="start" y="509" font-family="Times, serif" fill="#000000" font-size="12px">2021-01-01</text><text x="1019" text-anchor="end" y="509" font-family="Times, serif" fill="#000000" font-size="12px">2021-01-13</text><text x="518.0" text-anchor="middle" y="509" font-family="Times, serif" fill="#000000" font-size="12px">timestamp</text><text x="13" text-anchor="start" y="493" font-family="Times, serif" fill="#000000" font-size="12px" transform="rotate(-90,13,493)">0.00</text><text x="13" text-anchor="end" y="3" font-family="Times, serif" fill="#000000" font-size="12px" transform="rotate(-90,13,3)">30.00</text><text x="13" text-anchor="middle" y="248.0" font-family="Times, serif" fill="#000000" font-size="12px" transform="rotate(-90,13,248.0)">count</text><rect width="1023" height="512" x="0" y="0" fill-opacity="0.0" stroke="#000000" /></svg>

# %% [markdown]
# ## Simple LinkNode Example

# %%
# Simple linknode example
import networkx as nx

df = pd.DataFrame({'src':  ['a',  'a',  'a',  'a', 'b', 'c', 'd', 'e',  'e',  'e',  'e',  'e',  'c', 'f',  'f',  'f'],
                   'dst':  ['a0', 'a1', 'a2', 'b', 'c', 'd', 'e', 'e0', 'e1', 'e2', 'e3', 'e4', 'f', 'f0', 'f1', 'f2'],
                   'color':['x',  'x',  'x',  'x', 'x', 'y', 'y', 'y',  'y',  'y',  'y',  'y',  'z', 'z',  'z',  'z']})

_relationships = [('src','dst')]

df_g = rt.createNetworkXGraph(df, _relationships)
df_g_pos = nx.spring_layout(df_g)

rt.linkNode(df, _relationships, df_g_pos, color_by='color', link_color='vary', link_arrow=False, link_size='medium')

# %% [markdown]
# <svg id="linknode_59899" x="0" y="0" width="256" height="256" xmlns="http://www.w3.org/2000/svg"><rect width="255" height="255" x="0" y="0" fill="#ffffff" stroke="#ffffff" /><line x1="110.46161915951954" y1="43.26806157001957" x2="76.35456764495008" y2="30.425329890485276" stroke-width="3" stroke="#b0b383" stroke-opacity="1.0" /><line x1="110.46161915951954" y1="43.26806157001957" x2="102.21188379219159" y2="14.363636363636374" stroke-width="3" stroke="#b0b383" stroke-opacity="1.0" /><line x1="110.46161915951954" y1="43.26806157001957" x2="134.76680515449567" y2="21.587036053917615" stroke-width="3" stroke="#b0b383" stroke-opacity="1.0" /><line x1="110.46161915951954" y1="43.26806157001957" x2="123.019793739356" y2="86.18081093581107" stroke-width="3" stroke="#b0b383" stroke-opacity="1.0" /><line x1="123.019793739356" y1="86.18081093581107" x2="136.88316467970395" y2="131.07098293333797" stroke-width="3" stroke="#b0b383" stroke-opacity="1.0" /><line x1="136.88316467970395" y1="131.07098293333797" x2="96.52616631994123" y2="170.8475338704195" stroke-width="3" stroke="#0e2fae" stroke-opacity="1.0" /><line x1="136.88316467970395" y1="131.07098293333797" x2="199.22569742544698" y2="133.59935774665243" stroke-width="3" stroke="#75d67e" stroke-opacity="1.0" /><line x1="96.52616631994123" y1="170.8475338704195" x2="56.11908931915156" y2="211.10154008726727" stroke-width="3" stroke="#0e2fae" stroke-opacity="1.0" /><line x1="56.11908931915156" y1="211.10154008726727" x2="24.590872257784326" y2="196.7802209571439" stroke-width="3" stroke="#0e2fae" stroke-opacity="1.0" /><line x1="56.11908931915156" y1="211.10154008726727" x2="30.38324078074987" y2="236.0004509776025" stroke-width="3" stroke="#0e2fae" stroke-opacity="1.0" /><line x1="56.11908931915156" y1="211.10154008726727" x2="14.363636363636358" y2="218.21195243508328" stroke-width="3" stroke="#0e2fae" stroke-opacity="1.0" /><line x1="56.11908931915156" y1="211.10154008726727" x2="85.42986656537252" y2="228.32539253186013" stroke-width="3" stroke="#0e2fae" stroke-opacity="1.0" /><line x1="56.11908931915156" y1="211.10154008726727" x2="59.20576965360044" y2="241.63636363636365" stroke-width="3" stroke="#0e2fae" stroke-opacity="1.0" /><line x1="199.22569742544698" y1="133.59935774665243" x2="241.63636363636363" y2="135.15875527152068" stroke-width="3" stroke="#75d67e" stroke-opacity="1.0" /><line x1="199.22569742544698" y1="133.59935774665243" x2="223.57838135293056" y2="155.0564395499488" stroke-width="3" stroke="#75d67e" stroke-opacity="1.0" /><line x1="199.22569742544698" y1="133.59935774665243" x2="226.5798214768241" y2="114.28385364573445" stroke-width="3" stroke="#75d67e" stroke-opacity="1.0" /><circle cx="110.46161915951954" cy="43.26806157001957" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="123.019793739356" cy="86.18081093581107" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="136.88316467970395" cy="131.07098293333797" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="96.52616631994123" cy="170.8475338704195" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="56.11908931915156" cy="211.10154008726727" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="199.22569742544698" cy="133.59935774665243" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="76.35456764495008" cy="30.425329890485276" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="102.21188379219159" cy="14.363636363636374" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="134.76680515449567" cy="21.587036053917615" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="24.590872257784326" cy="196.7802209571439" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="30.38324078074987" cy="236.0004509776025" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="14.363636363636358" cy="218.21195243508328" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="85.42986656537252" cy="228.32539253186013" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="59.20576965360044" cy="241.63636363636365" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="241.63636363636363" cy="135.15875527152068" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="223.57838135293056" cy="155.0564395499488" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><circle cx="226.5798214768241" cy="114.28385364573445" r="5" fill="#4988b6" stroke="#2f54d0" fill-opacity="1.0" stroke-opacity="1.0" /><text x="110.46161915951954" text-anchor="middle" y="60.26806157001957" font-family="Times, serif" fill="#000000" font-size="12px">a</text><text x="123.019793739356" text-anchor="middle" y="103.18081093581107" font-family="Times, serif" fill="#000000" font-size="12px">b</text><text x="136.88316467970395" text-anchor="middle" y="148.07098293333797" font-family="Times, serif" fill="#000000" font-size="12px">c</text><text x="96.52616631994123" text-anchor="middle" y="187.8475338704195" font-family="Times, serif" fill="#000000" font-size="12px">d</text><text x="56.11908931915156" text-anchor="middle" y="228.10154008726727" font-family="Times, serif" fill="#000000" font-size="12px">e</text><text x="199.22569742544698" text-anchor="middle" y="150.59935774665243" font-family="Times, serif" fill="#000000" font-size="12px">f</text><text x="76.35456764495008" text-anchor="middle" y="47.42532989048527" font-family="Times, serif" fill="#000000" font-size="12px">a0</text><text x="102.21188379219159" text-anchor="middle" y="31.363636363636374" font-family="Times, serif" fill="#000000" font-size="12px">a1</text><text x="134.76680515449567" text-anchor="middle" y="38.587036053917615" font-family="Times, serif" fill="#000000" font-size="12px">a2</text><text x="24.590872257784326" text-anchor="middle" y="213.7802209571439" font-family="Times, serif" fill="#000000" font-size="12px">e0</text><text x="30.38324078074987" text-anchor="middle" y="253.0004509776025" font-family="Times, serif" fill="#000000" font-size="12px">e1</text><text x="14.363636363636358" text-anchor="middle" y="235.21195243508328" font-family="Times, serif" fill="#000000" font-size="12px">e2</text><text x="85.42986656537252" text-anchor="middle" y="245.32539253186013" font-family="Times, serif" fill="#000000" font-size="12px">e3</text><text x="59.20576965360044" text-anchor="middle" y="258.6363636363636" font-family="Times, serif" fill="#000000" font-size="12px">e4</text><text x="241.63636363636363" text-anchor="middle" y="152.15875527152068" font-family="Times, serif" fill="#000000" font-size="12px">f0</text><text x="223.57838135293056" text-anchor="middle" y="172.0564395499488" font-family="Times, serif" fill="#000000" font-size="12px">f1</text><text x="226.5798214768241" text-anchor="middle" y="131.28385364573444" font-family="Times, serif" fill="#000000" font-size="12px">f2</text><rect width="255" height="255" x="0" y="0" fill-opacity="0.0" stroke="#000000" /></svg>

# %% [markdown]
# ## Simple Histogram Example

# %%
# Simple histogram example
df = pd.DataFrame({'bin':  ['cats', 'dogs', 'horses', 'chickens', 'cows'],
                   'count':[10,     20,     5,        30,         2]})
rt.histogram(df, bin_by='bin', count_by='count', w=256, h=96)

# %% [markdown]
# <svg id="histogram_44990" x="0" y="0" width="256" height="96" xmlns="http://www.w3.org/2000/svg"><rect width="255" height="95" x="0" y="0" fill="#ffffff" stroke="#ffffff" /><rect id="histogram_44990_encsvgid_chickens" width="242.0" height="14" x="0" y="0" fill="#4988b6" stroke="#4988b6"/><rect id="histogram_44990_encsvgid_dogs" width="161.33333333333334" height="14" x="0" y="15" fill="#4988b6" stroke="#4988b6"/><rect id="histogram_44990_encsvgid_cats" width="80.66666666666667" height="14" x="0" y="30" fill="#4988b6" stroke="#4988b6"/><rect id="histogram_44990_encsvgid_horses" width="40.333333333333336" height="14" x="0" y="45" fill="#4988b6" stroke="#4988b6"/><rect id="histogram_44990_encsvgid_cows" width="16.133333333333333" height="14" x="0" y="60" fill="#4988b6" stroke="#4988b6"/><text x="2" text-anchor="start" y="13" font-family="Times, serif" fill="#000000" font-size="12px">chickens</text><text x="2" text-anchor="start" y="28" font-family="Times, serif" fill="#000000" font-size="12px">dogs</text><text x="2" text-anchor="start" y="43" font-family="Times, serif" fill="#000000" font-size="12px">cats</text><text x="2" text-anchor="start" y="58" font-family="Times, serif" fill="#000000" font-size="12px">horses</text><text x="2" text-anchor="start" y="73" font-family="Times, serif" fill="#000000" font-size="12px">cows</text><text x="237" text-anchor="end" y="93" font-family="Times, serif" fill="#000000" font-size="12px">30</text><line x1="242" y1="2" x2="242" y2="96" stroke="#101010" stroke-width="1" stroke-dasharray="3 2" /><text x="246" text-anchor="middle" y="48.0" font-family="Times, serif" fill="#000000" font-size="12px" transform="rotate(90,246,48.0)">bin</text><rect width="255" height="95" x="0" y="0" fill-opacity="0.0" stroke="#000000" /></svg>
